# %%
# !sudo apt-get install -y fonts-nanum

# !sudo fc-cache -fv

# !rm ~/.cache/matplotlib -rf\

# %%
# !apt-get install -y fonts-nanum*
# !rm -rf /root/.cache/matplotlib/* # 폰트 캐시 재설정

# %% [markdown]
# 임폴트

# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from glob import glob
import os
import warnings
import matplotlib as mpl
warnings.filterwarnings('ignore')
plt.rcParams['font.family'] = 'NanumBarunGothic' # 나눔바른고딕 적용하기

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
#
path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
font_name = mpl.font_manager.FontProperties(fname=path).get_name()
plt.rcParams['font.family'] = font_name

# %% [markdown]
# # 데이터 불러오기

# %%
df_member = pd.read_csv('C:/Users/UserK/Desktop/Ranee/data/One_Market_Data/member_data.csv')
df1 = pd.read_csv('C:/Users/UserK/Desktop/Ranee/data/One_Market_Data/product_data_001.csv')
df2 = pd.read_csv('C:/Users/UserK/Desktop/Ranee/data/One_Market_Data/product_data_002.csv')
df3 = pd.read_csv('C:/Users/UserK/Desktop/Ranee/data/One_Market_Data/product_data_003.csv')
df4 = pd.read_csv('C:/Users/UserK/Desktop/Ranee/data/One_Market_Data/product_data_004.csv')

# %%
df = pd.concat([df1,df2,df3,df4]).reset_index(drop=True)

# %% [markdown]
# 범주형 자료

# %%
df_member['모바일알람여부'].replace('.','미수신',inplace=True)

# %%
df_member['모바일알람여부'].value_counts()
# Out:
# 모바일알람여부
# 미수신    10653
# 수신       902
# Name: count, dtype: int64

# %%
df_member['배송서비스신청여부'].value_counts()
# Out:
# 배송서비스신청여부
# 미신청    10512
# 신청      1043
# Name: count, dtype: int64

# %%
df_member['조합원상태'].value_counts()
# Out:
# 조합원상태
# 정상회원     11413
# 탈퇴         139
# 탈퇴처리중        2
# 탈퇴신청         1
# Name: count, dtype: int64

# %%
df_member['성별'].value_counts()
# Out:
# 성별
# 여    10885
# 남      668
# Name: count, dtype: int64

# %%
df_member['주소'].value_counts()
# Out:
# 주소
# 수지구-풍덕천동    3188
# 수지구-상현동     1601
# 수지구-신봉동     1422
# 기타-기타       1126
# 수지구-동천동      924
#             ...
# 수정구-복정동        1
# 수정구-상대원동       1
# 기타-비조합원        1
# 기타-동천동         1
# 기타-성남동         1
# Name: count, Length: 95, dtype: int64

# %%
df_member['Gold_member'].value_counts()
# Out:
# Gold_member
# normal    11350
# VIP         205
# Name: count, dtype: int64

# %% [markdown]
# 총구매횟수,총구매금액,1회평균구매금액 셀 만들기

# %%
df['label'] = 1
p1 = df.pivot_table(index = ['회원번호','공급일자'], values='label', aggfunc='min').reset_index()
p1 = p1.pivot_table(index = '회원번호', values='label', aggfunc='sum').reset_index()

# %%
df_member2 = pd.merge(df_member, p1, on='회원번호', how = 'left').rename(columns={'label':'구매횟수'})
df_member2
# Out:
#              회원번호 조합원상태        주소 성별    연령 배송서비스신청여부 모바일알람여부 Gold_member  구매횟수
# 0      1000012800  정상회원  수지구-풍덕천동  여  58.0       미신청     미수신      normal     1
# 1      1000103744  정상회원   처인구-고림동  여  34.0       미신청     미수신      normal     1
# 2      1000122304  정상회원     광주-기타  여  38.0       미신청     미수신      normal    15
# 3      1000163136  정상회원   수지구-동천동  여  73.0       미신청     미수신      normal     4
# 4      1000281920  정상회원  수지구-풍덕천동  여  42.0        신청     미수신      normal    28
# ...           ...   ...       ... ..   ...       ...     ...         ...   ...
# 11550   999682432    탈퇴   수지구-동천동  여  47.0       미신청     미수신      normal     1
# 11551   999721408  정상회원   수지구-동천동  여  43.0       미신청     미수신      normal     3
# 11552   999738112  정상회원   수지구-성복동  여  67.0       미신청     미수신      normal     9
# 11553   999754816  정상회원   수지구-상현동  여  44.0        신청     미수신      normal    21
# 11554    99995712  정상회원   수지구-상현동  여  66.0       미신청     미수신      normal    40
#
# [11555 rows x 9 columns]

# %%
# 회원별 총 구매금액
df[df['반품_원거래일자'].isnull()].pivot_table(index = '회원번호', values='구매금액', aggfunc='sum').reset_index()
p3 = df.pivot_table(index = '회원번호', values='구매금액', aggfunc='sum').reset_index()
df_member2 = pd.merge(df_member2, p3, on='회원번호', how = 'left').rename(columns={'구매금액':'총구매금액'})
df_member2
# Out:
#              회원번호 조합원상태        주소 성별    연령 배송서비스신청여부 모바일알람여부 Gold_member  \
# 0      1000012800  정상회원  수지구-풍덕천동  여  58.0       미신청     미수신      normal
# 1      1000103744  정상회원   처인구-고림동  여  34.0       미신청     미수신      normal
# 2      1000122304  정상회원     광주-기타  여  38.0       미신청     미수신      normal
# 3      1000163136  정상회원   수지구-동천동  여  73.0       미신청     미수신      normal
# 4      1000281920  정상회원  수지구-풍덕천동  여  42.0        신청     미수신      normal
# ...           ...   ...       ... ..   ...       ...     ...         ...
# 11550   999682432    탈퇴   수지구-동천동  여  47.0       미신청     미수신      normal
# 11551   999721408  정상회원   수지구-동천동  여  43.0       미신청     미수신      normal
# 11552   999738112  정상회원   수지구-성복동  여  67.0       미신청     미수신      normal
# 11553   999754816  정상회원   수지구-상현동  여  44.0        신청     미수신      normal
# 11554    99995712  정상회원   수지구-상현동  여  66.0       미신청     미수신      normal
#
#        구매횟수    총구매금액
# 0         1     7658
# 1         1    36948
# 2        15   142831
# 3         4   138892
# 4        28   592543
# ...     ...      ...
# 11550     1    39246
# 11551     3    39820
# 11552     9   152960
# 11553    21   641334
# 11554    40  1848650
#
# [11555 rows x 10 columns]

# %%
# 회원별 1회 구매 평균 구매 금액
p4 = df.pivot_table(index = ['회원번호','공급일자'], values='구매금액', aggfunc='sum').reset_index()
p3 = p4.pivot_table(index = '회원번호', values='구매금액', aggfunc='mean').reset_index()
df_member2 = pd.merge(df_member2, p3, on='회원번호', how = 'left').rename(columns={'구매금액':'1회평균구매금액'})
df_member2
# Out:
#              회원번호 조합원상태        주소 성별    연령 배송서비스신청여부 모바일알람여부 Gold_member  \
# 0      1000012800  정상회원  수지구-풍덕천동  여  58.0       미신청     미수신      normal
# 1      1000103744  정상회원   처인구-고림동  여  34.0       미신청     미수신      normal
# 2      1000122304  정상회원     광주-기타  여  38.0       미신청     미수신      normal
# 3      1000163136  정상회원   수지구-동천동  여  73.0       미신청     미수신      normal
# 4      1000281920  정상회원  수지구-풍덕천동  여  42.0        신청     미수신      normal
# ...           ...   ...       ... ..   ...       ...     ...         ...
# 11550   999682432    탈퇴   수지구-동천동  여  47.0       미신청     미수신      normal
# 11551   999721408  정상회원   수지구-동천동  여  43.0       미신청     미수신      normal
# 11552   999738112  정상회원   수지구-성복동  여  67.0       미신청     미수신      normal
# 11553   999754816  정상회원   수지구-상현동  여  44.0        신청     미수신      normal
# 11554    99995712  정상회원   수지구-상현동  여  66.0       미신청     미수신      normal
#
#        구매횟수    총구매금액      1회평균구매금액
# 0         1     7658   7658.000000
# 1         1    36948  36948.000000
# 2        15   142831   9522.066667
# 3         4   138892  34723.000000
# 4        28   592543  21162.250000
# ...     ...      ...           ...
# 11550     1    39246  39246.000000
# 11551     3    39820  13273.333333
# 11552     9   152960  16995.555556
# 11553    21   641334  30539.714286
# 11554    40  1848650  46216.250000
#
# [11555 rows x 11 columns]

# %%
p1 = df.pivot_table(index = ['회원번호','공급일자'], values='label', aggfunc='sum').reset_index()
p2 = p1.pivot_table(index = '회원번호', values='label', aggfunc='mean').reset_index()
df_member2 = pd.merge(df_member2, p2, on='회원번호', how = 'left').rename(columns={'label':'1회평균구매수량'})
df_member2
# Out:
#              회원번호 조합원상태        주소 성별    연령 배송서비스신청여부 모바일알람여부 Gold_member  \
# 0      1000012800  정상회원  수지구-풍덕천동  여  58.0       미신청     미수신      normal
# 1      1000103744  정상회원   처인구-고림동  여  34.0       미신청     미수신      normal
# 2      1000122304  정상회원     광주-기타  여  38.0       미신청     미수신      normal
# 3      1000163136  정상회원   수지구-동천동  여  73.0       미신청     미수신      normal
# 4      1000281920  정상회원  수지구-풍덕천동  여  42.0        신청     미수신      normal
# ...           ...   ...       ... ..   ...       ...     ...         ...
# 11550   999682432    탈퇴   수지구-동천동  여  47.0       미신청     미수신      normal
# 11551   999721408  정상회원   수지구-동천동  여  43.0       미신청     미수신      normal
# 11552   999738112  정상회원   수지구-성복동  여  67.0       미신청     미수신      normal
# 11553   999754816  정상회원   수지구-상현동  여  44.0        신청     미수신      normal
# 11554    99995712  정상회원   수지구-상현동  여  66.0       미신청     미수신      normal
#
#        구매횟수    총구매금액      1회평균구매금액  1회평균구매수량
# 0         1     7658   7658.000000  1.000000
# 1         1    36948  36948.000000  6.000000
# 2        15   142831   9522.066667  1.466667
# 3         4   138892  34723.000000  2.000000
# 4        28   592543  21162.250000  1.607143
# ...     ...      ...           ...       ...
# 11550     1    39246  39246.000000  2.000000
# 11551     3    39820  13273.333333  1.000000
# 11552     9   152960  16995.555556  1.666667
# 11553    21   641334  30539.714286  2.285714
# 11554    40  1848650  46216.250000  2.250000
#
# [11555 rows x 12 columns]

# %%
df_member2.rename(columns={'구매횟수':'총구매횟수'}, inplace=True)

# %% [markdown]
# # 회원서비스 신청에 따른 ['총구매금액','총구매횟수','평균구매금액','평균구매횟수'] 비교

# %%
plt.pie(df_member2['배송서비스신청여부'].value_counts(), labels=df_member2['배송서비스신청여부'].value_counts().index, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x798d9abeb910>,
#   <matplotlib.patches.Wedge at 0x798d9abeaaa0>],
#  [Text(-1.0560681982374385, 0.30776608109330467, '미신청'),
#   Text(1.056068191033653, -0.30776610581236513, '신청')],
#  [Text(-0.5760371990386027, 0.16787240786907526, '91.0%'),
#   Text(0.5760371951092652, -0.16787242135219912, '9.0%')])

# %%
plt.pie(df_member2['모바일알람여부'].value_counts(), labels=df_member2['모바일알람여부'].value_counts().index, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x798d9aad3a60>,
#   <matplotlib.patches.Wedge at 0x798d9aad3940>],
#  [Text(-1.0670877092570354, 0.2670651994412089, '미수신'),
#   Text(1.06708769675481, -0.26706524939519005, '수신')],
#  [Text(-0.5820478414129284, 0.1456719269679321, '92.2%'),
#   Text(0.5820478345935326, -0.14567195421555817, '7.8%')])

# %% [markdown]
# ##### 배송서비스 신청여부

# %%
# 평균계산
p1 = df_member2.pivot_table(index = '배송서비스신청여부',
                            values=['총구매횟수','총구매금액','1회평균구매금액','1회평균구매수량'], aggfunc='mean').reset_index()
p1
# Out:
#   배송서비스신청여부      1회평균구매금액  1회평균구매수량          총구매금액      총구매횟수
# 0       미신청  20666.396832  1.738551  248348.022736  11.752854
# 1        신청  28904.800497  2.348343  617950.151486  23.008629

# %%
p_col = ['총구매횟수','총구매금액','1회평균구매금액','1회평균구매수량']

# %%
plt.figure(figsize=(13,10))
for index,i in enumerate(p_col):
  plt.subplot(2,2,index+1)
  sns.barplot(data = p1, x = '배송서비스신청여부', y = i, palette='Greens')
  plt.title(i)
plt.show()

# %%
# 합으로 계산
p1 = df_member2.pivot_table(index = '배송서비스신청여부',
                            values=['총구매횟수','총구매금액','1회평균구매금액','1회평균구매수량'], aggfunc='median').reset_index()
p1
# Out:
#   배송서비스신청여부      1회평균구매금액  1회평균구매수량   총구매금액  총구매횟수
# 0       미신청  16218.163636  1.555556   76529      4
# 1        신청  25891.714286  2.200000  572063     23

# %%
plt.figure(figsize=(13,10))
for index,i in enumerate(p_col):
  plt.subplot(2,2,index+1)
  sns.barplot(data = p1, x = '배송서비스신청여부', y = i, palette='Greens')
  plt.title(i)
plt.show()

# %% [markdown]
# ##### 모바일 알람여부

# %%
# 평균계산
p2 = df_member2.pivot_table(index = '모바일알람여부', values=['총구매횟수','총구매금액','1회평균구매금액','1회평균구매수량'], aggfunc='mean').reset_index()
p2
# Out:
#   모바일알람여부      1회평균구매금액  1회평균구매수량          총구매금액      총구매횟수
# 0     미수신  21360.213354  1.787557  228025.293532  10.381301
# 1      수신  21998.356498  1.864889  915746.087583  40.966741

# %%
plt.figure(figsize=(13,10))
for index,i in enumerate(p_col):
  plt.subplot(2,2,index+1)
  sns.barplot(data = p2, x = '모바일알람여부', y = i, palette='Greens')
  plt.title(i)
plt.show()

# %%
# 합으로 계산
p2 = df_member2.pivot_table(index = '모바일알람여부', values=['총구매횟수','총구매금액','1회평균구매금액','1회평균구매수량'], aggfunc='sum').reset_index()
plt.figure(figsize=(13,10))
for index,i in enumerate(p_col):
  plt.subplot(2,2,index+1)
  sns.barplot(data = p2, x = '모바일알람여부', y = i, palette='Greens')
  plt.title(i)
plt.show()

# %% [markdown]
# # 회원서비스 고객과 아닌 고객의 월별 구매금액 차이

# %% [markdown]
# ##### 모바일알람

# %%
cond1 = df_member2['모바일알람여부'] == '수신'
cond2 = df_member2['배송서비스신청여부'] == '신청'
df_member2[cond1]
# Out:
#              회원번호 조합원상태        주소 성별    연령 배송서비스신청여부 모바일알람여부 Gold_member  \
# 35     1004617536  정상회원   수지구-죽전동  여  41.0       미신청      수신      normal
# 50     1005669888  정상회원   수지구-상현동  여  63.0       미신청      수신      normal
# 81     1007817280  정상회원  수지구-풍덕천동  여  48.0       미신청      수신      normal
# 82     1007820992  정상회원  수지구-풍덕천동  여  48.0       미신청      수신      normal
# 92     1008511424  정상회원   수지구-동천동  여  46.0       미신청      수신      normal
# ...           ...   ...       ... ..   ...       ...     ...         ...
# 11490   993938112  정상회원   수지구-신봉동  여  47.0       미신청      수신         VIP
# 11492   994348288  정상회원  수지구-풍덕천동  여  32.0       미신청      수신         VIP
# 11512    99763712  정상회원   수지구-신봉동  여  48.0       미신청      수신         VIP
# 11532   999068096  정상회원   기흥구-신갈동  여  43.0       미신청      수신      normal
# 11536   999227712  정상회원   수지구-상현동  여  40.0       미신청      수신         VIP
#
#        총구매횟수    총구매금액      1회평균구매금액  1회평균구매수량
# 35         1    27951  27951.000000  2.000000
# 50         2    57433  28716.500000  1.000000
# 81        60  1501914  25031.900000  2.650000
# 82        54   804440  14897.037037  1.685185
# 92        12   217477  18123.083333  2.083333
# ...      ...      ...           ...       ...
# 11490    118  4799085  40670.211864  3.169492
# 11492    138  2260752  16382.260870  2.101449
# 11512     88  1752355  19913.125000  1.886364
# 11532      1     3733   3733.000000  1.000000
# 11536    100  1881205  18812.050000  1.940000
#
# [902 rows x 12 columns]

# %%
df['공급일자2'] = pd.to_datetime(df['공급일자'])
df['월'] = df['공급일자2'].dt.month

# %%
alam_yes = df[df['회원번호'].isin(df_member.loc[cond1]['회원번호'])]
alam_yes.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()
# Out:
#     월      구매금액
# 0   1  84610224
# 1   2  79139040
# 2   3  80578206
# 3   4  78261886
# 4   5  82866844
# 5   6  81739076
# 6   7  96505586
# 7   8  87730171
# 8   9  82113941
# 9  10  72457997

# %%
month_list = alam_yes['월'].value_counts().index.sort_values()

# %%
plt.plot(alam_yes.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()['월'],alam_yes.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()['구매금액'])

# %%
alam_yes = df[df['회원번호'].isin(df_member.loc[cond1]['회원번호'])]
alam_yes.pivot_table(index = '월', values = 'label', aggfunc='sum').reset_index()
# Out:
#     월  label
# 0   1   7948
# 1   2   6613
# 2   3   7609
# 3   4   7484
# 4   5   7844
# 5   6   8233
# 6   7   8869
# 7   8   8126
# 8   9   7208
# 9  10   6851

# %%
plt.plot(alam_yes.pivot_table(index = '월', values = 'label', aggfunc='sum').reset_index()['월'],alam_yes.pivot_table(index = '월', values = 'label', aggfunc='sum').reset_index()['label'])

# %%
alam_yes = df[df['회원번호'].isin(df_member.loc[cond1]['회원번호'])]
alam_yes.pivot_table(index = '월', values = '구매금액', aggfunc='median').reset_index()
# Out:
#     월  구매금액
# 0   1  7275
# 1   2  7466
# 2   3  7179
# 3   4  7275
# 4   5  7275
# 5   6  7083
# 6   7  7083
# 7   8  7275
# 8   9  7849
# 9  10  7466

# %%
plt.plot(alam_yes.pivot_table(index = '월', values = '구매금액', aggfunc='median').reset_index()['월'],alam_yes.pivot_table(index = '월', values = '구매금액', aggfunc='median').reset_index()['구매금액'])

# %%
plt.plot(alam_yes.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()['월'],alam_yes.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()['구매금액'])

# %%
alam_yes.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()
for i in month_list:
  df_nyang = alam_yes[alam_yes['월'] == i]
  print(st.normaltest(df_nyang['구매금액']))
# Out:
# NormaltestResult(statistic=16029.91563031541, pvalue=0.0)
# NormaltestResult(statistic=9729.845682034034, pvalue=0.0)
# NormaltestResult(statistic=9697.534639334817, pvalue=0.0)
# NormaltestResult(statistic=7155.138579210781, pvalue=0.0)
# NormaltestResult(statistic=6314.125855484504, pvalue=0.0)
# NormaltestResult(statistic=4728.780063758241, pvalue=0.0)
# NormaltestResult(statistic=26569.148540838258, pvalue=0.0)
# NormaltestResult(statistic=8736.880188116438, pvalue=0.0)
# NormaltestResult(statistic=6909.168788268256, pvalue=0.0)
# NormaltestResult(statistic=12132.811211930999, pvalue=0.0)

# %%
for i in month_list:
  df_nyang = alam_yes[alam_yes['월'] == i]
  for j in month_list:
    if i != j:
      df_nyong = alam_yes[alam_yes['월'] == j]
      if st.ranksums(df_nyang['구매금액'], df_nyong['구매금액'])[1] < 0.05:
        print(f'{i}와 {j}의 중앙값은 다르다')
        print(st.ranksums(df_nyang['구매금액'], df_nyong['구매금액']))
# Out:
# 1와 2의 중앙값은 다르다
# RanksumsResult(statistic=-4.211014714408301, pvalue=2.542261848688521e-05)
# 1와 4의 중앙값은 다르다
# RanksumsResult(statistic=2.084620193563803, pvalue=0.03710378999587076)
# 1와 5의 중앙값은 다르다
# RanksumsResult(statistic=3.2270536892024455, pvalue=0.0012507198977443497)
# 1와 6의 중앙값은 다르다
# RanksumsResult(statistic=6.636780914445841, pvalue=3.2060762292158245e-11)
# 1와 7의 중앙값은 다르다
# RanksumsResult(statistic=3.6632775931195343, pvalue=0.0002490084292456231)
# 1와 8의 중앙값은 다르다
# RanksumsResult(statistic=2.007347041478315, pvalue=0.044712723528512674)
# 2와 1의 중앙값은 다르다
# RanksumsResult(statistic=4.211014714408301, pvalue=2.542261848688521e-05)
# 2와 3의 중앙값은 다르다
# RanksumsResult(statistic=5.233755727689329, pvalue=1.6609993236068598e-07)
# 2와 4의 중앙값은 다르다
# RanksumsResult(statistic=6.0654264508226285, pvalue=1.316039853998252e-09)
# 2와 5의 중앙값은 다르다
# RanksumsResult(statistic=7.029547056996198, pvalue=2.0720506474022593e-12)
# 2와 6의 중앙값은 다르다
# RanksumsResult(statistic=10.209808587416711, pvalue=1.7921803372276454e-24)
# 2와 7의 중앙값은 다르다
# RanksumsResult(statistic=7.476995038742964, pvalue=7.604128436895004e-14)
# 2와 8의 중앙값은 다르다
# RanksumsResult(statistic=5.810451898619981, pvalue=6.2304432787436065e-09)
# 2와 9의 중앙값은 다르다
# RanksumsResult(statistic=2.396676334490233, pvalue=0.016544530739600657)
# 2와 10의 중앙값은 다르다
# RanksumsResult(statistic=5.550310000875199, pvalue=2.851634801668246e-08)
# 3와 2의 중앙값은 다르다
# RanksumsResult(statistic=-5.233755727689329, pvalue=1.6609993236068598e-07)
# 3와 6의 중앙값은 다르다
# RanksumsResult(statistic=5.252631832310723, pvalue=1.4994106815039693e-07)
# 3와 7의 중앙값은 다르다
# RanksumsResult(statistic=2.2110135694651545, pvalue=0.02703489740625509)
# 3와 9의 중앙값은 다르다
# RanksumsResult(statistic=-2.565437661346145, pvalue=0.010304573597580568)
# 4와 1의 중앙값은 다르다
# RanksumsResult(statistic=-2.084620193563803, pvalue=0.03710378999587076)
# 4와 2의 중앙값은 다르다
# RanksumsResult(statistic=-6.0654264508226285, pvalue=1.316039853998252e-09)
# 4와 6의 중앙값은 다르다
# RanksumsResult(statistic=4.367088449300275, pvalue=1.2591374710596671e-05)
# 4와 9의 중앙값은 다르다
# RanksumsResult(statistic=-3.347173417923831, pvalue=0.0008164012038857294)
# 5와 1의 중앙값은 다르다
# RanksumsResult(statistic=-3.2270536892024455, pvalue=0.0012507198977443497)
# 5와 2의 중앙값은 다르다
# RanksumsResult(statistic=-7.029547056996198, pvalue=2.0720506474022593e-12)
# 5와 6의 중앙값은 다르다
# RanksumsResult(statistic=3.5120280993608337, pvalue=0.00044470097824910723)
# 5와 9의 중앙값은 다르다
# RanksumsResult(statistic=-4.201934686050375, pvalue=2.6464349629488965e-05)
# 6와 1의 중앙값은 다르다
# RanksumsResult(statistic=-6.636780914445841, pvalue=3.2060762292158245e-11)
# 6와 2의 중앙값은 다르다
# RanksumsResult(statistic=-10.209808587416711, pvalue=1.7921803372276454e-24)
# 6와 3의 중앙값은 다르다
# RanksumsResult(statistic=-5.252631832310723, pvalue=1.4994106815039693e-07)
# 6와 4의 중앙값은 다르다
# RanksumsResult(statistic=-4.367088449300275, pvalue=1.2591374710596671e-05)
# 6와 5의 중앙값은 다르다
# RanksumsResult(statistic=-3.5120280993608337, pvalue=0.00044470097824910723)
# 6와 7의 중앙값은 다르다
# RanksumsResult(statistic=-3.2148275199543717, pvalue=0.0013052292232829466)
# 6와 8의 중앙값은 다르다
# RanksumsResult(statistic=-4.471011883204592, pvalue=7.785037207241788e-06)
# 6와 9의 중앙값은 다르다
# RanksumsResult(statistic=-7.664340128933713, pvalue=1.7975295449363373e-14)
# 6와 10의 중앙값은 다르다
# RanksumsResult(statistic=-4.425628219730871, pvalue=9.616201786264438e-06)
# 7와 1의 중앙값은 다르다
# RanksumsResult(statistic=-3.6632775931195343, pvalue=0.0002490084292456231)
# 7와 2의 중앙값은 다르다
# RanksumsResult(statistic=-7.476995038742964, pvalue=7.604128436895004e-14)
# 7와 3의 중앙값은 다르다
# RanksumsResult(statistic=-2.2110135694651545, pvalue=0.02703489740625509)
# 7와 6의 중앙값은 다르다
# RanksumsResult(statistic=3.2148275199543717, pvalue=0.0013052292232829466)
# 7와 9의 중앙값은 다르다
# RanksumsResult(statistic=-4.7211066272142785, pvalue=2.3456492465349294e-06)
# 8와 1의 중앙값은 다르다
# RanksumsResult(statistic=-2.007347041478315, pvalue=0.044712723528512674)
# 8와 2의 중앙값은 다르다
# RanksumsResult(statistic=-5.810451898619981, pvalue=6.2304432787436065e-09)
# 8와 6의 중앙값은 다르다
# RanksumsResult(statistic=4.471011883204592, pvalue=7.785037207241788e-06)
# 8와 9의 중앙값은 다르다
# RanksumsResult(statistic=-3.078471863768396, pvalue=0.002080651762219964)
# 9와 2의 중앙값은 다르다
# RanksumsResult(statistic=-2.396676334490233, pvalue=0.016544530739600657)
# 9와 3의 중앙값은 다르다
# RanksumsResult(statistic=2.565437661346145, pvalue=0.010304573597580568)
# 9와 4의 중앙값은 다르다
# RanksumsResult(statistic=3.347173417923831, pvalue=0.0008164012038857294)
# 9와 5의 중앙값은 다르다
# RanksumsResult(statistic=4.201934686050375, pvalue=2.6464349629488965e-05)
# 9와 6의 중앙값은 다르다
# RanksumsResult(statistic=7.664340128933713, pvalue=1.7975295449363373e-14)
# 9와 7의 중앙값은 다르다
# RanksumsResult(statistic=4.7211066272142785, pvalue=2.3456492465349294e-06)
# 9와 8의 중앙값은 다르다
# RanksumsResult(statistic=3.078471863768396, pvalue=0.002080651762219964)
# 9와 10의 중앙값은 다르다
# RanksumsResult(statistic=3.0523468684096646, pvalue=0.002270595504603646)
# 10와 2의 중앙값은 다르다
# RanksumsResult(statistic=-5.550310000875199, pvalue=2.851634801668246e-08)
# 10와 6의 중앙값은 다르다
# RanksumsResult(statistic=4.425628219730871, pvalue=9.616201786264438e-06)
# 10와 9의 중앙값은 다르다
# RanksumsResult(statistic=-3.0523468684096646, pvalue=0.002270595504603646)

# %%
alam_no = df[df['회원번호'].isin(df_member.loc[~cond1]['회원번호'])]
alam_no.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()
# Out:
#     월       구매금액
# 0   1  256244486
# 1   2  256378615
# 2   3  238123060
# 3   4  229039081
# 4   5  236832699
# 5   6  225733621
# 6   7  263305833
# 7   8  246220461
# 8   9  254756105
# 9  10  222519491

# %%
plt.plot(alam_no.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()['월'],alam_no.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()['구매금액'])

# %%
df.pivot_table(index = '월', values = 'label', aggfunc='sum').reset_index()
# Out:
#     월  label
# 0   1  31411
# 1   2  27498
# 2   3  29711
# 3   4  29131
# 4   5  29532
# 5   6  29566
# 6   7  32172
# 7   8  30813
# 8   9  27971
# 9  10  26840

# %%
# plt.plot(alam_no.pivot_table(index = '월', values = 'label', aggfunc='sum').reset_index()['월'],alam_no.pivot_table(index = '월', values = 'label', aggfunc='sum').reset_index()['구매금액'])

# %% [markdown]
# ##### 배송서비스

# %%
deli_yes = df[df['회원번호'].isin(df_member.loc[cond2]['회원번호'])]
deli_yes.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()
# Out:
#     월      구매금액
# 0   1  68472853
# 1   2  66593224
# 2   3  64214516
# 3   4  61437864
# 4   5  62105758
# 5   6  60070792
# 6   7  72636407
# 7   8  65938045
# 8   9  66621825
# 9  10  56430724

# %%
plt.plot(deli_yes.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()['월'],deli_yes.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()['구매금액'])

# %%
deli_no = df[df['회원번호'].isin(df_member.loc[~cond2]['회원번호'])]
deli_no.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()
# Out:
#     월       구매금액
# 0   1  272381857
# 1   2  268924431
# 2   3  254486750
# 3   4  245863103
# 4   5  257593785
# 5   6  247401905
# 6   7  287175012
# 7   8  268012587
# 8   9  270248221
# 9  10  238546764

# %%
plt.plot(deli_no.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()['월'],deli_no.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()['구매금액'])

# %%
df.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()
# Out:
#     월       구매금액
# 0   1  340854710
# 1   2  335517655
# 2   3  318701266
# 3   4  307300967
# 4   5  319699543
# 5   6  307472697
# 6   7  359811419
# 7   8  333950632
# 8   9  336870046
# 9  10  294977488

# %%
plt.plot(df.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()['월'],df.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()['구매금액'])

# %% [markdown]
# # 연령대, 월별 최빈값

# %%
def age_classify(x):
    if pd.isnull(x):
        return x
    elif x >= 100:
        return '90대'
    else:
        return str(x)[0] + '0대'

df_member2['연령대'] = df_member2['연령'].apply(age_classify)
df_member2['연령대'].value_counts()
# Out:
# 연령대
# 40대    4480
# 50대    2546
# 30대    2137
# 60대    1455
# 70대     736
# 80대     136
# 20대      52
# 90대      10
# 10대       1
# Name: count, dtype: int64

# %%
for i in df_member2['연령대'].unique():
  cond1 = df_member2['연령대'] == i
  mem_id = df_member2[cond1]['회원번호']
  cond2 = df['회원번호'].isin(mem_id)
  df_temp = df[cond2]
  print(i)
  print(df_temp.물품중분류.value_counts().index[:3])
  print(df_temp.물품소분류.value_counts().index[:10])
# Out:
# 50대
# Index(['두부/유부', '잎/줄기채소', '알'], dtype='object', name='물품중분류')
# Index(['두부', '유정란', '스낵', '콩나물', '우유/산양유', '양파', '오이', '김가공', '돼지(중량)', '멥쌀'], dtype='object', name='물품소분류')
# 30대
# Index(['과자', '음료', '두부/유부'], dtype='object', name='물품중분류')
# Index(['스낵', '두부', '유정란', '과즙', '우유/산양유', '김가공', '콩나물', '양파', '푸딩',
#        '식빵, 식사대용'],
#       dtype='object', name='물품소분류')
# 70대
# Index(['잎/줄기채소', '두부/유부', '알'], dtype='object', name='물품중분류')
# Index(['두부', '유정란', '콩나물', '스낵', '오이', '논지엠오유정란', '우유/산양유', '양파', '멥쌀', '당근'], dtype='object', name='물품소분류')
# 40대
# Index(['두부/유부', '알', '잎/줄기채소'], dtype='object', name='물품중분류')
# Index(['두부', '유정란', '스낵', '우유/산양유', '콩나물', '김가공', '과즙', '양파', '식빵, 식사대용',
#        '가래떡'],
#       dtype='object', name='물품소분류')
# 60대
# Index(['잎/줄기채소', '두부/유부', '알'], dtype='object', name='물품중분류')
# Index(['두부', '유정란', '스낵', '콩나물', '우유/산양유', '오이', '멥쌀', '양파', '김가공', '논지엠오유정란'], dtype='object', name='물품소분류')
# 80대
# Index(['두부/유부', '잎/줄기채소', '알'], dtype='object', name='물품중분류')
# Index(['두부', '유정란', '멥쌀', '우유/산양유', '콩나물', '논지엠오유정란', '오이', '양파', '스낵',
#        '식육추출가공'],
#       dtype='object', name='물품소분류')
# 20대
# Index(['두부/유부', '잎/줄기채소', '유제품'], dtype='object', name='물품중분류')
# Index(['두부', '우유/산양유', '스낵', '유정란', '양파', '오이', '식빵, 식사대용', '멥쌀', '애호박', '당근'], dtype='object', name='물품소분류')
# 90대
# Index(['유제품', '알', '과일'], dtype='object', name='물품중분류')
# Index(['우유/산양유', '유정란', '스낵', '두부', '사과', '냉동생선', '김가공', '논지엠오유정란', '딸기', '묵'], dtype='object', name='물품소분류')
# 10대
# Index(['과일', '잎/줄기채소', '유제품'], dtype='object', name='물품중분류')
# Index(['즉석떡', '무화과', '한우(냉장)', '김가공', '요구르트', '두부', '보리살림(냉장)', '냉동패류',
#        '완숙토마토', '양념가루'],
#       dtype='object', name='물품소분류')
# nan
# Index([], dtype='object', name='물품중분류')
# Index([], dtype='object', name='물품소분류')

# %%
for i in df['월'].unique():
  cond1 = df['월'] == i
  df_temp = df[cond1]
  print(i)
  print(df_temp.물품중분류.value_counts().index[:3])
  print(df_temp.물품소분류.value_counts().index[:10])
# Out:
# 1
# Index(['두부/유부', '알', '잎/줄기채소'], dtype='object', name='물품중분류')
# Index(['두부', '유정란', '스낵', '콩나물', '우유/산양유', '김가공', '대파', '양파', '가래떡', '시금치'], dtype='object', name='물품소분류')
# 2
# Index(['두부/유부', '알', '잎/줄기채소'], dtype='object', name='물품중분류')
# Index(['두부', '유정란', '스낵', '콩나물', '대파', '우유/산양유', '가래떡', '양파', '김가공', '시금치'], dtype='object', name='물품소분류')
# 3
# Index(['잎/줄기채소', '두부/유부', '알'], dtype='object', name='물품중분류')
# Index(['두부', '유정란', '스낵', '콩나물', '우유/산양유', '김가공', '양파', '과즙', '대파', '딸기'], dtype='object', name='물품소분류')
# 4
# Index(['잎/줄기채소', '두부/유부', '알'], dtype='object', name='물품중분류')
# Index(['두부', '유정란', '스낵', '우유/산양유', '콩나물', '과즙', '양파', '당근', '김가공', '미역/다시마'], dtype='object', name='물품소분류')
# 5
# Index(['잎/줄기채소', '두부/유부', '과자'], dtype='object', name='물품중분류')
# Index(['두부', '스낵', '유정란', '오이', '우유/산양유', '콩나물', '양파', '과즙', '당근', '중파'], dtype='object', name='물품소분류')
# 6
# Index(['두부/유부', '잎/줄기채소', '열매채소'], dtype='object', name='물품중분류')
# Index(['두부', '유정란', '스낵', '오이', '우유/산양유', '콩나물', '애호박', '김가공', '과즙', '중파'], dtype='object', name='물품소분류')
# 7
# Index(['열매채소', '두부/유부', '음료'], dtype='object', name='물품중분류')
# Index(['두부', '유정란', '스낵', '우유/산양유', '오이', '과즙', '콩나물', '김가공', '애호박', '간편조리면'], dtype='object', name='물품소분류')
# 8
# Index(['열매채소', '두부/유부', '알'], dtype='object', name='물품중분류')
# Index(['두부', '유정란', '스낵', '우유/산양유', '오이', '콩나물', '김가공', '식사대용/기타', '과즙', '가지'], dtype='object', name='물품소분류')
# 9
# Index(['두부/유부', '열매채소', '알'], dtype='object', name='물품중분류')
# Index(['두부', '유정란', '스낵', '콩나물', '우유/산양유', '김가공', '멥쌀', '과즙', '송편', '냉동생선'], dtype='object', name='물품소분류')
# 10
# Index(['두부/유부', '알', '잎/줄기채소'], dtype='object', name='물품중분류')
# Index(['두부', '유정란', '스낵', '콩나물', '우유/산양유', '오이', '멥쌀', '김가공', '논지엠오유정란', '과즙'], dtype='object', name='물품소분류')

# %% [markdown]
# # 연령대별 구매차이

# %%
p1 = df_member2.pivot_table(index = '연령대' , values= ['총구매횟수',	'총구매금액',	'1회평균구매금액',	'1회평균구매수량'], aggfunc='sum').reset_index()

# %%
plt.figure(figsize=(13,7))
for index,i in enumerate(p_col):
  plt.subplot(2,2,index+1)
  sns.barplot(data = p1, x = '연령대', y = i, palette='Greens')
  plt.title(i)
plt.show()

# %% [markdown]
# # 연령대별 회원서비스 신청상황

# %%
df_member2[df_member2['모바일알람여부'] =='수신'].pivot_table(index = '연령대' , values= ['모바일알람여부'], aggfunc='count')
# Out:
#      모바일알람여부
# 연령대
# 30대      167
# 40대      407
# 50대      250
# 60대       52
# 70대       20
# 80대        5
# 90대        1

# %%
df_member2[df_member2['배송서비스신청여부'] =='신청'].pivot_table(index = '연령대' , values= ['배송서비스신청여부'], aggfunc='count')
# Out:
#      배송서비스신청여부
# 연령대
# 20대          6
# 30대        131
# 40대        398
# 50대        261
# 60대        164
# 70대         72
# 80대         11

# %% [markdown]
# # 월별 매출

# %%
cond1 = df_member2['모바일알람여부'] == '수신'
df_list = df_member2[cond1]['회원번호']
df_list2 = df_member2[~cond1]['회원번호']
df_mobile_yes = df[df['회원번호'].isin(df_list)]
df_mobile_no = df[df['회원번호'].isin(df_list2)]
p1 = df_mobile_yes.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()
p2 = df_mobile_no.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()
plt.subplot(1,2,1)
plt.plot(p1['월'],p1['구매금액'],label='수신')
plt.subplot(1,2,2)
plt.plot(p2['월'],p2['구매금액'],label='미수신')
plt.legend()
plt.show()

# %%
cond1 = df_member2['배송서비스신청여부'] == '신청'
df_list = df_member2[cond1]['회원번호']
df_list2 = df_member2[~cond1]['회원번호']
df_mobile_yes = df[df['회원번호'].isin(df_list)]
df_mobile_no = df[df['회원번호'].isin(df_list2)]
p1 = df_mobile_yes.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()
p2 = df_mobile_no.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()
plt.subplot(1,2,1)
plt.plot(p1['월'],p1['구매금액'],label='신청')
plt.subplot(1,2,2)
plt.plot(p2['월'],p2['구매금액'],label='미신청')
plt.legend()
plt.show()

# %% [markdown]
# # 연령대별 월별 구매횟수, 금액

# %%
# Out:
# array(['50대', '30대', '70대', '40대', '60대', '80대', '20대', '90대', '10대', nan],
#       dtype=object)

# %%
plt.figure(figsize=(20,10))
for idx,i in enumerate(df_member2['연령대'].unique()[:-1]):
  cond1 = df_member2['연령대'] == i
  mem_id = df_member2[cond1]['회원번호']
  cond2 = df['회원번호'].isin(mem_id)
  df_temp = df[cond2]
  p1 = df_temp.pivot_table(index = ['회원번호','공급일자'], values = 'label', aggfunc='min').reset_index()
  p1['공급월'] = pd.to_datetime(p1['공급일자']).dt.month
  p2 = p1.pivot_table(index = ['회원번호','공급월'], values = 'label', aggfunc='sum').reset_index()
  p3 = p2.pivot_table(index = '공급월', values = 'label', aggfunc='sum').reset_index()
  plt.subplot(2,5,idx+1)
  sns.barplot(p3,x='공급월',y = 'label')
  plt.title(i+'월별 구매금액')

plt.show()

# %%
p1 = df_temp.pivot_table(index = ['회원번호','공급일자'], values = 'label', aggfunc='min').reset_index()
p1['공급월'] = pd.to_datetime(p1['공급일자']).dt.month
p2 = p1.pivot_table(index = ['회원번호','공급월'], values = 'label', aggfunc='sum').reset_index()
# Out:
#               공급일자        회원번호 조합원상태  물품대분류 물품중분류     물품소분류  \
# 0       2022-01-01   272369856  정상회원     과실    과일        사과
# 1       2022-01-01  1476143616  정상회원     간식     빵  식빵, 식사대용
# 2       2022-01-01   743192512  정상회원     채소  양념채소        생강
# 3       2022-01-01   176912064  정상회원    축산물   유제품    우유/산양유
# 4       2022-01-01    87592064  정상회원  양념/가루    가루      양념가루
# ...            ...         ...   ...    ...   ...       ...
# 294640  2022-10-30  1110819712  정상회원     채소  뿌리채소         무
# 294641  2022-10-30  1517953728  정상회원     채소  양념채소        쪽파
# 294642  2022-10-30   713691392  정상회원     반찬   밑반찬        조림
# 294643  2022-10-30   247926336  정상회원     간식     빵     건강곡물빵
# 294644  2022-10-30   748292800  정상회원     채소  뿌리채소         무
#
#                         물품명  구매수량   구매금액 구매매장 반품_원거래일자   구매시각  label  \
# 0               사과/유(1.5kg)   1.0  22207  매장C      NaN  10:04      1
# 1           아침빵(240g/8개)/매장   1.0   4403  매장C      NaN  10:09      1
# 2                  생강(300g)   1.0   7083  매장C      NaN  10:12      1
# 3       유기농저지방우유(종이팩/900ml)   1.0   7849  매장C      NaN  10:23      1
# 4             카레(매운맛: 100g)   3.0  15507  매장C      NaN  10:29      1
# ...                     ...   ...    ...  ...      ...    ...    ...
# 294640         무(0.7~1kg미만)   1.0   2680  매장A      NaN  13:26      1
# 294641             쪽파(500g)   1.0   4212  매장A      NaN  10:58      1
# 294642       우엉조림(반찬용/150g)   1.0   7658  매장A      NaN  14:36      1
# 294643       감자바게트(180g)/매장   1.0   5169  매장A      NaN  16:23      1
# 294644             무(1kg이상)   1.0   3829  매장A      NaN  16:51      1
#
#             공급일자2   월
# 0      2022-01-01   1
# 1      2022-01-01   1
# 2      2022-01-01   1
# 3      2022-01-01   1
# 4      2022-01-01   1
# ...           ...  ..
# 294640 2022-10-30  10
# 294641 2022-10-30  10
# 294642 2022-10-30  10
# 294643 2022-10-30  10
# 294644 2022-10-30  10
#
# [294645 rows x 15 columns]

# %%
m1 = pd.merge(df,df_member2[['회원번호','연령대']], on='회원번호', how = 'left')
m1['월'] = m1['월'].astype(int)

# %%
p_x = m1.pivot_table(index=['회원번호','공급일자'], values=['label','월'],aggfunc='min').reset_index()
p_x2 = p_x.pivot_table(index=['회원번호','월'], values=['label'],aggfunc='sum').reset_index()

# %%
m2 = pd.merge(p_x2,df_member2[['연령대','회원번호']], on='회원번호', how = 'left')

# %%
p3 = m2.pivot_table(index = ['연령대','월'], values = 'label', aggfunc='sum').reset_index()

# %%
plt.figure(figsize=(20,10))
for idx,i in enumerate(df_member2['연령대'].unique()[:-1]):
  cond1 = df_member2['연령대'] == i
  mem_id = df_member2[cond1]['회원번호']
  cond2 = df['회원번호'].isin(mem_id)
  df_temp = df[cond2]
  p1 = df_temp.pivot_table(index = '월', values = '구매금액', aggfunc='sum').reset_index()
  plt.subplot(2,5,idx+1)
  plt.plot(p1['월'],p1['구매금액'], label = '구매금액')
  plt.title(i+'월별 구매금액')
  plt.legend()

plt.show()

# %%
plt.figure(figsize=(20,10))
for idx,i in enumerate(df_member2['연령대'].unique()):
  plt.subplot(2,5,idx+1)
  plt.plot(p3[p3['연령대'] == i]['월'],p3[p3['연령대'] == i]['label'])
  plt.title(i)
plt.show()

# %% [markdown]
# # RFM을 기준으로 고객 등급과 회원서비스 간의 상관관계
