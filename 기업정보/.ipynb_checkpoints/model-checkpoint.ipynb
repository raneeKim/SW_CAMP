# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, RobustScaler, OneHotEncoder
import xgboost as xgb
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error, r2_score

# %%
# 데이터 로드
#df = pd.read_csv('/Users/smooooth/Downloads/이상치모두제거.csv', index_col=0)
#df.drop(columns=['연차', 'BusinessNum'], inplace=True)

# %%
# 데이터로드
path = 'C:/Users/MSI/Desktop/study/Data/기업정보/'
df = pd.read_csv(path + '원자료변수_이상치모두제거.csv', index_col=0)
df.drop(columns=['BusinessNum'], inplace=True)

# %%
df2 = pd.read_csv(path + '원자료변수_재무통합_전처리.csv', index_col=0)
df2 = df2.loc[df2['stYear']==2021.0]
df2.drop(columns=['BusinessNum'], inplace=True)
df2 = df2.dropna(subset=['매출액', '영업이익', '당기순이익(손실)'])

# %%
df.columns
# Out:
# Index(['stYear', '당기순이익(손실)', '매출액', '영업이익', '유동부채', '유동자산', '자기자본', '총자산',
#        '매출총이익', '매출원가', '매출채권', '종업원수', '대분류코드', '항목명', '성장단계', '주소'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['stYear', '당기순이익(손실)', '매출액', '영업이익', '유동부채', '유동자산', '자기자본', '총자산',
#        '매출총이익', '매출원가', '매출채권', '종업원수', '대분류코드', '항목명', '성장단계', '주소'],
#       dtype='object')

# %%
cond1 = df['stYear'] == 2021.0
df3 = df.loc[~cond1]


df3 = df3.dropna(subset=['매출액', '영업이익', '당기순이익(손실)'])

# 카테고리와 숫자형 변수 리스트 생성
category_list = df3.select_dtypes(include=['object']).columns
numeric_list = df3.select_dtypes(include=[np.number]).columns.drop(['매출액', '영업이익', '당기순이익(손실)'])

# 스케일러 목록
scalers = [StandardScaler(), RobustScaler()]

# 모델 목록
models = {
    'XGBoost': xgb.XGBRegressor(),
    'ElasticNet' : ElasticNet(),
    'GradientBoostingRegressor': GradientBoostingRegressor()
}

# 타겟 변수 목록
targets = ['매출액', '영업이익', '당기순이익(손실)']

results = []
results2 = []

for target in targets:
    Y = df3[target]
    X = df3.drop(columns=target)
    
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=42)
    
    for scaler in scalers:
        numeric_pipe = make_pipeline(SimpleImputer(strategy='median'), scaler)
        category_pipe = make_pipeline(SimpleImputer(strategy='most_frequent'), OneHotEncoder(handle_unknown='ignore'))
        
        prepro_pipe = make_column_transformer((numeric_pipe, numeric_list),
                                            (category_pipe, category_list))
        
        for model_name, model in models.items():
            model_pipe = make_pipeline(prepro_pipe, model)
            
            model_pipe.fit(X_train, Y_train)
            
            Y_train_pred = model_pipe.predict(X_train)
            Y_test_pred = model_pipe.predict(X_test)
            
            train_mse = mean_squared_error(Y_train, Y_train_pred)
            test_mse = mean_squared_error(Y_test, Y_test_pred)
            train_r2 = r2_score(Y_train, Y_train_pred)
            test_r2 = r2_score(Y_test, Y_test_pred)
            
            results.append({
                'target': target,
                'scaler': scaler.__class__.__name__,
                'model': model_name,
                'train_mse': train_mse,
                'test_mse': test_mse,
                'train_r2': train_r2,
                'test_r2': test_r2
            })

            # df2에 대한 성능 평가
            if target in df2.columns:
                X_df2 = df2.drop(columns=target)
                Y_df2 = df2[target]
                Y_df2_pred = model_pipe.predict(X_df2)
                df2_mse = mean_squared_error(Y_df2, Y_df2_pred)
                df2_r2 = r2_score(Y_df2, Y_df2_pred)


                results2.append({
                    'target': target,
                    'scaler': scaler.__class__.__name__,
                    'model': model_name,
                    'df2_mse': df2_mse,
                    'df2_r2': train_r2
                })

# 결과를 데이터프레임으로 변환
results_df = pd.DataFrame(results)
results2_df = pd.DataFrame(results2)

# int형으로 변환
results_df['train_mse'] = results_df['train_mse'].apply(lambda x: int(float(x)))
results_df['test_mse'] = results_df['test_mse'].apply(lambda x: int(float(x)))
results2_df['df2_mse'] = results2_df['df2_mse'].apply(lambda x: int(float(x)))

# %%
# 파생변수
# results_df
# Out:
#        target          scaler                      model      train_mse  \
# 0         매출액  StandardScaler                    XGBoost   325679771972
# 1         매출액  StandardScaler                 ElasticNet  4797079760252
# 2         매출액  StandardScaler  GradientBoostingRegressor  2466627963942
# 3         매출액    RobustScaler                    XGBoost   331649322390
# 4         매출액    RobustScaler                 ElasticNet  4706766581338
# 5         매출액    RobustScaler  GradientBoostingRegressor  2466627963942
# 6        영업이익  StandardScaler                    XGBoost     1175861603
# 7        영업이익  StandardScaler                 ElasticNet     9799229720
# 8        영업이익  StandardScaler  GradientBoostingRegressor     6280306325
# 9        영업이익    RobustScaler                    XGBoost     1175861603
# 10       영업이익    RobustScaler                 ElasticNet     9808588322
# 11       영업이익    RobustScaler  GradientBoostingRegressor     6280306325
# 12  당기순이익(손실)  StandardScaler                    XGBoost      581557740
# 13  당기순이익(손실)  StandardScaler                 ElasticNet     8907600339
# 14  당기순이익(손실)  StandardScaler  GradientBoostingRegressor     3974955742
# 15  당기순이익(손실)    RobustScaler                    XGBoost      581557740
# 16  당기순이익(손실)    RobustScaler                 ElasticNet     8929379379
# 17  당기순이익(손실)    RobustScaler  GradientBoostingRegressor     3974955742
#
#          test_mse
# 0   2947917693579
# 1   4557023833415
# 2   2783371933655
# 3   2894180982395
# 4   4403952335066
# 5   2779794974869
# 6      7567468298
# 7      9287005133
# 8      7204909244
# 9      7567468298
# 10     9272367284
# 11     7205302725
# 12     4636370714
# 13     8506984735
# 14     4961512963
# 15     4636370714
# 16     8448184990
# 17     4857010512

# %%
#원자료변수
results_df
# Out:
#        target          scaler                      model     train_mse  \
# 0         매출액  StandardScaler                    XGBoost     139822445
# 1         매출액  StandardScaler                 ElasticNet  112421198797
# 2         매출액  StandardScaler  GradientBoostingRegressor    1671032664
# 3         매출액    RobustScaler                    XGBoost     139822445
# 4         매출액    RobustScaler                 ElasticNet   60762129525
# 5         매출액    RobustScaler  GradientBoostingRegressor    1671032664
# 6        영업이익  StandardScaler                    XGBoost      17373060
# 7        영업이익  StandardScaler                 ElasticNet    6183543330
# 8        영업이익  StandardScaler  GradientBoostingRegressor     441139188
# 9        영업이익    RobustScaler                    XGBoost      17373060
# 10       영업이익    RobustScaler                 ElasticNet    7381303971
# 11       영업이익    RobustScaler  GradientBoostingRegressor     441139188
# 12  당기순이익(손실)  StandardScaler                    XGBoost     129605633
# 13  당기순이익(손실)  StandardScaler                 ElasticNet    5620675326
# 14  당기순이익(손실)  StandardScaler  GradientBoostingRegressor    1196379536
# 15  당기순이익(손실)    RobustScaler                    XGBoost     129605633
# 16  당기순이익(손실)    RobustScaler                 ElasticNet    6450110788
# 17  당기순이익(손실)    RobustScaler  GradientBoostingRegressor    1196379536
#
#         test_mse  train_r2   test_r2
# 0     6104208291  0.999862  0.993609
# 1   107129207510  0.888942  0.887836
# 2     7868325844  0.998349  0.991762
# 3     6104208451  0.999862  0.993609
# 4    60384729398  0.939975  0.936777
# 5     7826101945  0.998349  0.991806
# 6      516356980  0.998779  0.961033
# 7     5802106692  0.565236  0.562139
# 8      696037883  0.968984  0.947473
# 9      516364043  0.998779  0.961032
# 10    6869065841  0.481022  0.481620
# 11     702018444  0.968984  0.947022
# 12    1625527362  0.988900  0.837271
# 13    4658365718  0.518600  0.533659
# 14    1729448509  0.897532  0.826868
# 15    1625534624  0.988900  0.837270
# 16    5315867002  0.447560  0.467837
# 17    1742610858  0.897532  0.825550

# %%
#논문자료변수
results_df
# Out:
#        target          scaler                      model     train_mse  \
# 0         매출액  StandardScaler                    XGBoost     769231931
# 1         매출액  StandardScaler                 ElasticNet  139942446173
# 2         매출액  StandardScaler  GradientBoostingRegressor   11528827185
# 3         매출액    RobustScaler                    XGBoost     375416967
# 4         매출액    RobustScaler                 ElasticNet  138725159971
# 5         매출액    RobustScaler  GradientBoostingRegressor   11528827185
# 6        영업이익  StandardScaler                    XGBoost    6202884108
# 7        영업이익  StandardScaler                 ElasticNet   49105126246
# 8        영업이익  StandardScaler  GradientBoostingRegressor   24138845990
# 9        영업이익    RobustScaler                    XGBoost    6345715140
# 10       영업이익    RobustScaler                 ElasticNet   49072755439
# 11       영업이익    RobustScaler  GradientBoostingRegressor   24138845990
# 12  당기순이익(손실)  StandardScaler                    XGBoost    5762994439
# 13  당기순이익(손실)  StandardScaler                 ElasticNet   48254115769
# 14  당기순이익(손실)  StandardScaler  GradientBoostingRegressor   22320633673
# 15  당기순이익(손실)    RobustScaler                    XGBoost    5041566754
# 16  당기순이익(손실)    RobustScaler                 ElasticNet   48221475996
# 17  당기순이익(손실)    RobustScaler  GradientBoostingRegressor   22320633673
#
#         test_mse  train_r2   test_r2
# 0    20575367896  0.999276  0.980833
# 1   143603716135  0.868308  0.866225
# 2    30238184615  0.989151  0.971832
# 3    18806542489  0.999647  0.982481
# 4   142012611716  0.869453  0.867708
# 5    30516392037  0.989151  0.971572
# 6    27394583243  0.898901  0.431731
# 7    37966390091  0.199649  0.212431
# 8    28227982644  0.606567  0.414443
# 9    26665661158  0.896573  0.446852
# 10   38064651400  0.200176  0.210393
# 11   28190841858  0.606567  0.415214
# 12   26699366862  0.901466  0.346687
# 13   33336841737  0.174964  0.184273
# 14   27831323759  0.618368  0.318989
# 15   27342734419  0.913801  0.330945
# 16   33502569812  0.175522  0.180218
# 17   27827519197  0.618368  0.319082

# %%
# 원자료변수 + 이상치변환
#results_df
# Out:
#        target          scaler                      model      train_mse  \
# 0         매출액  StandardScaler                    XGBoost   380249872137
# 1         매출액  StandardScaler                 ElasticNet  3617120716978
# 2         매출액  StandardScaler  GradientBoostingRegressor  1920606696534
# 3         매출액    RobustScaler                    XGBoost   380249872137
# 4         매출액    RobustScaler                 ElasticNet  3318051454728
# 5         매출액    RobustScaler  GradientBoostingRegressor  1920606696534
# 6        영업이익  StandardScaler                    XGBoost     2517756618
# 7        영업이익  StandardScaler                 ElasticNet    21563573041
# 8        영업이익  StandardScaler  GradientBoostingRegressor    11620922120
# 9        영업이익    RobustScaler                    XGBoost     2517756618
# 10       영업이익    RobustScaler                 ElasticNet    21423739653
# 11       영업이익    RobustScaler  GradientBoostingRegressor    11620922120
# 12  당기순이익(손실)  StandardScaler                    XGBoost     3948226257
# 13  당기순이익(손실)  StandardScaler                 ElasticNet    16978950611
# 14  당기순이익(손실)  StandardScaler  GradientBoostingRegressor    10656369397
# 15  당기순이익(손실)    RobustScaler                    XGBoost     3948226257
# 16  당기순이익(손실)    RobustScaler                 ElasticNet    16872562204
# 17  당기순이익(손실)    RobustScaler  GradientBoostingRegressor    10656369397
#
#          test_mse  train_r2   test_r2
# 0   1620248440364  0.961342  0.832741
# 1   3642967103861  0.632267  0.623934
# 2   2135985174275  0.804742  0.779501
# 3   1620305998924  0.961342  0.832735
# 4   3357491770874  0.662672  0.653404
# 5   2136670644612  0.804742  0.779430
# 6      6886207529  0.909564  0.749278
# 7     21599825213  0.225448  0.213565
# 8     12366536739  0.582583  0.549743
# 9      6885951567  0.909564  0.749287
# 10    21489676785  0.230470  0.217575
# 11    12363717450  0.582583  0.549845
# 12     9706814963  0.817998  0.558178
# 13    17459374449  0.217317  0.205308
# 14    11761586469  0.508771  0.464652
# 15     9706814963  0.817998  0.558178
# 16    17358788594  0.222222  0.209886
# 17    11759888669  0.508771  0.464729

# %%
# 원자료변수
results2_df
# Out:
#        target          scaler                      model            df2_mse  \
# 0         매출액  StandardScaler                    XGBoost  50746822199951000
# 1         매출액  StandardScaler                 ElasticNet  83869803129097248
# 2         매출액  StandardScaler  GradientBoostingRegressor  50689235445846024
# 3         매출액    RobustScaler                    XGBoost  50746822019340384
# 4         매출액    RobustScaler                 ElasticNet  32956246967907276
# 5         매출액    RobustScaler  GradientBoostingRegressor  50686480408195640
# 6        영업이익  StandardScaler                    XGBoost   2165282805274501
# 7        영업이익  StandardScaler                 ElasticNet   2100988563835355
# 8        영업이익  StandardScaler  GradientBoostingRegressor   2165226281598264
# 9        영업이익    RobustScaler                    XGBoost   2165282804348882
# 10       영업이익    RobustScaler                 ElasticNet   3775542888404923
# 11       영업이익    RobustScaler  GradientBoostingRegressor   2165026435883872
# 12  당기순이익(손실)  StandardScaler                    XGBoost   1473841745858898
# 13  당기순이익(손실)  StandardScaler                 ElasticNet   2037515156101562
# 14  당기순이익(손실)  StandardScaler  GradientBoostingRegressor   1474031075083091
# 15  당기순이익(손실)    RobustScaler                    XGBoost   1473841745817835
# 16  당기순이익(손실)    RobustScaler                 ElasticNet   3673964134607783
# 17  당기순이익(손실)    RobustScaler  GradientBoostingRegressor   1474027445053204
#
#       df2_r2
# 0   0.999862
# 1   0.888942
# 2   0.998349
# 3   0.999862
# 4   0.939975
# 5   0.998349
# 6   0.998779
# 7   0.565236
# 8   0.968984
# 9   0.998779
# 10  0.481022
# 11  0.968984
# 12  0.988900
# 13  0.518600
# 14  0.897532
# 15  0.988900
# 16  0.447560
# 17  0.897532

# %%
# 논문자료변수
results2_df
# Out:
#        target          scaler                      model            df2_mse  \
# 0         매출액  StandardScaler                    XGBoost  50803221458992744
# 1         매출액  StandardScaler                 ElasticNet   5429921268329194
# 2         매출액  StandardScaler  GradientBoostingRegressor  50668197938699992
# 3         매출액    RobustScaler                    XGBoost  50814530039543544
# 4         매출액    RobustScaler                 ElasticNet   4955982120944182
# 5         매출액    RobustScaler  GradientBoostingRegressor  50687514898672528
# 6        영업이익  StandardScaler                    XGBoost   2177350682412965
# 7        영업이익  StandardScaler                 ElasticNet   2502253504354956
# 8        영업이익  StandardScaler  GradientBoostingRegressor   2176725897529438
# 9        영업이익    RobustScaler                    XGBoost   2179143419233644
# 10       영업이익    RobustScaler                 ElasticNet   2580193076509855
# 11       영업이익    RobustScaler  GradientBoostingRegressor   2176569544294960
# 12  당기순이익(손실)  StandardScaler                    XGBoost   1489316427742448
# 13  당기순이익(손실)  StandardScaler                 ElasticNet   1631691343662870
# 14  당기순이익(손실)  StandardScaler  GradientBoostingRegressor   1482418924859039
# 15  당기순이익(손실)    RobustScaler                    XGBoost   1483589013762017
# 16  당기순이익(손실)    RobustScaler                 ElasticNet   1698210713063392
# 17  당기순이익(손실)    RobustScaler  GradientBoostingRegressor   1482090114935441
#
#       df2_r2
# 0   0.999276
# 1   0.868308
# 2   0.989151
# 3   0.999647
# 4   0.869453
# 5   0.989151
# 6   0.898901
# 7   0.199649
# 8   0.606567
# 9   0.896573
# 10  0.200176
# 11  0.606567
# 12  0.901466
# 13  0.174964
# 14  0.618368
# 15  0.913801
# 16  0.175522
# 17  0.618368

# %%
# 원자료변수 + 이상치변환
#results2_df
# Out:
#        target          scaler                      model            df2_mse  \
# 0         매출액  StandardScaler                    XGBoost  51237656119843616
# 1         매출액  StandardScaler                 ElasticNet  32440357949804632
# 2         매출액  StandardScaler  GradientBoostingRegressor  50613531560042720
# 3         매출액    RobustScaler                    XGBoost  51237645493825832
# 4         매출액    RobustScaler                 ElasticNet  16325546210387058
# 5         매출액    RobustScaler  GradientBoostingRegressor  50644526326526496
# 6        영업이익  StandardScaler                    XGBoost   2166788731919113
# 7        영업이익  StandardScaler                 ElasticNet   1615818576805678
# 8        영업이익  StandardScaler  GradientBoostingRegressor   2165064195258085
# 9        영업이익    RobustScaler                    XGBoost   2166788718330880
# 10       영업이익    RobustScaler                 ElasticNet   1678831636769655
# 11       영업이익    RobustScaler  GradientBoostingRegressor   2165260073323457
# 12  당기순이익(손실)  StandardScaler                    XGBoost   1472486834546309
# 13  당기순이익(손실)  StandardScaler                 ElasticNet   1023404706607852
# 14  당기순이익(손실)  StandardScaler  GradientBoostingRegressor   1473335034895504
# 15  당기순이익(손실)    RobustScaler                    XGBoost   1472486808738486
# 16  당기순이익(손실)    RobustScaler                 ElasticNet   1094279175507593
# 17  당기순이익(손실)    RobustScaler  GradientBoostingRegressor   1473427713728388
#
#       df2_r2
# 0   0.961342
# 1   0.632267
# 2   0.804742
# 3   0.961342
# 4   0.662672
# 5   0.804742
# 6   0.909564
# 7   0.225448
# 8   0.582583
# 9   0.909564
# 10  0.230470
# 11  0.582583
# 12  0.817998
# 13  0.217317
# 14  0.508771
# 15  0.817998
# 16  0.222222
# 17  0.508771

# %% [markdown]
# ## 베스트 모델 선택 후 하이퍼 파라미터 튜닝

# %%
cond1 = df['stYear'] == 2021.0
df3 = df.loc[~cond1]

df3 = df3.dropna(subset=['매출액', '영업이익', '당기순이익(손실)'])
df2 = df2.dropna(subset=['매출액', '영업이익', '당기순이익(손실)'])

# %%
# 카테고리와 숫자형 변수 리스트 생성
category_list = df3.select_dtypes(include=['object']).columns
numeric_list = df3.select_dtypes(include=[np.number]).columns.drop(['매출액', '영업이익', '당기순이익(손실)'])

# %%
# 타겟 변수 목록
targets = ['매출액', '영업이익', '당기순이익(손실)']
results = []

# %%
# 하이퍼파라미터 그리드 설정
param_grid = {
    'gradientboostingregressor__n_estimators': [50, 100, 200],
    'gradientboostingregressor__max_depth': [3, 4, 5, 6],
    'gradientboostingregressor__learning_rate': [0.01, 0.05, 0.1],
    'gradientboostingregressor__subsample': [0.7, 0.8, 0.9]
}

for target in targets:
    Y = df3[target]
    X = df3.drop(columns=target)
    
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=42)
    
    numeric_pipe = make_pipeline(SimpleImputer(strategy='median'), StandardScaler())
    category_pipe = make_pipeline(SimpleImputer(strategy='most_frequent'), OneHotEncoder(handle_unknown='ignore'))
        
    prepro_pipe = make_column_transformer((numeric_pipe, numeric_list),
                                          (category_pipe, category_list))
        
    model_pipe = make_pipeline(prepro_pipe, GradientBoostingRegressor(random_state=42))
    
    grid_search = GridSearchCV(model_pipe, param_grid, cv=3, scoring='neg_mean_squared_error', n_jobs=-1)
    grid_search.fit(X_train, Y_train)
    
    best_model = grid_search.best_estimator_
    
    Y_train_pred = best_model.predict(X_train)
    Y_test_pred = best_model.predict(X_test)
    
    train_mse = mean_squared_error(Y_train, Y_train_pred)
    test_mse = mean_squared_error(Y_test, Y_test_pred)
    train_r2 = r2_score(Y_train, Y_train_pred)
    test_r2 = r2_score(Y_test, Y_test_pred)
    
    results.append({
        'target': target,
        'train_mse': train_mse,
        'test_mse': test_mse,
        'train_r2': train_r2,
        'test_r2': test_r2,
        'best_params': grid_search.best_params_        
    })

# %%
results_df = pd.DataFrame(results)
results_df
results_df['train_mse'] = results_df['train_mse'].apply(lambda x: int(float(x)))
results_df['test_mse'] = results_df['test_mse'].apply(lambda x: int(float(x)))
results_df
# Out:
#       target  train_mse    test_mse  train_r2   test_r2  \
# 0        매출액  314722315  7670183339  0.999689  0.991969
# 1       영업이익   13585743   370913514  0.999045  0.972009
# 2  당기순이익(손실)  308052691  1402688244  0.973616  0.859579
#
#                                          best_params
# 0  {'gradientboostingregressor__learning_rate': 0...
# 1  {'gradientboostingregressor__learning_rate': 0...
# 2  {'gradientboostingregressor__learning_rate': 0...

# %%
results_df = pd.DataFrame(results)
results_df
results_df['train_mse'] = results_df['train_mse'].apply(lambda x: int(float(x)))
results_df['test_mse'] = results_df['test_mse'].apply(lambda x: int(float(x)))
results_df
# Out:
#       target  train_mse    test_mse  train_r2   test_r2  \
# 0        매출액  504331824  6908128118  0.999502  0.992767
# 1       영업이익   33266178   403474849  0.997661  0.969551
# 2  당기순이익(손실)  360436132  1451241022  0.969129  0.854719
#
#                                          best_params
# 0  {'xgbregressor__colsample_bytree': 0.9, 'xgbre...
# 1  {'xgbregressor__colsample_bytree': 0.9, 'xgbre...
# 2  {'xgbregressor__colsample_bytree': 0.9, 'xgbre...

# %%
for i in results_df['best_params'] :
    print(i)
# Out:
# {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 300, 'xgbregressor__subsample': 0.8}
# {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 300, 'xgbregressor__subsample': 0.6}
# {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 7, 'xgbregressor__n_estimators': 300, 'xgbregressor__subsample': 0.6}

# %%
results2 = []

# %%
for target in targets:
    X_df2 = df2.drop(columns=target)
    Y_df2 = df2[target]
    Y_df2_pred = best_model.predict(X_df2)
    df2_mse = mean_squared_error(Y_df2, Y_df2_pred)
    df2_r2 = r2_score(Y_df2, Y_df2_pred)


    results2.append({
        'target': target,
        'scaler': scaler.__class__.__name__,
        'model': model_name,
        'df2_mse': df2_mse,
        'df2_r2': train_r2 })

# %%
results_df2 = pd.DataFrame(results2)
results_df2
results_df2['df2_mse'] = results_df2['df2_mse'].apply(lambda x: int(float(x)))
results_df2
# Out:
#       target        scaler                      model            df2_mse  \
# 0        매출액  RobustScaler  GradientBoostingRegressor  51098253117395296
# 1       영업이익  RobustScaler  GradientBoostingRegressor   2165825058782721
# 2  당기순이익(손실)  RobustScaler  GradientBoostingRegressor   1474310239634679
#
#      df2_r2
# 0  0.973616
# 1  0.973616
# 2  0.973616
