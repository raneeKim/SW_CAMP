# %%
import pandas as pd
import numpy as np
import plotly.express as px
import scipy.stats as stats

# %%
df_member = pd.read_csv(r'C:\Users\UserK\Desktop\Ranee\data\ML\유아용품판매데이터\Member_data.csv')
df_product = pd.read_csv(r'C:\Users\UserK\Desktop\Ranee\data\ML\유아용품판매데이터\Product_data.csv')
df_sales =  pd.read_csv(r'C:\Users\UserK\Desktop\Ranee\data\ML\유아용품판매데이터\Sales_data.csv')
# Out:
# C:\Users\UserK\AppData\Local\Temp\ipykernel_1308\2489966323.py:1: DtypeWarning:
#
# Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#
# C:\Users\UserK\AppData\Local\Temp\ipykernel_1308\2489966323.py:3: DtypeWarning:
#
# Columns (1,6) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199999 entries, 0 to 199998
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  199999 non-null  int64
#  1   주문번호        199999 non-null  object
#  2   배송완료일       199999 non-null  object
#  3   배송시작일       199999 non-null  object
#  4   구매일         199999 non-null  object
#  5   구매시월령       168142 non-null  float64
#  6   고객번호        199999 non-null  object
#  7   구매금액        199999 non-null  int64
#  8   결제금액        199999 non-null  int64
#  9   물품대분류       199999 non-null  object
#  10  상품명         199999 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 16.8+ MB

# %%
df_sales.sort_values(by='구매시월령',ascending=False).iloc[40:50]
# Out:
#         Unnamed: 0                주문번호       배송완료일       배송시작일         구매일  \
# 80210        80210   90906281107430009  2022-09-10  2022-09-07  2022-09-06
# 12090        12090   90301210199330008  2022-03-07  2022-03-03  2022-03-02
# 25875        25875   90413227769659393  2022-04-17  2022-04-15  2022-04-14
# 165510      165510   00312352168630391  2023-03-16  2023-03-14  2023-03-13
# 164946      164946   00310351210130390  2023-03-15  2023-03-12  2023-03-11
# 21543        21543   90331222159458622  2022-04-04  2022-04-02  2022-04-01
# 78720        78720  909042800831159840  2022-09-07  2022-09-05  2022-09-04
# 50323        50323  907012546376107690  2022-07-04  2022-07-02  2022-07-01
# 28956        28956   90428231389781890  2022-05-01  2022-04-29  2022-04-28
# 13237        13237   90308213262468479  2022-03-12  2022-03-09  2022-03-08
#
#         구매시월령             고객번호   구매금액   결제금액 물품대분류  \
# 80210   659.0  201901310785174   2600   2574    FC
# 12090   653.0  201901310785174  19100  13454   FMC
# 25875   583.0  201903010820258  19100  14295   FMC
# 165510  566.0  201902010785401  51200  40887    팬티
# 164946  566.0  201902010785401  19900  18513   FMC
# 21543   548.0  201903010819904   7000   4821   FMC
# 78720   544.0  201909030976130   7280   4672   체험팩
# 50323   538.0  201905140892279  29800  17680   SKC
# 28956   518.0  201903270852044   7280   5841   체험팩
# 13237   514.0  201903080828799  10800   7335   FMC
#
#                                        상품명
# 80210                 좋은느낌 순수 팬티라이너 롱 18개입
# 12090               크리넥스 데코앤소프트 클래식 27-30롤
# 25875               크리넥스 데코앤소프트 클래식 27-30롤
# 165510    NEW 하기스 맥스드라이 팬티 5단계 남아 80매(팬티형)
# 164946     크리넥스 3겹 천연펄프 데코&소프트 화장지 27m 30롤
# 21543           크리넥스 디럭스 신수성 리미티드 250매X3개입
# 78720    하기스 네이처메이드 팬티 3단계 남아 20매(팬티형/체험팩)
# 50323               그린핑거 힘센보습 울트라 로션 260ml
# 28956   하기스 에어솔솔 썸머팬티 4단계 남아용 20매(팬티형/체험팩)
# 13237           크리넥스 안심 클래식 키친타올 120매 X 4롤

# %%
df_sales.sort

# %%
df_sales.shape
# Out:
# (199999, 11)

# %%
df_sales.isnull().sum()
# Out:
# Unnamed: 0        0
# 주문번호              0
# 배송완료일             0
# 배송시작일             0
# 구매일               0
# 구매시월령         31857
# 고객번호              0
# 구매금액              0
# 결제금액              0
# 물품대분류             0
# 상품명               0
# dtype: int64

# %%
df_sales['구매시월령'].describe()
# Out:
# count    168142.000000
# mean         14.845458
# std          38.521315
# min         -10.000000
# 25%           2.000000
# 50%           6.000000
# 75%          13.000000
# max        1439.000000
# Name: 구매시월령, dtype: float64

# %%
df_product.isnull().sum()
# Out:
# 물품대분류    0
# 상품명      0
# 물품판매량    0
# 제품단가     0
# dtype: int64

# %%
a = df_product['상품명'].unique().tolist()
# Out:
# ['(1+1) 좋은느낌 입는 오버나이트 대형 8개입',
#  '(1+1) 좋은느낌 입는 오버나이트 중형 8개입',
#  '(1+1) 화이트 입는 오버나이트 대형 L 8개입 (EA)',
#  '(1+1) 화이트 입는 오버나이트 중형 M 8개입 (EA)',
#  '(핫딜위크/1+1) 좋은느낌 입는 오버나이트 대형 8개입',
#  '(핫딜위크/1+1) 좋은느낌 입는 오버나이트 중형 8개입',
#  '[1+1] 좋은느낌 라인프렌즈 유기농 순면 팬티라이너 롱 36 개입',
#  '[1+1] 좋은느낌 팬티라이너 유기농 순면 롱 36개입',
#  '[대량발주] 택배파손_1224',
#  '[동일상품 1+1] 화이트 입는 오버나이트 대형 L 8개입',
#  '[동일상품 1+1] 화이트 입는 오버나이트 중형 M 8개입',
#  '[멤버십 가입선물] 라네이처 시그니처 팬티라이너 롱 28개입',
#  '[벚꽃에디션] 좋은느낌 라인프렌즈 유기농 순면 뉴 수퍼롱 오버나이트 8개입',
#  '[벚꽃에디션] 좋은느낌 라인프렌즈 유기농 순면 뉴 수퍼롱 오버나이트 8개입 (EA)',
#  '[벚꽃에디션] 좋은느낌 라인프렌즈 유기농 순면 뉴 수퍼롱 오버나이트 8개입 X4',
#  '[벚꽃에디션] 좋은느낌 라인프렌즈 유기농 순면 뉴 슬림 날개 대형 14개입',
#  '[벚꽃에디션] 좋은느낌 라인프렌즈 유기농 순면 뉴 슬림 날개 대형 14개입 (EA)',
#  '[벚꽃에디션] 좋은느낌 라인프렌즈 유기농 순면 뉴 슬림 날개 대형 14개입 X4',
#  '[벚꽃에디션] 좋은느낌 라인프렌즈 유기농 순면 뉴 슬림 날개 중형 14개입',
#  '[벚꽃에디션] 좋은느낌 라인프렌즈 유기농 순면 뉴 슬림 날개 중형 14개입 (EA)',
#  '[벚꽃에디션] 좋은느낌 라인프렌즈 유기농 순면 뉴 슬림 날개 중형 14개입 X4',
#  '[벚꽃에디션] 좋은느낌 팬티라이너 유기농 순면 롱 36개입',
#  '[벚꽃에디션] 좋은느낌 팬티라이너 유기농 순면 롱 36개입 (EA)',
#  '[벚꽃에디션] 좋은느낌 팬티라이너 유기농 순면 롱 36개입 X3',
#  '[시리얼1종랜덤증정+무료배송] 좋은느낌 유기농 순면 뉴 수퍼롱 오버나이트 8매X3팩',
#  '[시리얼1종랜덤증정+무료배송] 좋은느낌 유기농 순면 뉴 오버나이트 10매X3팩',
#  '[시리얼1종랜덤증정+무료배송] 좋은느낌 유기농 순면 뉴 울트라 날개 대형 16매X3팩',
#  '[시리얼1종랜덤증정+무료배송] 좋은느낌 유기농 입는 오버나이트 중형 8매X2팩',
#  '[시리얼1종랜덤증정+무료배송] 좋은느낌 유기농순면 뉴 울트라 날개 중형 18매X2팩 + 날개 대형 16매X1팩',
#  '[시리얼1종랜덤증정+무료배송] 좋은느낌 유기농순면 뉴 울트라 날개 중형 18매X3팩',
#  '[중형8p증정+무료배송] 좋은느낌 유기농 순면 뉴 수퍼롱 오버나이트 8매X3팩',
#  '[중형8p증정+무료배송] 좋은느낌 유기농 순면 뉴 오버나이트 10매X3팩',
#  '[중형8p증정+무료배송] 좋은느낌 유기농 순면 뉴 울트라 날개 대형 16매X3팩',
#  '[중형8p증정+무료배송] 좋은느낌 유기농순면 뉴 울트라 날개 중형 18매X2팩 + 날개 대형 16매X1팩',
#  '[중형8p증정+무료배송] 좋은느낌 유기농순면 뉴 울트라 날개 중형 18매X3팩',
#  '[할로윈에디션] 좋은느낌 라인프렌즈 유기농순면 뉴 수퍼롱오버 8개입 X 3팩 + 뉴 울트라 날개 중형 8매',
#  '[할로윈에디션] 좋은느낌 라인프렌즈 유기농순면 데일리 라이너 롱 36개입 X 3팩 + 뉴 울트라 날개 중형 8매',
#  '디펜드 맘스 안심 팬티 8개입',
#  '디펜드 맘스 안심패드 30개입',
#  '디펜드 스타일 언더웨어 남성용 슬림 대형 16개입 X 3',
#  '디펜드 스타일 언더웨어 남성용 슬림 대형 54매 (실속 점보팩)',
#  '디펜드 스타일 언더웨어 남성용 슬림 중형 18개입 X 3',
#  '디펜드 스타일 언더웨어 남성용 슬림 중형 60매 (실속 점보팩)',
#  '디펜드 스타일 언더웨어 여성용 슬림 대형 16개입 X 3',
#  '디펜드 스타일 언더웨어 여성용 슬림 대형 54매 (실속 점보팩)',
#  '디펜드 스타일 언더웨어 여성용 슬림 중형 18개입 X 3',
#  '디펜드 스타일 언더웨어 여성용 슬림 중형 60매 (실속 점보팩)',
#  '디펜드 안심플러스 언더웨어 중형 18개입 X 3',
#  '디펜드 안심플러스 언더웨어 중형 54매',
#  '라네이처 데일리라이너 롱 28개입',
#  '라네이처 데일리라이너 롱 28개입 X 3',
#  '라네이처 세트',
#  '라네이처 시그니처 맥시슬림 날개 대형 10개입',
#  '라네이처 시그니처 맥시슬림 날개 대형 10개입 (EA)',
#  '라네이처 시그니처 맥시슬림 날개 대형 10개입 (EA) X 3',
#  '라네이처 시그니처 맥시슬림 날개 중형 12개입',
#  '라네이처 시그니처 맥시슬림 날개 중형 12개입 (EA)',
#  '라네이처 시그니처 맥시슬림 날개 중형 12개입 (EA) X 3',
#  '라네이처 시그니처 맥시슬림 수퍼롱 오버나이트 6개입',
#  '라네이처 시그니처 맥시슬림 수퍼롱 오버나이트 6개입 (EA)',
#  '라네이처 시그니처 맥시슬림 수퍼롱 오버나이트 6개입 (EA) X 3',
#  '라네이처 시그니처 세트',
#  '라네이처 시그니처 울트라 날개 오버나이트 8개입',
#  '라네이처 시그니처 울트라 날개 오버나이트 8개입 (EA)',
#  '라네이처 시그니처 울트라 날개 오버나이트 8개입 (EA) X 3',
#  '라네이처 시그니처 울트라슬림 날개 대형 10개입 (EA)',
#  '라네이처 시그니처 울트라슬림 날개 소형 14개입 (EA)',
#  '라네이처 시그니처 울트라슬림 날개 중형 12개입 (EA)',
#  '라네이처 시그니처 팬티라이너 롱 28개입',
#  '라네이처 시그니처 팬티라이너 롱 28개입 (EA)',
#  '라네이처 시그니처 팬티라이너 롱 28개입 (EA) X 3',
#  '라네이처 울트라 날개 대형 10개입',
#  '라네이처 울트라 날개 대형 10개입 X 3',
#  '라네이처 울트라 날개 소형 14개입',
#  '라네이처 울트라 날개 오버나이트 14개입',
#  '라네이처 울트라 날개 오버나이트 14개입 X 2',
#  '라네이처 울트라 날개 중형 12개입',
#  '라네이처 울트라 날개 중형 12개입 (EA)',
#  '라네이처 울트라 날개 중형 12개입 X 2 + 울트라 날개 오버나이트 14개입',
#  '라네이처 울트라 날개 중형 12개입 X 3',
#  '라네이처 페미닌 워시 젤 240ml',
#  '라네이처 페미닌 워시 젤 240ml (EA)',
#  '라네이처 페미닌 워시 폼 200ml',
#  '라네이처 페미닌 워시 폼 200ml (EA)',
#  '라네이처 페미닌 티슈 6매 X 5개입',
#  '라네이처 페미닌 티슈 6매 X 5개입 (EA)',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 수퍼롱 오버나이트 8개입',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 수퍼롱 오버나이트 8개입 (EA)',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 수퍼롱 오버나이트 8개입 X 3팩',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 수퍼롱 오버나이트 8개입 X 3팩 + 20주년 한정판 파우치',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 슬림 날개 대형 14개입',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 슬림 날개 대형 14개입 (EA)',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 슬림 날개 대형 14개입 X 3팩',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 슬림 날개 대형 14개입 X 3팩 + 20주년 한정판 파우치',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 슬림 날개 대형 14개입 X 3팩 + 뉴 울트라 날개 중형 8매',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 슬림 날개 중형 14개입',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 슬림 날개 중형 14개입 (EA)',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 슬림 날개 중형 14개입 X 2팩 + 뉴 슬림 날개 대형 14개입 + 20주년 한정판 파우치',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 슬림 날개 중형 14개입 X 2팩 + 뉴 슬림 날개 대형 14개입 + 뉴 울트라 날개 중형 8매',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 슬림 날개 중형 14개입 X 3팩',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 슬림 날개 중형 14개입 X 3팩 + 20주년 한정판 파우치',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 슬림 날개 중형 14개입 X 3팩 + 뉴 울트라 날개 중형 8매',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 오버나이트 10개입',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 오버나이트 10개입 (EA)',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 오버나이트 10개입 X 3팩',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 오버나이트 10개입 X 3팩 + 20주년 한정판 파우치',
#  '좋은느낌 라인프렌즈 유기농 순면 뉴 오버나이트 10개입 X 3팩 + 뉴 울트라 날개 중형 8매',
#  '좋은느낌 라인프렌즈 유기농 순면 입는 오버나이트 중형 4개입',
#  '좋은느낌 라인프렌즈 유기농 순면 입는 오버나이트 중형 4개입 X 2팩',
#  '좋은느낌 라인프렌즈 유기농 순면 입는 오버나이트 중형 4개입 X 2팩 + 20주년 한정판 파우치',
#  '좋은느낌 라인프렌즈 유기농 순면 입는 오버나이트 중형 4개입 X 2팩 + 뉴 울트라 날개 중형 8매',
#  '좋은느낌 라인프렌즈 유기농 순면 팬티라이너 롱 36 개입',
#  '좋은느낌 라인프렌즈 유기농 순면 팬티라이너 롱 36 개입 X 3팩',
#  '좋은느낌 라인프렌즈 유기농 순면 팬티라이너 롱 36 개입 X 3팩 + 20주년 한정판 파우치',
#  '좋은느낌 매직쿠션 울트라 날개 대형 17개입',
#  '좋은느낌 매직쿠션 울트라 날개 중형 19개입',
#  '좋은느낌 솜솜 대형 날개형 12개입',
#  '좋은느낌 솜솜 대형 날개형 12개입 (EA)',
#  '좋은느낌 솜솜 소중형 날개형 14개입',
#  '좋은느낌 솜솜 수퍼롱 오버나이트 8개입',
#  '좋은느낌 솜솜 수퍼롱 오버나이트 8개입 (EA)',
#  '좋은느낌 솜솜 중형 날개형 14개입',
#  '좋은느낌 솜솜 중형 날개형 14개입 (EA)',
#  '좋은느낌 솜솜 특대형 날개형 12개입',
#  '좋은느낌 순수 울트라 날개 대형 16개입',
#  '좋은느낌 순수 울트라 날개 대형 16개입 (EA)',
#  '좋은느낌 순수 울트라 날개 중형 18개입',
#  '좋은느낌 순수 울트라 날개 중형 18개입 (EA)',
#  '좋은느낌 순수 팬티라이너 롱 18개입',
#  '좋은느낌 순수 팬티라이너 롱 18개입 (EA)',
#  '좋은느낌 에어핏쿠션 슬림 날개 수퍼롱 오버나이트 20개입',
#  '좋은느낌 에어핏쿠션 슬림 날개 수퍼롱 오버나이트 20개입 (EA)',
#  '좋은느낌 에어핏쿠션 울트라 날개 대형 17개입',
#  '좋은느낌 에어핏쿠션 울트라 날개 대형 17개입 (EA)',
#  '좋은느낌 에어핏쿠션 울트라 날개 대형 17개입 X 3',
#  '좋은느낌 에어핏쿠션 울트라 날개 중형 18개입X2 + 슬림 날개 수퍼롱 오버나이트 10개입',
#  '좋은느낌 에어핏쿠션 울트라 날개 중형 18개입X2 + 슬림 날개 수퍼롱 오버나이트 10개입 (EA)',
#  '좋은느낌 에어핏쿠션 울트라 날개 중형 19개입',
#  '좋은느낌 에어핏쿠션 울트라 날개 중형 19개입 (EA)',
#  '좋은느낌 에어핏쿠션 울트라 날개 중형 19개입 X 3',
#  '좋은느낌 유기농 순면 뉴 수퍼롱 오버나이트 8개입',
#  '좋은느낌 유기농 순면 뉴 수퍼롱 오버나이트 8개입 X3',
#  '좋은느낌 유기농 순면 뉴 수퍼롱 오버나이트 8개입 X 3',
#  '좋은느낌 유기농 순면 뉴 슬림 날개 중형 3개입(지퍼백)',
#  '좋은느낌 유기농 순면 뉴 슬림 날개 중형 3개입(지퍼팩) x 12',
#  '좋은느낌 유기농 순면 뉴 슬림 날개 중형 36개입',
#  '좋은느낌 유기농 순면 뉴 슬림 날개 중형 36개입 (EA)',
#  '좋은느낌 유기농 순면 뉴 오버나이트 10개입',
#  '좋은느낌 유기농 순면 뉴 오버나이트 10개입 (EA)',
#  '좋은느낌 유기농 순면 뉴 오버나이트 10개입 X3',
#  '좋은느낌 유기농 순면 뉴 오버나이트 10개입 X 3',
#  '좋은느낌 유기농 순면 뉴 울트라 날개 대형 16개입',
#  '좋은느낌 유기농 순면 뉴 울트라 날개 대형 16개입 (EA)',
#  '좋은느낌 유기농 순면 뉴 울트라 날개 대형 16개입 X3',
#  '좋은느낌 유기농 순면 뉴 울트라 날개 대형 16매X3팩',
#  '좋은느낌 유기농 순면 뉴 울트라 날개 중형 18개입',
#  '좋은느낌 유기농 순면 뉴 울트라 날개 중형 18개입 (EA)',
#  '좋은느낌 유기농 순면 뉴 울트라 날개 중형 18개입 X3',
#  '좋은느낌 유기농 입는 오버나이트 대형 8개입',
#  '좋은느낌 유기농 입는 오버나이트 대형 8개입 (EA)',
#  '좋은느낌 유기농 입는 오버나이트 대형 8개입 X 2',
#  '좋은느낌 유기농 입는 오버나이트 중형 8개입 (EA)',
#  '좋은느낌 유기농 입는 오버나이트 중형 8개입 X 2',
#  '좋은느낌 유기농 입는 오버나이트 중형 8입',
#  '좋은느낌 유기농 입는 오버나이트 중형 8입 (EA)',
#  '좋은느낌 유기농 탐폰 슈퍼 12개입',
#  '좋은느낌 유기농 탐폰 슈퍼 12개입 (EA)',
#  '좋은느낌 유기농순면 뉴 맥시슬림 날개 대형 14개입',
#  '좋은느낌 유기농순면 뉴 맥시슬림 날개 대형 14개입 (EA)',
#  '좋은느낌 유기농순면 뉴 맥시슬림 날개 중형 14개입',
#  '좋은느낌 유기농순면 뉴 맥시슬림 날개 중형 14개입 (EA)',
#  '좋은느낌 유기농순면 뉴 맥시슬림 수퍼롱 오버나이트 8개입 (EA)',
#  '좋은느낌 유기농순면 뉴 맥시슬림 오버나이트 12개입 (EA)',
#  '좋은느낌 유기농순면 뉴 울트라 날개 중형 18매X2팩 + 날개 대형 16매X1팩',
#  '좋은느낌 유기농순면 뉴 울트라 날개 중형 18매X3팩',
#  '좋은느낌 유기농순면 뉴 울트라슬림 날개 대형 16개입 (EA)',
#  '좋은느낌 유기농순면 뉴 울트라슬림 날개 중형 18개입 (EA)',
#  '좋은느낌 유기농순면 팬티라이너 롱 36개입 X 2',
#  '좋은느낌 유기농순면 팬티라이너 롱 36개입 X 2 (EA)',
#  '좋은느낌 입는 오버나이트 대형 8개입',
#  '좋은느낌 입는 오버나이트 대형 8개입 (EA)',
#  '좋은느낌 입는 오버나이트 대형 8개입 X2',
#  '좋은느낌 입는 오버나이트 대형 8개입 X 2',
#  '좋은느낌 입는 오버나이트 중형 8개입',
#  '좋은느낌 입는 오버나이트 중형 8개입 (EA)',
#  '좋은느낌 입는 오버나이트 중형 8개입 X2',
#  '좋은느낌 입는 오버나이트 중형 8개입 X 2',
#  '좋은느낌 좋은순면 슬림 날개 수퍼롱 10개입',
#  '좋은느낌 좋은순면 울트라 날개 대형 17개입',
#  '좋은느낌 좋은순면 울트라 날개 대형 17개입 (EA)',
#  '좋은느낌 좋은순면 울트라 날개 중형 19개입',
#  '좋은느낌 좋은순면 울트라 날개 중형 19개입 (EA)',
#  '좋은느낌 좋은순면 팬티라이너 롱 36개입',
#  '좋은느낌 좋은순면 팬티라이너 롱 36개입 (EA)',
#  '좋은느낌 팬티라이너 유기농 순면 롱 36개입',
#  '좋은느낌 팬티라이너 유기농 순면 롱 36개입 (EA)',
#  '좋은느낌 팬티라이너 유기농 순면 롱 36개입 X 3',
#  '좋은느낌라이너 유기농순면 롱 팬티라이너 36개입 (EA)',
#  '좋은느낌라이너 유기농순면 롱 팬티라이너 36개입 X 2 (EA)',
#  '화이트 스타일핏 수퍼울트라 날개 대형 16입',
#  '화이트 스타일핏 수퍼울트라 날개 중형 18개입',
#  '화이트 시크릿홀 가든프레시뉴 울트라 날개 대형 16개입',
#  '화이트 시크릿홀 가든프레시뉴 울트라 날개 중형 18개입',
#  '화이트 시크릿홀 맥시슬림 수퍼롱 오버나이트 10개입',
#  '화이트 시크릿홀 맥시슬림 수퍼롱 오버나이트 10개입 (EA)',
#  '화이트 시크릿홀 맥시슬림 수퍼롱 오버나이트 10개입 X3',
#  '화이트 시크릿홀 수퍼롱 10개입',
#  '화이트 시크릿홀 울트라 날개 대형 17개입',
#  '화이트 시크릿홀 울트라 날개 중형 19개입',
#  '화이트 시크릿홀 울트라슬림 날개 대형 17개입',
#  '화이트 시크릿홀 울트라슬림 날개 대형 17개입 (EA)',
#  '화이트 시크릿홀 울트라슬림 날개 대형 17개입 X3',
#  '화이트 시크릿홀 울트라슬림 날개 중형 19개입',
#  '화이트 시크릿홀 울트라슬림 날개 중형 19개입 (EA)',
#  '화이트 시크릿홀 울트라슬림 날개 중형 19개입 X3',
#  '화이트 시크릿홀 울트라슬림 날개 중형 19개입+울트라슬림 날개 대형 17개입+맥시슬림 수퍼롱 오버나이트 10개입',
#  '화이트 에코프레시 맥시슬림 날개 대형 14개입',
#  '화이트 에코프레시 맥시슬림 날개 대형 14개입 (EA)',
#  '화이트 에코프레시 맥시슬림 날개 대형 14개입 X4',
#  '화이트 에코프레시 맥시슬림 날개 중형 16개입',
#  '화이트 에코프레시 맥시슬림 날개 중형 16개입 (EA)',
#  '화이트 에코프레시 맥시슬림 날개 중형 16개입 X4',
#  '화이트 에코프레시 맥시슬림 슈퍼롱 오버나이트 8개입',
#  '화이트 에코프레시 맥시슬림 슈퍼롱 오버나이트 8개입 (EA)',
#  '화이트 에코프레시 맥시슬림 슈퍼롱 오버나이트 8개입 X3',
#  '화이트 에코프레시 맥시슬림 슈퍼롱 오버나이트 8개입 X4',
#  '화이트 에코프레시 슈퍼롱 오버나이트 8개입',
#  '화이트 에코프레시 울트라슬림 날개 대형 16개입',
#  '화이트 에코프레시 울트라슬림 날개 대형 16개입 (EA)',
#  '화이트 에코프레시 울트라슬림 날개 대형 16개입 X3',
#  '화이트 에코프레시 울트라슬림 날개 대형 16개입 X4',
#  '화이트 에코프레시 울트라슬림 날개 중형 18개입',
#  '화이트 에코프레시 울트라슬림 날개 중형 18개입 (EA)',
#  '화이트 에코프레시 울트라슬림 날개 중형 18개입 X3',
#  '화이트 에코프레시 울트라슬림 날개 중형 18개입 X4',
#  '화이트 에코프레시 팬티라이너 롱 44개입 (EA)',
#  '화이트 에코프레시 팬티라이너 롱 44개입 X4',
#  '화이트 에코프레시？팬티라이너 롱 44개입',
#  '화이트 입는 오버나이트 대형 8개입',
#  '화이트 입는 오버나이트 대형 L 8개입',
#  '화이트 입는 오버나이트 대형 L 8개입 (EA)',
#  '화이트 입는 오버나이트 대형 L 8개입 X2',
#  '화이트 입는 오버나이트 중형 8개입',
#  '화이트 입는 오버나이트 중형 M 8개입',
#  '화이트 입는 오버나이트 중형 M 8개입 (EA)',
#  '화이트 입는 오버나이트 중형 M 8개입 X2',
#  '화이트 클린 울트라슬림 날개 대형 17개입',
#  '화이트 클린 울트라슬림 날개 중형 19개입',
#  '화이트 탐폰 레귤러 16개입',
#  '화이트 탐폰 슈퍼 16개입',
#  '화이트 탐폰 오가닉 레귤러 14개입',
#  '화이트 탐폰 오가닉 슈퍼 14개입',
#  '화이트 한듯안한듯 팬티라이너 롱 36개입',
#  '화이트 한듯안한듯 팬티라이너 롱 36개입 (EA)',
#  '화이트 한듯안한듯 팬티라이너 롱 36개입 X3',
#  '(1+1) 크리넥스 버블버블 핸드워시 그린향 거품펌프형 250ml + 용기형리필 250ml X 2',
#  '(1+1) 크리넥스 버블버블 핸드워시 상큼향 거품펌프형 250ml + 용기형리필 250ml X 2',
#  '(핫딜위크/1+1) 스카트 주방 위생 세트',
#  '(핫딜위크/1+1) 크리넥스 칼로리라이트 키친타월 55매 X 3롤',
#  '[1+1] 스카트 항균 프레쉬블루 빨아쓰는 행주타월 45매 X 4롤',
#  '[1+1] 크리넥스 데코앤소프트 클래식 27-30롤',
#  '[1+1] 크리넥스 마이비데 46매 X 10팩',
#  '[1+1] 크리넥스 버블버블 핸드워시 그린향 거품펌프형 250ml + 용기형리필 250ml X 2',
#  '[1+1] 크리넥스 버블버블 핸드워시 상큼향 거품펌프형 250ml + 용기형리필 250ml X 2',
#  '[1+1] 크리넥스 순수 3겹 소프트 27m-30롤',
#  '[1+1] 크리넥스 울트라클린 27M 30롤',
#  '[2020년 2월 신제품] 크리넥스 KF94 데일리 방역 마스크 블랙 17P',
#  '[2020년 2월 신제품] 크리넥스 KF94 데일리 방역 마스크 화이트 대형 1P X2',
#  '[2020년 2월 신제품] 크리넥스 카카오 프렌즈 건강마스크 성인 중형 (5P)',
#  '[2020년 2월 신제품] 크리넥스 카카오 프렌즈 입체마스크 3D 베이비용 (3개입)',
#  '[2020년 2월 신제품] 크리넥스 카카오 프렌즈 입체마스크 3D 어린이 (3개입)',
#  '[2020년 2월 신제품] 크리넥스 황사마스크 뉴디자인플러스 소형 1P X2',
#  '[2020년 3월 신제품] 크리넥스 KF94 데일리 방역 마스크 화이트 대형 17P',
#  '[2020년 3월 신제품] 크리넥스 가습 촉촉 마스크 뉴 대형 2P',
#  '[2020년 3월 신제품] 크리넥스 스타일 마스크 블랙 대형 3P',
#  '[2020년 3월 신제품] 크리넥스 안심 물티슈 캡형 60매',
#  '[2020년 3월 신제품] 크리넥스 안심 물티슈 캡형 60매 (EA)',
#  '[2020년 3월 신제품] 크리넥스 안심 물티슈 휴대용 20매X3개입',
#  '[2020년 3월 신제품] 크리넥스 안심 물티슈 휴대용 20매X3개입 (EA)',
#  '[대량발주] 택배파손_0102',
#  '[사용완료] 크리넥스 KF94 데일리 방역 마스크 화이트 대형 17P',
#  '[신규회원 한정특가] [1+1] 스카트 항균 프레쉬블루 행주타올 45매 X 4롤',
#  '[쿠폰적용가11,940원] 크리넥스 마이비데 캡형 42매 X 9팩 카카오프렌즈',
#  '[쿠폰적용가22,790원] 크리넥스 순수 3겹 소프트 27m-30롤 X 2',
#  '[쿠폰적용가25,490원] 크리넥스 데코앤소프트 클래식 27-30롤 X 2',
#  '[쿠폰적용가26,860원] 크리넥스 3겹 울트라클린 27m 30롤 X 2',
#  '[쿠폰적용가42,240원] 크리넥스 황사마스크 뉴디자인플러스 대형 3P X 16',
#  '[쿠폰적용가42,240원] 크리넥스 황사마스크 뉴디자인플러스 소형 3P X 16',
#  '“스페인하숙에 나온 바로 그 행주” 스카트 항균 3겹 위생행주 20매',
#  '“스페인하숙에 나온 바로 그 행주” 스카트 항균 클리어 핑크 행주타올 45매 x 2롤',
#  '“스페인하숙에 나온 바로 그 행주” 스카트 항균 프레쉬블루 행주타올 45매 X 4롤',
#  '메이브리즈 KF80 황사마스크 대형 20P (EA)',
#  '스카트 10주년기념 빨아쓰는 행주타월 63매 X 2롤',
#  '스카트 10주년기념 행주타월 63매 X 2롤',
#  '스카트 THE 버블 수세미 베이지 50매',
#  '스카트 THE 버블 수세미 베이지 50매 (EA)',
#  '스카트 THE 버블 수세미 브라운 30매 (EA)',
#  '스카트 THE 보송 습기제거제 3P (EA)',
#  '스카트 THE 보송 습기제거제 18P',
#  '스카트 기름때전용 티슈 30매',
#  '스카트 기름때전용 티슈 30매 (EA)',
#  '스카트 막대걸레 베이직 표준형',
#  '스카트 막대걸레 베이직 표준형 (EA)',
#  '스카트 물걸레 청소포 올인원 표준형 25매',
#  '스카트 물걸레 청소포 올인원 표준형 25매 (EA)',
#  '스카트 잘 닦이는 세정티슈 80매',
#  '스카트 잘 닦이는 세정티슈 80매 (EA)',
#  '스카트 점착식 청소포 표준형 30매',
#  '스카트 점착식 청소포 표준형 30매 (EA)',
#  '스카트 정전기청소포 프리미엄 표준형 30매',
#  '스카트 정전기청소포 프리미엄 표준형 30매 (EA)',
#  '스카트 하루한장 양면수세미 설거지용 10매',
#  '스카트 하루한장 양면수세미 설거지용 10매 (EA)',
#  '스카트 하루한장 일회용 양면수세미 설거지용 10매',
#  '스카트 항균 3겹 빨아쓰는 위생행주 20매',
#  '스카트 항균 3겹 빨아쓰는 위생행주 20매 (EA)',
#  '스카트 항균 3겹 위생행주 20매',
#  '스카트 항균 빨아쓰는 행주타월 72매 (EA)',
#  '스카트 항균 클리어 핑크 빨아쓰는 행주타올 45매 x 2롤',
#  '스카트 항균 클리어 핑크 빨아쓰는 행주타월 45매 x 2롤',
#  '스카트 항균 클리어 핑크 빨아쓰는 행주타월 45매 x 2롤 (EA)',
#  '스카트 항균 클리어 핑크 행주타올 45매 x 2롤',
#  '스카트 항균 클리어 핑크 행주타월  30매',
#  '스카트 항균 클리어 핑크 행주타월  30매 (EA)',
#  '스카트 항균 프레쉬블루 빨아쓰는 행주타올 45매 X 4롤',
#  '스카트 항균 프레쉬블루 빨아쓰는 행주타월 45매 X 4롤',
#  '스카트 항균 프레쉬블루 빨아쓰는 행주타월 45매 X 4롤 (EA)',
#  '스카트 항균 프레쉬블루 행주타올 45매 X 4롤',
#  '크리넥스 3겹 데코앤소프트 27m 30롤',
#  '크리넥스 3겹 데코앤소프트 27m 30롤 X 2',
#  '크리넥스 3겹 데코앤소프트 와이드 35m 12롤',
#  '크리넥스 3겹 수프림 소프트 27m 12롤',
#  '크리넥스 3겹 수프림 소프트 30m 30롤',
#  '크리넥스 3겹 순수 소프트 27m 30롤',
#  '크리넥스 3겹 순수 소프트 27m 30롤 X 2',
#  '크리넥스 3겹 울트라클린 27m 30롤',
#  '크리넥스 3겹 울트라클린 27m 30롤 X 2',
#  '크리넥스 3겹 울트라클린 27m 30롤 X 2백',
#  '크리넥스 3겹 천연펄프 데코&소프트 와이드 화장지 35m 12롤',
#  '크리넥스 3겹 천연펄프 데코&소프트 와이드 화장지 35m 12롤 (EA)',
#  '크리넥스 3겹 천연펄프 데코&소프트 화장지 27m 30롤',
#  '크리넥스 3겹 천연펄프 데코&소프트 화장지 27m 30롤 (EA)',
#  '크리넥스 3겹 천연펄프 데코&소프트 화장지 27m 30롤 X 2',
#  '크리넥스 3겹 천연펄프 수프림소프트 화장지 27m 12롤',
#  '크리넥스 3겹 천연펄프 수프림소프트 화장지 27m 12롤 (EA)',
#  '크리넥스 3겹 천연펄프 수프림소프트 화장지 30m 30롤',
#  '크리넥스 3겹 천연펄프 수프림소프트 화장지 30m 30롤 (EA)',
#  '크리넥스 3겹 천연펄프 순수소프트 더퓨어 27m-30롤 (EA)',
#  '크리넥스 3겹 천연펄프 순수소프트 화장지 27m 30롤',
#  '크리넥스 3겹 천연펄프 순수소프트 화장지 27m 30롤 (EA)',
#  '크리넥스 3겹 천연펄프 순수소프트 화장지 27m 30롤 X 2',
#  '크리넥스 3겹 천연펄프 울트라클린 화장지 27m 30롤',
#  '크리넥스 3겹 천연펄프 울트라클린 화장지 27m 30롤 (EA)',
#  '크리넥스 3겹 천연펄프 울트라클린 화장지 27m 30롤 X 2',
#  '크리넥스 3겹 클린케어 메가롤 50m-12롤 (EA)',
#  '크리넥스 3겹 클린케어 메가롤 50m-30롤 (EA)',
#  '크리넥스 3겹 클린케어 메가롤 50m-30롤 X 2',
#  '크리넥스 + 스카트 세트',
#  '크리넥스 + 스카트 세트(2)',
#  '크리넥스 KF80 메이브리즈 황사마스크 대형 20P',
#  '크리넥스 KF80 황사용마스크 대형 2P (EA)',
#  '크리넥스 KF94 데일리 방역 마스크 화이트 대형 17P',
#  '크리넥스 KF94 데일리 방역 마스크 화이트 대형 17P (EA)',
#  '크리넥스 KF94 데일리방역마스크 블랙 대형 3P (EA)',
#  '크리넥스 KF94 방역용 마스크 베이직 대형 (1개입)',
#  '크리넥스 NEW 디럭스 미니_카카오 230매 X 6개입',
#  '크리넥스 NEW 디럭스 미니_카카오 230매 X 6개입 (EA)',
#  '크리넥스 가습 촉촉 마스크 뉴 대형 2P',
#  '크리넥스 가습 촉촉 마스크 뉴 대형 2P (EA)',
#  '크리넥스 가습촉촉 마스크 (2개입)',
#  '크리넥스 내추럴알로에로션 각티슈 150매 X 3개입',
#  '크리넥스 내추럴알로에로션 각티슈 150매 X 3개입 (EA)',
#  '크리넥스 데일리 입체마스크 블랙 대형 20P',
#  '크리넥스 데코앤소프트 클래식 27-30롤',
#  '크리넥스 데코앤소프트 클래식 27-30롤 X 2',
#  '크리넥스 도톰한 순수 3겹 35m-36롤',
#  '크리넥스 디럭스 신수성 리미티드 250매X3개입',
#  '크리넥스 마이비데 10매 x 3팩 (EA)',
#  '크리넥스 마이비데 46매 X 10팩',
#  '크리넥스 마이비데 46매x8팩 + 용기',
#  '크리넥스 마이비데 48매 X 9팩',
#  '크리넥스 마이비데 for LADY 10매 X 2팩 (EA)',
#  '크리넥스 마이비데 for Lady 캡 42매 X 9팩',
#  '크리넥스 마이비데 카카오프렌즈 포켓용 2매 X 30입 (EA)',
#  '크리넥스 마이비데 캡 64매 X 8팩',
#  '크리넥스 마이비데 캡형 42매 X 9팩 카카오프렌즈',
#  '크리넥스 마이비데 키즈 캡 42매 X 9팩',
#  '크리넥스 마이비데 키즈 캡 42매 X 9팩 + 키즈용 화장지 3겹 27m 8롤',
#  '크리넥스 마이비데 키즈 캡 60매 X 3팩 (EA)',
#  '크리넥스 메이브리즈 황사마스크 대형 (1개입)',
#  '크리넥스 메이브리즈 황사마스크 소형 (1개입)',
#  '크리넥스 메이브리즈 황사마스크 중형 (1개입)',
#  '크리넥스 버블버블 핸드워시 그린향 거품펌프형 250ml + 용기형리필 250ml X 2',
#  '크리넥스 버블버블 핸드워시 그린향 거품펌프형 250ml + 용기형리필 250ml X 2 (EA)',
#  '크리넥스 버블버블 핸드워시 그린향 용기 250ml + 리필 250ml x 2',
#  '크리넥스 버블버블 핸드워시 그린향 용기 250ml + 용기형 리필 250ml x 2',
#  '크리넥스 버블버블 핸드워시 상큼향 거품펌프형 250ml + 용기형리필 250ml X 2',
#  '크리넥스 버블버블 핸드워시 상큼향 거품펌프형 250ml + 용기형리필 250ml X 2 (EA)',
#  '크리넥스 버블버블 핸드워시 상큼향 용기 250ml + 리필 250ml x 2',
#  '크리넥스 버블버블 핸드워시 상큼향 용기 250ml + 용기형 리필 250ml x 2',
#  '크리넥스 베이비 입체 마스크 (3개입)',
#  '크리넥스 보습에센스로션 150매X3개입',
#  '크리넥스 보습에센스로션 미용티슈 150매X3개입',
#  '크리넥스 보습에센스로션 미용티슈 150매X3개입 (EA)',
#  '크리넥스 비말차단용 스타일마스크 화이트 엠보 소형 3P (EA)',
#  '크리넥스 뽑아쓰는 키친타올 140매 X 4입',
#  '크리넥스 뽑아쓰는 키친타월 140매 X 4입',
#  '크리넥스 뽑아쓰는 키친타월 140매 X 4입 (EA)',
#  '크리넥스 뽑아쓰는 키친타월 펭수에디션 140매 X 4입',
#  '크리넥스 뽑아쓰는 키친타월 펭수에디션 140매 X 4입 (EA)',
#  '크리넥스 수앤수 코튼클린 오리지널 캡형 88매 X 3',
#  '크리넥스 수앤수 코튼클린 오리지널 캡형 88매 X 3 (EA)',
#  '크리넥스 수앤수 코튼클린 플러스 캡형 72매 X 3',
#  '크리넥스 수앤수 코튼클린 플러스 캡형 72매 X 3 (EA)',
#  '크리넥스 수프림 소프트 27m 30롤',
#  '크리넥스 순수 3겹 소프트 27m-30롤',
#  '크리넥스 순수 3겹 소프트 27m-30롤 X 2',
#  '크리넥스 스타일 마스크 블랙 대형 3P',
#  '크리넥스 스타일 마스크 블랙 대형 3P (EA)',
#  '크리넥스 스타일마스크 그레이 대형 3P',
#  '크리넥스 스타일마스크 그레이 대형 3P (EA)',
#  '크리넥스 스타일마스크 네이비 대형 3P',
#  '크리넥스 스타일마스크 버건디 대형 3P',
#  '크리넥스 스타일마스크 블랙 대형 3P (EA)',
#  '크리넥스 스타일마스크 블랙 어린이용 3P',
#  '크리넥스 스타일마스크 블랙 중형 3P',
#  '크리넥스 스타일마스크 어린이용 블랙 3P (EA)',
#  '크리넥스 실크소프트 250매 X 3개입',
#  '크리넥스 실크소프트 250매 X 3개입 (EA)',
#  '크리넥스 실크소프트 250매X3개입 + 60매(보너스)',
#  '크리넥스 안심 손소독제겔 250ml',
#  '크리넥스 안심 손소독제겔 250ml (EA)',
#  '크리넥스 안심 슈퍼 프리미엄 파워 3겹 키친타올 55매 X 2롤',
#  '크리넥스 안심 클래식 키친타올 120매 X 4롤',
#  '크리넥스 안심 클래식 키친타올 140매 X 12롤',
#  '크리넥스 안심 클래식 키친타월 140매 X 12롤',
#  '크리넥스 안심 클래식 키친타월 140매 X 12롤 (EA)',
#  '크리넥스 안심 키친타월 120매 X 4롤',
#  '크리넥스 안심 키친타월 120매 X 4롤 (EA)',
#  '크리넥스 안심 프리미엄 3겹 키친타올 140매 X 4롤',
#  '크리넥스 안심 프리미엄 3겹 키친타월 140매 X 4롤',
#  '크리넥스 안심 프리미엄 3겹 키친타월 140매 X 4롤 (EA)',
#  '크리넥스 안심물티슈 포켓용 2매 X 30입 (EA)',
#  '크리넥스 여행용 호호바수딩로션 펭수 50매 (컬러랜덤발송) (EA)',
#  '크리넥스 여행용티슈 대한민국 70매 (랜덤발송) (EA)',
#  '크리넥스 여행용티슈 대한민국 70매 X 8 (랜덤발송)',
#  '크리넥스 여행용티슈 카카오프렌즈 70매 X 3개입',
#  '크리넥스 여행용티슈 카카오프렌즈 70매 X 3개입 (EA)',
#  '크리넥스 카카오 프렌즈 건강 마스크 어린이용 (5개입)',
#  '크리넥스 카카오 프렌즈 건강 마스크 어린이용 (5개입) (EA)',
#  '크리넥스 카카오 프렌즈 입체 마스크 성인용(3개입)',
#  '크리넥스 카카오 프렌즈 입체 마스크 어린이용 (3개입)',
#  '크리넥스 카카오 프렌즈 입체 마스크 어린이용 (3개입) (EA)',
#  '크리넥스 카카오 프렌즈 입체마스크 3D 베이비용 (3개입)',
#  '크리넥스 카카오 프렌즈 입체마스크 3D 어린이 (3개입)',
#  '크리넥스 카카오프렌즈 입체마스크 3D 성인용 3P',
#  '크리넥스 카카오프렌즈 입체마스크 3D 성인용 3P (EA)',
#  '크리넥스 칼로리라이트 키친타월 55매 X 3롤',
#  '크리넥스 칼로리라이트 키친타월 55매 X 3롤 (EA)',
#  '크리넥스 코편한 티슈 60매',
#  '크리넥스 코편한티슈 60매',
#  '크리넥스 코편한티슈 60매 (EA)',
#  '크리넥스 콧물전용 물티슈 20매',
#  '크리넥스 콧물전용 물티슈 20매 (EA)',
#  '크리넥스 클래식 180매 X 8개입',
#  '크리넥스 클래식 180매 X 8개입 (EA)',
#  '크리넥스 키즈용화장지 27m 8롤 + 마이비데 키즈캡 42매 x 4개',
#  '크리넥스 프렌즈 버블핸드워시 그린향 200ml 리필',
#  '크리넥스 프렌즈 버블핸드워시 그린향 250ml 용기',
#  '크리넥스 프렌즈 버블핸드워시 상큼향 200ml 리필',
#  '크리넥스 프렌즈 버블핸드워시 상큼향 250ml 용기',
#  '크리넥스 프렌즈 버블핸드워시 스윗향 200ml 리필',
#  '크리넥스 프렌즈 버블핸드워시 스윗향 250ml 용기',
#  '크리넥스 호호바수딩로션 펭수 180매 X 3개입 (EA)',
#  '크리넥스 호호바수딩로션 펭수 180매 X 6개입 (EA)',
#  '크리넥스 황사마스크 뉴디자인플러스 대형 3P',
#  '크리넥스 황사마스크 뉴디자인플러스 소형 3P',
#  '크리넥스 황사용 마스크 플러스 대형10P',
#  '크리넥스/스카트 세트',
#  '크리넥스？키즈용？화장지？3겹？27m 8롤',
#  '[2018년 신제품]그린핑거 인텐시브 투명 선밤 15g',
#  '[2018년 신제품]그린핑거 퓨어 클렌징 워터 200ml',
#  '[2020년 3월 신제품] 그린핑거 손 소독제 겔 350 ml',
#  '[2020년 3월 신제품] 그린핑거 손 소독제 겔 350 ml (EA)',
#  '[2020년 3월 신제품] 그린핑거 자두야에디션 손 소독제 겔 350ml',
#  '그린핑거 내추럴 수딩 젤로션100ml (애프터 선)',
#  '그린핑거 내추럴 수딩젤로션 100ml',
#  '그린핑거 내추럴 수딩젤로션 100ml (EA)',
#  '그린핑거 내추럴 수딩젤로션 120ml',
#  '그린핑거 내추럴 수딩젤로션 120ml (EA)',
#  '그린핑거 네이처메이드 베이비 로션 230ml',
#  '그린핑거 네이처메이드 베이비 로션 230ml (EA)',
#  '그린핑거 네이처메이드 베이비 샴푸&워시 230ml',
#  '그린핑거 네이처메이드 베이비 샴푸&워시 230ml (EA)',
#  '그린핑거 네이처메이드 베이비 크림 95g',
#  '그린핑거 네이처메이드 베이비 크림 95g (EA)',
#  '그린핑거 마이키즈 + 자두야에디션 세트',
#  '그린핑거 마이키즈 + 힘센보습 세트',
#  '그린핑거 마이키즈 거품샴푸 320ml',
#  '그린핑거 마이키즈 거품워시 320ml',
#  '그린핑거 마이키즈 로션 260ml',
#  '그린핑거 마이키즈 로션 260ml (EA)',
#  '그린핑거 마이키즈 로션 260ml + 워시 320ml',
#  '그린핑거 마이키즈 로션 330ml(대용량) + 워시 500ml(대용량)',
#  '그린핑거 마이키즈 로션 대용량 330ml',
#  '그린핑거 마이키즈 로션 대용량 330ml (EA)',
#  '그린핑거 마이키즈 로션 프레쉬 320ml',
#  '그린핑거 마이키즈 로션 프레쉬 대용량 1000ml',
#  '그린핑거 마이키즈 로션프레쉬 1000ml',
#  '그린핑거 마이키즈 샴푸 320ml',
#  '그린핑거 마이키즈 샴푸 320ml (EA)',
#  '그린핑거 마이키즈 샴푸 320ml + 훼이셜솝 160ml',
#  '그린핑거 마이키즈 샴푸 대용량 500ml',
#  '그린핑거 마이키즈 샴푸 대용량 500ml (EA)',
#  '그린핑거 마이키즈 샴푸 프레쉬 대용량 1000ml',
#  '그린핑거 마이키즈 샴푸 프레쉬 대용량 1000ml (EA)',
#  '그린핑거 마이키즈 세트',
#  '그린핑거 마이키즈 얼굴로션 160ml',
#  '그린핑거 마이키즈 얼굴로션 160ml (EA)',
#  '그린핑거 마이키즈 워시 320ml',
#  '그린핑거 마이키즈 워시 320ml (EA)',
#  '그린핑거 마이키즈 워시 500ml(대용량) + 샴푸 500ml(대용량)',
#  '그린핑거 마이키즈 워시 대용량 500ml',
#  '그린핑거 마이키즈 워시 대용량 500ml (EA)',
#  '그린핑거 마이키즈 워시 프레쉬 대용량 1000ml',
#  '그린핑거 마이키즈 워시 프레쉬 대용량 1000ml (EA)',
#  '그린핑거 마이키즈 자두야에디션 로션 프레쉬 320ml',
#  '그린핑거 마이키즈 자두야에디션 로션 프레쉬 320ml (EA)',
#  '그린핑거 마이키즈 자두야에디션 샴푸 프레쉬 320ml',
#  '그린핑거 마이키즈 자두야에디션 샴푸 프레쉬 320ml (EA)',
#  '그린핑거 마이키즈 자두야에디션 워시 프레쉬 320ml',
#  '그린핑거 마이키즈 자두야에디션 워시 프레쉬 320ml (EA)',
#  '그린핑거 마이키즈 자두야에디션 촉촉 립밤(딸기향)',
#  '그린핑거 마이키즈 자두야에디션 촉촉 립밤(사과향)',
#  '그린핑거 마이키즈 자두야에디션 촉촉 립밤(사과향) (EA)',
#  '그린핑거 마이키즈 자두야에디션 핸드워시 그린 300ml',
#  '그린핑거 마이키즈 자두야에디션 핸드워시 스윗 300ml',
#  '그린핑거 마이키즈 자두야에디션 핸드워시 프레쉬 300ml',
#  '그린핑거 마이키즈 크림 200ml',
#  '그린핑거 마이키즈 크림 200ml + 워시 320ml + 샴푸 320ml',
#  '그린핑거 마이키즈 크림 200ml X 2',
#  '그린핑거 마이키즈 크림 300ml',
#  '그린핑거 마이키즈 크림 300ml (EA)',
#  '그린핑거 마이키즈 항균 핸드워시 거품형 350ml(대용량) + 리필 300ml',
#  '그린핑거 마이키즈 항균 핸드워시 리필 300ml',
#  '그린핑거 마이키즈 훼이셜솝 160ml',
#  '그린핑거 마이키즈 훼이셜솝 160ml + 로션 330ml(대용량)',
#  '그린핑거 베이비 세라마이드 로션 180g',
#  '그린핑거 베이비 세라마이드 미네랄 선팩트 15g',
#  '그린핑거 베이비 세라마이드 미네랄팩트 리필 15g',
#  '그린핑거 베이비 세라마이드 세트',
#  '그린핑거 베이비 세라마이드 수딩젤 로션 100ml',
#  '그린핑거 베이비 세라마이드 수딩젤 로션 100ml (EA)',
#  '그린핑거 베이비 세라마이드 수딩젤 로션 200ml',
#  '그린핑거 베이비 세라마이드 워시 250ml',
#  '그린핑거 베이비 세라마이드 워시 250ml + 세라마이드 크림 150g',
#  '그린핑거 베이비 세라마이드 크림 150g',
#  '그린핑거 베이비 세라마이드 크림 150g X 2',
#  '그린핑거 베이비 세라마이드 훼이셜로션 80g',
#  '그린핑거 세라마이드 미네랄 선로션 80ml',
#  '그린핑거 세라마이드 미네랄 선로션 80ml (EA)',
#  '그린핑거 손 소독제 겔 30ml X 2입 (휴대용) (EA)',
#  '그린핑거 시그니처 물티슈 캡형 64매 x 6팩',
#  '그린핑거 알로에베라 물티슈 캡형 64매 X 6팩',
#  '그린핑거 야외놀이 선로션 80ml',
#  '그린핑거 야외놀이 선로션 80ml (EA)',
#  '그린핑거 야외놀이 선크림 80ml',
#  '그린핑거 야외놀이 선크림 80ml (EA)',
#  '그린핑거 야외놀이 선크림80ml X2 + 내추럴 수딩 젤로션100ml + 마이키즈 여행용 샘플(랜덤 1종)',
#  '그린핑거 야외놀이 선크림80ml X2 + 내추럴 수딩 젤로션100ml + 마이키즈 여행용 샘플(랜덤 1종) (EA)',
#  '그린핑거 야외놀이 선크림 100ml',
#  '그린핑거 야외놀이 선크림 100ml (EA)',
#  '그린핑거 야외놀이 선크림 100ml + 퓨어 클렌징 티슈 캡 30매X3팩+ 퓨어 클렌징 워터 200ml + 내추럴 수딩 젤로션 100ml',
#  '그린핑거 인텐시브 선밤 15g',
#  '그린핑거 인텐시브 선밤 15g (EA)',
#  '그린핑거 인텐시브 선밤 (투명) 15g',
#  '그린핑거 인텐시브 선밤 (투명) 15g (EA)',
#  '그린핑거 인텐시브 선밤 (투명) 20g',
#  '그린핑거 인텐시브 선밤 (투명) 20g (EA)',
#  '그린핑거 인텐시브 투명 선밤 15g',
#  '그린핑거 인텐시브 투명 선밤20g + 마이키즈 얼굴로션160ml + 마이키즈 여행용 샘플(랜덤1종)',
#  '그린핑거 인텐시브 투명 선밤20g X2 + 내츄럴 수딩 젤로션120ml + 마이키즈 여행용 샘플(랜덤1종)',
#  '그린핑거 자두야에디션 손 소독제 겔 30ml X 2입 (휴대용)',
#  '그린핑거 자두야에디션 손 소독제 겔 350ml',
#  '그린핑거 자두야에디션 촉촉 선쿠션 12g',
#  '그린핑거 자두야에디션 촉촉 선쿠션 12g (EA)',
#  '그린핑거 촉촉 선팩트16g',
#  '그린핑거 촉촉 선팩트 16g',
#  '그린핑거 촉촉 선팩트 16g (EA)',
#  '그린핑거 촉촉 선팩트 16g + 리필 16g',
#  '그린핑거 촉촉 선팩트 16g + 촉촉 선팩트 리필 16g + 야외놀이 선로션 80ml + 퓨어 클렌징 티슈 캡30매',
#  '그린핑거 촉촉 선팩트16g + 촉촉 선팩트 리필16g + 퓨어 클렌징 워터200ml + 마이키즈 여행용 샘플(랜덤 1종) (EA)',
#  '그린핑거 촉촉 선팩트 리필 16g',
#  '그린핑거 촉촉 선팩트 리필 16g (EA)',
#  '그린핑거 촉촉한 자연보습 거품워시 320ml',
#  '그린핑거 촉촉한 자연보습 거품워시 320ml (EA)',
#  '그린핑거 촉촉한 자연보습 거품워시 320ml + 그린핑거 촉촉한 자연보습 워시 320ml',
#  '그린핑거 촉촉한 자연보습 로션 320ml',
#  '그린핑거 촉촉한 자연보습 로션 320ml (EA)',
#  '그린핑거 촉촉한 자연보습 로션 320ml X2',
#  '그린핑거 촉촉한 자연보습 비누 80g x 2개입',
#  '그린핑거 촉촉한 자연보습 비누 80g x 2개입 (EA)',
#  '그린핑거 촉촉한 자연보습 샴푸 320ml',
#  '그린핑거 촉촉한 자연보습 샴푸 320ml (EA)',
#  '그린핑거 촉촉한 자연보습 울트라크림 300g',
#  '그린핑거 촉촉한 자연보습 울트라크림 300g + 힘센보습 울트라 워시 300ml + 울트라 샴푸 300ml',
#  '그린핑거 촉촉한 자연보습 울트라크림 300g X 2',
#  '그린핑거 촉촉한 자연보습 워시 320ml',
#  '그린핑거 촉촉한 자연보습 워시 320ml (EA)',
#  '그린핑거 판테딘 로션 230ml + 탑투토워시 40ml + 크림 40ml (EA)',
#  '그린핑거 판테딘 물티슈 캡형 50매X3팩 (EA)',
#  '그린핑거 판테딘 수딩젤 150ml + 탑투토워시 40ml (EA)',
#  '그린핑거 판테딘 크림 200ml + 로션 40ml + 탑투토워시 40ml (EA)',
#  '그린핑거 판테딘 탑투토워시 230ml + 탑투토워시 40ml + 로션 40ml (EA)',
#  '그린핑거 퓨어 클렌징 워터 200ml',
#  '그린핑거 퓨어 클렌징 워터 200ml (EA)',
#  '그린핑거 퓨어클렌징 티슈 캡30매',
#  '그린핑거 퓨어클렌징 티슈 캡30매 (EA)',
#  '그린핑거 프레쉬 마일드 선스틱 15g',
#  '그린핑거 프레쉬 마일드 선스틱 15g (EA)',
#  '그린핑거 프레쉬 마일드 선쿠션 12g',
#  '그린핑거 프레쉬 마일드 선쿠션 12g (EA)',
#  '그린핑거 프레쉬 선젤 80ml',
#  '그린핑거 힘센 보습 울트라크림 300g',
#  '그린핑거 힘센 보습 울트라크림 300g X 2',
#  '그린핑거 힘센보습 울트라 로션 260ml',
#  '그린핑거 힘센보습 울트라 로션 260ml (EA)',
#  '그린핑거 힘센보습 울트라 샴푸 300ml',
#  '그린핑거 힘센보습 울트라 샴푸 300ml (EA)',
#  '그린핑거 힘센보습 울트라 워시 300ml',
#  '그린핑거 힘센보습 울트라 워시 300ml (EA)',
#  '그린핑거 힘센보습 울트라 크리미오일 180ml',
#  '그린핑거 힘센보습 울트라 크리미오일 180ml (EA)',
#  '그린핑거 힘센보습 울트라크림 300g',
#  '그린핑거 힘센보습 울트라크림 300g (EA)',
#  '그린핑거 힘센보습 울트라크림 300g X 2',
#  '티엔 AC 매끈 진정 시트 마스크(7매) (EA)',
#  '티엔 촉촉 클렌징 티슈 (30매) (EA)',
#  '티엔 촉촉 클렌징 폼 100ml (EA)',
#  '디펜드 맘스 안심 팬티 8개입 (EA)',
#  '디펜드 맘스 안심패드 30개입 (EA)',
#  '디펜드 스타일 라이너 여성용 무향 롱 168매',
#  '디펜드 안심케어 매직테이프 대형 80매',
#  '[9/9발송예약판매] 2020 하기스 매직 컴포트 3단계 공용 180매',
#  '[9/9발송예약판매] 2020 하기스 매직 컴포트 4단계 공용 150매',
#  '[2019년형] 하기스 에어솔솔 썸머기저귀 3단계 공용 144매(밴드형)',
#  '[2019년형] 하기스 에어솔솔 썸머기저귀 3단계 공용 144매(밴드형) + 물놀이팬티 3단계 공용 10매 (팬티형)',
#  '[2019년형] 하기스 에어솔솔 썸머기저귀 4단계 공용 120매(밴드형)',
#  '[2019년형] 하기스 에어솔솔 썸머기저귀 4단계 공용 120매(밴드형) + 물놀이팬티 4단계 공용 10매 (팬티형)',
#  '[모닛X하기스] 스마트 베이비 모니터',
#  '[신규회원 한정특가] 하기스 맥스드라이 2단계 공용 52매(밴드형)',
#  '[쿠폰적용가23,490원] 하기스 네이처메이드 이른둥이기저귀 중형 150매(밴드형)',
#  '[쿠폰적용가32,280원] 하기스 맥스드라이 2단계 공용 156매(밴드형)',
#  '[쿠폰적용가32,280원] 하기스 맥스드라이 3단계 공용 132매(밴드형)',
#  '[쿠폰적용가32,280원] 하기스 맥스드라이 4단계 공용 108매(밴드형)',
#  '[쿠폰적용가36,400원] 하기스 네이처메이드 1단계 공용 186매(밴드형)',
#  '[쿠폰적용가36,400원] 하기스 네이처메이드 2단계 남아 156매(밴드형)',
#  '[쿠폰적용가36,400원] 하기스 네이처메이드 2단계 여아 156매(밴드형)',
#  '[쿠폰적용가36,400원] 하기스 네이처메이드 3단계 남아 132매(밴드형)',
#  '[쿠폰적용가36,400원] 하기스 네이처메이드 3단계 여아 132매(밴드형)',
#  '[쿠폰적용가36,400원] 하기스 네이처메이드 4단계 남아 108매(밴드형)',
#  '[쿠폰적용가36,400원] 하기스 네이처메이드 4단계 여아 108매(밴드형)',
#  '[쿠폰적용가37,490원] 하기스 매직핏 기저귀 1단계 공용 210매(밴드형)',
#  '[쿠폰적용가37,490원] 하기스 매직핏 꿀벅지 아기용 기저귀 2단계 공용 192매(밴드형)',
#  '[쿠폰적용가37,490원] 하기스 매직핏기저귀 2단계 공용 192매(밴드형)',
#  '[쿠폰적용가42,680원] 하기스 매직핏 꿀벅지 아기용 기저귀 3단계 공용 198매(밴드형)',
#  '[쿠폰적용가42,680원] 하기스 매직핏기저귀 3단계 공용 198매(밴드형)',
#  '[쿠폰적용가42,680원] 하기스 매직핏기저귀 4단계 공용 162매(밴드형)',
#  '[쿠폰적용가42,680원] 하기스 매직핏기저귀 5단계 공용 138매(밴드형)',
#  '[핑크퐁] 아기상어 입체 아쿠아슈즈',
#  '[핑크퐁] 핑크퐁 1도 쿨토시',
#  '[핑크퐁] 핑크퐁 상어가족 바스타올',
#  '[핑크퐁] 핑크퐁 상어가족 차량용 햇빛가리개 (2중암막)',
#  '[핑크퐁] 핑크퐁 샴푸캡',
#  '[핑크퐁] 핑크퐁 손잡이컵 세트',
#  '[핑크퐁] 핑크퐁 스텐 논슬립 손잡이 공기',
#  '[핑크퐁] 핑크퐁 스텐 논슬립 컵',
#  '[핑크퐁] 핑크퐁 아기상어 손가락 안전 보호대',
#  '[핑크퐁] 핑크퐁 아기상어 쿨토시',
#  '[핑크퐁] 핑크퐁 아기상어 피규어 샤워볼',
#  '[핑크퐁] 핑크퐁 에디슨 흘림방지 양손 빨대컵(블루)',
#  '[핑크퐁] 핑크퐁 에디슨 흘림방지 양손 빨대컵(핑크)',
#  '[핑크퐁] 핑크퐁 영어놀이 차량용 햇빛가리개 (3중암막)',
#  '[핑크퐁] 핑크퐁 튜브 아쿠아슈즈',
#  '[핑크퐁] 핑크퐁 한글놀이 차량용 햇빛가리개 (3중암막)',
#  '2020 하기스 매직 컴포트 1단계 공용 264매',
#  '2020 하기스 매직 컴포트 1단계 공용 264매(밴드형)',
#  '2020 하기스 매직 컴포트 1단계 공용 264매(밴드형) X2',
#  '2020 하기스 매직 컴포트 1단계 공용 264매(밴드형) X3',
#  '2020 하기스 매직 컴포트 2단계 공용 246매',
#  '2020 하기스 매직 컴포트 2단계 공용 246매(밴드형)',
#  '2020 하기스 매직 컴포트 2단계 공용 246매(밴드형) X2',
#  '2020 하기스 매직 컴포트 2단계 공용 246매(밴드형) X3',
#  '2020 하기스 매직 컴포트 3단계 공용 180매(밴드형)',
#  '2020 하기스 매직 컴포트 3단계 공용 180매(밴드형) X2',
#  '2020 하기스 매직 컴포트 3단계 공용 180매(밴드형) X3',
#  '2020 하기스 매직 컴포트 4단계 공용 150매(밴드형)',
#  '2020 하기스 매직 컴포트 4단계 공용 150매(밴드형) X2',
#  '2020 하기스 매직 컴포트 4단계 공용 150매(밴드형) X3',
#  '2020 하기스 매직 컴포트 5단계 공용 126매(밴드형)',
#  '2020 하기스 매직 컴포트 5단계 공용 126매(밴드형) X2',
#  '2020 하기스 매직 컴포트 5단계 공용 126매(밴드형) X3',
#  '2020 하기스 맥스드라이 3단계 공용 132매(밴드형)',
#  '2020 하기스 보송보송 2단계 공용 228매(밴드형)',
#  '2020 하기스 보송보송 3단계 공용 186매(밴드형)',
#  '2020 하기스 보송보송 4단계 공용 156매(밴드형)',
#  '2020 하기스 보송보송 5단계 공용 138매(밴드형)',
#  'NEW 하기스 네이처메이드 1단계 공용 186매(밴드형)',
#  'NEW 하기스 네이처메이드 1단계 공용 186매(밴드형) X2',
#  'NEW 하기스 네이처메이드 1단계 공용 186매(밴드형) X3',
#  'NEW 하기스 네이처메이드 2단계 남아 156매(밴드형)',
#  'NEW 하기스 네이처메이드 2단계 남아 156매(밴드형) X2',
#  'NEW 하기스 네이처메이드 2단계 남아 156매(밴드형) X3',
#  'NEW 하기스 네이처메이드 2단계 남아 세트',
#  'NEW 하기스 네이처메이드 2단계 여아 156매(밴드형)',
#  'NEW 하기스 네이처메이드 2단계 여아 156매(밴드형) X2',
#  'NEW 하기스 네이처메이드 2단계 여아 세트',
#  'NEW 하기스 네이처메이드 3단계 남아 132매(밴드형)',
#  'NEW 하기스 네이처메이드 3단계 남아 132매(밴드형) X2',
#  'NEW 하기스 네이처메이드 3단계 여아 132매(밴드형)',
#  'NEW 하기스 네이처메이드 3단계 여아 132매(밴드형) X2',
#  'NEW 하기스 네이처메이드 3단계 여아 132매(밴드형) X3',
#  'NEW 하기스 네이처메이드 4단계 남아 108매(밴드형)',
#  'NEW 하기스 네이처메이드 4단계 남아 108매(밴드형) X2',
#  'NEW 하기스 네이처메이드 4단계 남아 108매(밴드형) X3',
#  'NEW 하기스 네이처메이드 4단계 여아 108매(밴드형)',
#  'NEW 하기스 네이처메이드 4단계 여아 108매(밴드형) X2',
#  'NEW 하기스 네이처메이드 4단계 여아 108매(밴드형) X3',
#  'NEW 하기스 네이처메이드 5단계 남아 92매(밴드형)',
#  'NEW 하기스 네이처메이드 5단계 남아 92매(밴드형) X2',
#  'NEW 하기스 네이처메이드 5단계 여아 92매(밴드형)',
#  'NEW 하기스 네이처메이드 5단계 여아 92매(밴드형) X2',
#  'NEW 하기스 네이처메이드 이른둥이기저귀 소형 150매(밴드형)',
#  'NEW 하기스 네이처메이드 이른둥이기저귀 중형 150매(밴드형)',
#  'NEW 하기스 맥스드라이 1단계 공용 186매(밴드형)',
#  'NEW 하기스 맥스드라이 2단계 공용 156매(밴드형)',
#  'NEW 하기스 맥스드라이 2단계 공용 156매(밴드형) X2',
#  'NEW 하기스 맥스드라이 2단계 공용 156매(밴드형) X3',
#  'NEW 하기스 맥스드라이 3단계 공용 132매(밴드형)',
#  'NEW 하기스 맥스드라이 3단계 공용 132매(밴드형) X2',
#  'NEW 하기스 맥스드라이 3단계 공용 132매(밴드형) X3',
#  'NEW 하기스 맥스드라이 4단계 공용 108매(밴드형)',
#  'NEW 하기스 맥스드라이 4단계 공용 108매(밴드형) X 2',
#  'NEW 하기스 맥스드라이 4단계 공용 108매(밴드형) X3',
#  'NEW 하기스 맥스드라이 5단계 공용 92매(밴드형)',
#  'NEW 하기스 맥스드라이 5단계 공용 92매(밴드형) X 2',
#  'NEW 하기스 맥스드라이 5단계 공용 92매(밴드형) X3',
#  '그린핑거 기저귀 3단계 공용 132매(밴드형)',
#  '그린핑거 기저귀 3단계 공용 132매(밴드형) X2',
#  '그린핑거 기저귀 4단계 공용 92매(팬티형)',
#  '그린핑거 기저귀 4단계 공용 108매(밴드형)',
#  '그린핑거 기저귀 5단계 공용 76매(팬티형)',
#  '그린핑거 기저귀 6단계 공용 62매(팬티형)',
#  '스마트 프리미엄 멤버십 가입선물',
#  '하기스 NEW 네이처메이드 썸머 2단계 공용 140매(밴드형)',
#  '하기스 NEW 네이처메이드 썸머 2단계 공용 140매(밴드형) X 2',
#  '하기스 NEW 네이처메이드 썸머 3단계 공용 120매(밴드형)',
#  '하기스 NEW 네이처메이드 썸머 3단계 공용 120매(밴드형)  X 2',
#  '하기스 NEW 네이처메이드 썸머 3단계 공용 120매(밴드형)  X 3',
#  '하기스 NEW 네이처메이드 썸머 4단계 공용 96매(밴드형)',
#  '하기스 NEW 네이처메이드 썸머 4단계 공용 96매(밴드형) X 2',
#  '하기스 NEW 네이처메이드 썸머 4단계 공용 96매(밴드형) X 3',
#  '하기스 네이처메이드 1단계 공용 186매(밴드형)',
#  '하기스 네이처메이드 1단계 공용 186매(밴드형) X2',
#  '하기스 네이처메이드 1단계 공용 186매(밴드형) X3',
#  '하기스 네이처메이드 2단계 남아 156매(밴드형)',
#  '하기스 네이처메이드 2단계 남아 156매(밴드형) X3',
#  '하기스 네이처메이드 2단계 여아 156매(밴드형)',
#  '하기스 네이처메이드 2단계 여아 156매(밴드형) X2',
#  '하기스 네이처메이드 2단계 여아 156매(밴드형) X3',
#  '하기스 네이처메이드 3단계 남아 132매(밴드형)',
#  '하기스 네이처메이드 3단계 남아 132매(밴드형) X2',
#  '하기스 네이처메이드 3단계 남아 132매(밴드형) X3',
#  '하기스 네이처메이드 3단계 여아 132매(밴드형)',
#  '하기스 네이처메이드 3단계 여아 132매(밴드형) X2',
#  '하기스 네이처메이드 3단계 여아 132매(밴드형) X3',
#  '하기스 네이처메이드 4단계 남아 108매(밴드형)',
#  '하기스 네이처메이드 4단계 남아 108매(밴드형) X2',
#  '하기스 네이처메이드 4단계 남아 108매(밴드형) X3',
#  '하기스 네이처메이드 4단계 여아 108매(밴드형)',
#  '하기스 네이처메이드 4단계 여아 108매(밴드형) X2',
#  '하기스 네이처메이드 4단계 여아 108매(밴드형) X3',
#  '하기스 네이처메이드 5단계 남아 92매(밴드형)',
#  '하기스 네이처메이드 5단계 남아 92매(밴드형) X2',
#  '하기스 네이처메이드 5단계 남아 92매(밴드형) X3',
#  '하기스 네이처메이드 5단계 여아 92매(밴드형)',
#  '하기스 네이처메이드 5단계 여아 92매(밴드형) X2',
#  '하기스 네이처메이드 5단계 여아 92매(밴드형) X3',
#  '하기스 네이처메이드 남아 세트',
#  '하기스 네이처메이드 밤부 1단계 공용 186매(밴드형)',
#  '하기스 네이처메이드 밤부 1단계 공용 186매(밴드형) X3',
#  '하기스 네이처메이드 밤부 2단계 남아 156매(밴드형)',
#  '하기스 네이처메이드 밤부 2단계 남아 156매(밴드형) X3',
#  '하기스 네이처메이드 밤부 2단계 여아 156매(밴드형)',
#  '하기스 네이처메이드 밤부 2단계 여아 156매(밴드형) X2',
#  '하기스 네이처메이드 밤부 2단계 여아 156매(밴드형) X3',
#  '하기스 네이처메이드 밤부 3단계 남아 144매(밴드형)',
#  '하기스 네이처메이드 밤부 3단계 남아 144매(밴드형) X2',
#  '하기스 네이처메이드 밤부 3단계 남아 144매(밴드형) X 3',
#  '하기스 네이처메이드 밤부 3단계 여아 144매(밴드형)',
#  '하기스 네이처메이드 밤부 3단계 여아 144매(밴드형) X2',
#  '하기스 네이처메이드 밤부 3단계 여아 144매(밴드형) X 3',
#  '하기스 네이처메이드 밤부 4단계 남아 120매(밴드형)',
#  '하기스 네이처메이드 밤부 4단계 남아 120매(밴드형) X2',
#  '하기스 네이처메이드 밤부 4단계 여아 120매(밴드형)',
#  '하기스 네이처메이드 밤부 4단계 여아 120매(밴드형) X2',
#  '하기스 네이처메이드 밤부 4단계 여아 120매(밴드형) X 3',
#  '하기스 네이처메이드 밤부 5단계 남아 102매(밴드형)',
#  '하기스 네이처메이드 밤부 5단계 남아 102매(밴드형) X2',
#  '하기스 네이처메이드 밤부 5단계 여아 102매(밴드형)',
#  '하기스 네이처메이드 밤부 5단계 여아 102매(밴드형) X2',
#  '하기스 네이처메이드 여아 세트',
#  '하기스 네이처메이드 오가닉 1단계 공용 180매(밴드형)',
#  '하기스 네이처메이드 오가닉 1단계 공용 180매(밴드형) X2',
#  '하기스 네이처메이드 오가닉 2단계 남아 150매(밴드형)',
#  '하기스 네이처메이드 오가닉 2단계 남아 150매(밴드형) X2',
#  '하기스 네이처메이드 오가닉 2단계 여아 150매(밴드형)',
#  '하기스 네이처메이드 오가닉 2단계 여아 150매(밴드형) X2',
#  '하기스 네이처메이드 오가닉 3단계 남아 128매(밴드형)',
#  '하기스 네이처메이드 오가닉 3단계 남아 128매(밴드형) X2',
#  '하기스 네이처메이드 오가닉 3단계 여아 128매(밴드형)',
#  '하기스 네이처메이드 오가닉 3단계 여아 128매(밴드형) X2',
#  '하기스 네이처메이드 오가닉 4단계 남아 104매(밴드형)',
#  '하기스 네이처메이드 오가닉 4단계 남아 104매(밴드형) X2',
#  '하기스 네이처메이드 오가닉 4단계 여아 104매(밴드형)',
#  '하기스 네이처메이드 오가닉 4단계 여아 104매(밴드형) X2',
#  '하기스 네이처메이드 이른둥이기저귀 소형 150매(밴드형)',
#  '하기스 네이처메이드 이른둥이기저귀 중형 150매(밴드형)',
#  '하기스 네이처메이드 팬티 4단계 여아 96매(팬티형) X2',
#  '하기스 매직핏 기저귀 1단계 공용 210매(밴드형)',
#  '하기스 매직핏 꿀벅지 아기용 기저귀 2단계 공용 192매(밴드형)',
#  '하기스 매직핏 꿀벅지 아기용 기저귀 3단계 공용 198매(밴드형)',
#  '하기스 매직핏기저귀 2단계 공용 192매(밴드형)',
#  '하기스 매직핏기저귀 3단계 공용 198매(밴드형)',
#  '하기스 매직핏기저귀 4단계 공용 162매(밴드형)',
#  '하기스 매직핏기저귀 5단계 공용 138매(밴드형)',
#  '하기스 맥스드라이 1단계 공용 186매(밴드형)',
#  '하기스 맥스드라이 2단계 공용 156매(밴드형)',
#  '하기스 맥스드라이 2단계 공용 156매(밴드형) X2',
#  '하기스 맥스드라이 2단계 공용 156매(밴드형) X3',
#  '하기스 맥스드라이 3단계 공용 120매(밴드형)',
#  '하기스 맥스드라이 3단계 공용 132매(밴드형)',
#  '하기스 맥스드라이 3단계 공용 132매(밴드형) X2',
#  '하기스 맥스드라이 3단계 공용 132매(밴드형) X3',
#  '하기스 맥스드라이 4단계 공용 108매(밴드형)',
#  '하기스 맥스드라이 4단계 공용 108매(밴드형) X2',
#  '하기스 맥스드라이 4단계 공용 108매(밴드형) X3',
#  '하기스 맥스드라이 5단계 공용 92매(밴드형)',
#  '하기스 맥스드라이 5단계 공용 92매(밴드형) X2',
#  '하기스 맥스드라이 5단계 공용 92매(밴드형) X3',
#  '하기스 보송보송 2단계 공용 228매(밴드형)',
#  '하기스 보송보송 3단계 공용 186매(밴드형)',
#  '하기스 보송보송 4단계 공용 156매(밴드형)',
#  '하기스 보송보송 5단계 공용 138매(밴드형)',
#  '하기스 샘플러 3단계 공용 (밴드형/매직 컴포트+맥스드라이)',
#  '하기스 에어솔솔 기저귀 3단계 공용 144매(밴드형)',
#  '하기스 에어솔솔 기저귀 4단계 공용 120매(밴드형)',
#  '하기스 에어솔솔 썸머기저귀 3단계 공용 120매(밴드형)',
#  '하기스 에어솔솔 썸머기저귀 3단계 공용 144매(밴드형)',
#  '하기스 에어솔솔 썸머기저귀 3단계 공용 144매(밴드형) X 2 + 매직핏팬티4단계남아60p증정',
#  '하기스 에어솔솔 썸머기저귀 3단계 공용 144매(밴드형) X 2 + 매직핏팬티4단계여아60p증정',
#  '하기스 에어솔솔 썸머기저귀 4단계 공용 120매(밴드형)',
#  '하기스 에어솔솔 썸머기저귀 4단계 공용 120매(밴드형) X 2 + 매직핏팬티4단계남아60p증정',
#  '하기스 에어솔솔 썸머기저귀 4단계 공용 120매(밴드형) X 2 + 매직핏팬티4단계여아60p증정',
#  '하기스 크린베베 순면감촉 대형 216매',
#  '하기스 크린베베 순면감촉 소형 252매',
#  '하기스 크린베베 순면감촉 중형 234매',
#  '(1번세트/증정) 더블하트 레스랩 유아용 섬유세제 50ml (EA)',
#  '(증정) 그린핑거 손소독 물티슈 캡형 30매 X 10개입',
#  '(증정) 레드투래드 안티더스트 클렌징 폼 20ml (EA)',
#  '(증정) 레드투래드 클렌징 브러쉬 (EA)',
#  '(증정) 쥬트 린넨 쇼퍼백',
#  '(증정) 키즈밴드 랜덤 1종 증정 (핑크퐁 or 헬로키티) (EA)',
#  '(증정) 티엔 매끈 진정 마스크팩 (EA)',
#  '(증정) 하기스 리미티드 보행기 튜브 (EA)',
#  '(핫딜위크/500원딜) 스카트 이벤트 상품 30매 (EA)',
#  '(핫딜위크/무료배송 체험딜) 라네이처 시그니처 울트라 슬림 중형 12개입 (EA)',
#  '(핫딜위크/증정) 키즈밴드 랜덤 1종 증정 (핑크퐁 or 헬로키티) (EA)',
#  '[꿈비] 미미루 뱀부 이중 블랭킷',
#  '[꿈비] 알러지케어 사계절 낮잠이불세트',
#  '[꿈비] 클린 롤매트 255x110x4cm',
#  '[너프] 마이크로샷2 너프건',
#  '[너프] 수퍼소커 HC-E 핸드캐논 (에픽) 물총 너프건 장난감 E6875',
#  '[너프] 수퍼소커 버라지 너프건',
#  '[너프] 엘리트 트라이어드 EX-3 너프건',
#  '[누들앤부] 대용량 뉴본 (샴푸&워시_473ml)',
#  '[누들앤부] 대용량 로션 (473ml)',
#  '[누들앤부] 대용량 버블스 (473ml)',
#  '[누들앤부] 대용량 베이비밤 (238g)',
#  '[누들앤부] 대용량 샴푸 (473ml)',
#  '[누들앤부] 대용량 샴푸(473ml)+대용량 워시(473ml)',
#  '[누들앤부] 대용량로션(473ml)+대용량뉴본(473ml)',
#  '[누들앤부] 대용량로션(473ml)+대용량베이비밤(283ml)',
#  '[누텔라] 헤이즐넛 코코아 스프레드 370g 2개',
#  '[뉴나] 째즈 식탁의자',
#  '[뉴오리진] 비타민D (60일분)',
#  '[뉴오리진] 여성 질건강 유산균 이너플로라 (60일분)',
#  '[뉴오리진] 이너플로라 미니 여성 청결제 페미닌 파우더 워시',
#  '[데르뜨] 젤리 복숭아 90g 24개',
#  '[도담도담오가닉] 2종 배냇저고리세트',
#  '[도담도담오가닉] 2종 속싸개 유아타올세트',
#  '[도담도담오가닉] 2종 아기띠침받이세트',
#  '[도담도담오가닉] 5종 유아 타올+ 아기띠 침받이 특별구성',
#  '[도담도담오가닉] 5종 출산준비세트',
#  '[도담도담오가닉] 7종 출산준비세트',
#  '[도담도담오가닉] 9종 출산준비세트',
#  '[도담도담오가닉] 10종 기획 특선 출산 세트',
#  '[도담도담오가닉]  내츄럴 방수요',
#  '[도담도담오가닉]  배냇슈트(가운)',
#  '[도담도담오가닉]  아기띠침받이+외출용미니타올2장',
#  '[도담도담오가닉]  아기띠침받이+유아목욕손타올',
#  '[도담도담오가닉]  아기띠침받이+유아목욕손타올 2종세트',
#  '[도담도담오가닉]  아기띠침받이+유아턱받이',
#  '[도담도담오가닉]  외출용 필수 3종세트',
#  '[도담도담오가닉]  유아 대형 목욕타올',
#  '[도담도담오가닉]  유아 목욕 손타올+손타올',
#  '[도담도담오가닉]  유아 외출용 미니타올3장',
#  '[도담도담오가닉]  유아 타올 겸용 속싸개',
#  '[도담도담오가닉]  유아 타올 겸용 속싸개 1장',
#  '[도담도담오가닉] 내츄럴 외출용 방수요',
#  '[도담도담오가닉] 배냇저고리 1+1',
#  '[도담도담오가닉] 손타올2개+ 아기띠 침받이 2종 세트',
#  '[도담도담오가닉] 아기띠워머 외출용 3종 기획 특선-네이비',
#  '[도담도담오가닉] 아기띠워머 외출용 3종 기획 특선-브라운',
#  '[도담도담오가닉] 아기띠워머-네이비',
#  '[도담도담오가닉] 외출용방수요1장+목욕실내용방수요1장',
#  '[도담도담오가닉] 유아 샤워 손타올 1+1',
#  '[도담도담오가닉] 유아목욕타올 1+1',
#  '[도담도담오가닉] 턱받이 1+1',
#  '[드시모네] [체헙팩] 드시모네 베이비 캡슐 6캡슐',
#  '[드시모네] ★5포 추가증정★ 드시모네 곰돌이 츄어블 2박스 (80정*2)',
#  '[드시모네] ★추가증정 6캡슐★ 드시모네 베이비드롭 1박스 (1병)',
#  '[드시모네] 드시모네 곰돌이 츄어블 1박스(80정)',
#  '[드시모네] 드시모네 곰돌이 츄어블 2박스 (80정*2)',
#  '[드시모네] 드시모네 데일리 1박스 (30포)',
#  '[드시모네] 드시모네 베이비 캡슐 1박스 (30캡슐)',
#  '[드시모네] 드시모네 베이비 캡슐 1박스 (30캡슐) + 6캡슐 추가증정',
#  '[드시모네] 드시모네 베이비드롭 1박스 (1병)',
#  '[드시모네] 드시모네 베이비드롭 1박스 (1병) + 6캡슐 추가증정',
#  '[드시모네] 드시모네 캡슐 1박스 (60캡슐)',
#  '[드시모네] 드시모네 키즈프리미엄 1박스 (30포)',
#  '[디어에코] 오가닉 피마코튼 바디수트 (open_긴팔_크림) (베블 비누 증정)',
#  '[디어에코] 오가닉 피마코튼 바디수트 (긴팔_패턴) (2개 이상 구매 시 베블 페이셜크림 증정)',
#  '[디어에코] 오가닉 피마코튼 바디수트 (반팔_패턴) (베블 비누 증정)',
#  '[디어에코] 오가닉 피마코튼 바디수트 (카라_긴팔_패턴) (베블 비누 증정)',
#  '[디어에코] 오가닉 피마코튼 상의 (남아_단추) (베블 비누 증정)',
#  '[디어에코] 오가닉 피마코튼 상의 (여아_프릴) (베블 비누 증정)',
#  '[디어에코] 오가닉 피마코튼 손싸개',
#  '[디어에코] 오가닉 피마코튼 우주복 (No_Foot_패턴) (2개 이상 구매 시 베블 페이셜크림 증정)',
#  '[디어에코] 오가닉 피마코튼 우주복 (No_Foot_패턴) (베블 비누 증정)',
#  '[디어에코] 오가닉 피마코튼 우주복 (크림) (2개 이상 구매 시 베블 페이셜크림 증정)',
#  '[디어에코] 오가닉 피마코튼 우주복 (패턴) (베블 비누 증정)',
#  '[디어에코] 오가닉 피마코튼 하의 (남아) (베블 비누 증정)',
#  '[디어에코] 오가닉 피마코튼 하의 (여아_프릴) (베블 비누 증정)',
#  '[디즈니베이비] 거울 딸랑이-미니',
#  '[디즈니베이비] 도형놀이버스-미니',
#  '[디즈니베이비] 도형놀이버스-미키',
#  '[디즈니베이비] 도형놀이버스-푸우',
#  '[디즈니베이비] 디즈니 니모 액티비티 점퍼루',
#  '[디즈니베이비] 디즈니 미니마우스 락커',
#  '[디즈니베이비] 디즈니 미키마우스 락커',
#  '[디즈니베이비] 멜로디 수면등-미니',
#  '[디즈니베이비] 멜로디 수면등-미키',
#  '[디즈니베이비] 멜로디 스마트폰-미니',
#  '[디즈니베이비] 미니 유모차 컵홀더',
#  '[디즈니베이비] 미키 유모차 컵홀더',
#  '[디즈니베이비] 미키마우스 기차놀이',
#  '[디즈니베이비] 부스럭 미키마우스 장갑',
#  '[디즈니베이비] 블록 스쿨버스-미니',
#  '[디즈니베이비] 스마트폰 딸랑이-미키',
#  '[디즈니베이비] 액티비티 딸랑이-미니',
#  '[디즈니베이비] 액티비티 딸랑이-미키',
#  '[디즈니베이비] 오볼 디즈니 미니카(마이크1개+설리1개)',
#  '[디즈니베이비] 오볼 디즈니 미키 스테이션★디즈니미니카1개 추가사은품★',
#  '[디즈니베이비] 오볼 디즈니 푸우 트리하우스★디즈니미니카1개 추가사은품★',
#  '[디즈니베이비] 운전놀이 유모차 장난감-미키',
#  '[디즈니베이비] 유모차 멜로디 장난감-미니',
#  '[디즈니베이비] 유모차 멜로디 장난감-미키',
#  '[디즈니베이비] 타카라토미 팔로우미 미키마우스',
#  '[디즈니베이비] 팔로우미-미키',
#  '[디즈니베이비] 팔로우미-플루토',
#  '[디즈니베이비] 푸우 감각볼',
#  '[디즈니베이비] 푸우 딸랑이 쉐이커',
#  '[디즈니베이비] 푸우 부스럭 치발기',
#  '[디즈니베이비] 푸우 삑삑이',
#  '[디즈니베이비] 푸우 손발딸랑이',
#  '[디즈니베이비] 푸우 유모차 모빌',
#  '[디즈니베이비] 풀앤고 미니카(미키1개+미니1개)',
#  '[디즈니베이비] 플라워 딸랑이-미니',
#  '[라그랑] Lagrang Special Edition ( 바디용 라지 + 세안용 라지)',
#  '[라그랑] 라그랑 천연해면 - L SIZE 1+1 (건조클립 증정)',
#  '[라그랑] 라그랑 천연해면 - L SIZE 1+1 (세안해면 미들 증정, 건조집게 1개 증정)',
#  '[라그랑] 라그랑 천연해면 - L SIZE 1+1  (클립/세안용 미들/룰라러브 비누증정)',
#  '[라그랑] 라그랑 천연해면 - L SIZE (세안해면 증정)',
#  '[라그랑] 라그랑 천연해면 - XL SIZE',
#  '[라그랑] 라그랑 천연해면 - XL SIZE 1+1 (건조클립 증정)',
#  '[라그랑] 라그랑 천연해면 - XL SIZE 1+1  (세안해면 미들 증정, 건조집게 1개 증정)',
#  '[라그랑] 라그랑 천연해면 - XL SIZE 1+1 (세안해면 증정, 건조집게 1개 증정)',
#  '[라그랑] 라그랑 천연해면 - XL SIZE ( 구매시 건조집게1+세안용 미들1+세안타올 증정)',
#  '[라그랑] 라그랑 천연해면 - XL SIZE (세안해면 증정)',
#  ...]

# %%
df_product.loc[df_product['상품명'] == '[대량발주] 택배파손_1224']
# Out:
#   물품대분류               상품명  물품판매량   제품단가
# 8    FC  [대량발주] 택배파손_1224      1  35500
