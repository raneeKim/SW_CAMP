# %% [markdown]
# - '34_Data.xlsx' 파일을 불러와 아래의 분석을 수행하시오.
#
# - 해당 데이터는 2011년도부터 2013년도까지 국내 기업의 신용 대출 관련 데이터이다.
# - 업력의 단위는 연도 이며, 자본금과 대출금액 단위는 백만원이다.
# - 진행상태는 대출 승인 여부를 나타내며, 여신 승인은 대출 승인, 여신 거부는 대출 거부를 뜻한다.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import plotly.express as px

# %%
df1 = pd.read_excel(r'C:\Users\UserK\Desktop\Ranee\data\ML\34_Data.xlsx')

# %%
print(df1.shape)
df1.info()
# Out:
# (2015, 11)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2015 entries, 0 to 2014
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   회사명     2015 non-null   object
#  1   기술명     2015 non-null   object
#  2   기술분류    2014 non-null   object
#  3   설립일     2015 non-null   object
#  4   신청일     2015 non-null   datetime64[ns]
#  5   평가기관    2012 non-null   object
#  6   평가등급    2015 non-null   object
#  7   신청은행    2015 non-null   object
#  8   진행상태    2015 non-null   object
#  9   대출금액    2015 non-null   object
#  10  자본금     2015 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 173.3+ KB

# %%
df1.isnull().sum()
# Out:
# 회사명     0
# 기술명     0
# 기술분류    1
# 설립일     0
# 신청일     0
# 평가기관    3
# 평가등급    0
# 신청은행    0
# 진행상태    0
# 대출금액    0
# 자본금     0
# dtype: int64

# %%
df1.head(5)
# Out:
#        회사명                             기술명       기술분류         설립일  \
# 0    하나로물산          잠수함용 통합 양강마스트 개발 및 사업화         기계  2005/04/12
# 1    신식당화학     소성 가공을 통한 고강도 C형강 및 생산설비 개발         기계  1999/06/01
# 2    ANT산업       조관기 설비에 의한 파이프 및 각관 생산 기술        NaN  2002/03/01
# 3  엔프로그에너지         압진공성형 방식을 이용한 플라스틱 포장용기  화학(화공 섬유)  2012/09/21
# 4    경일솔루션  오리고기를 이용한 한끼 식사용 멸균 레토르트 제품 개발     바이오 의료  2003/05/05
#
#                   신청일    평가기관 평가등급  신청은행  진행상태 대출금액   자본금
# 0 2013-05-09 10:43:43  기술보증기금   AA  기업은행  여신승인   30  1100
# 1 2013-04-29 09:55:37  기술보증기금    A  우리은행  여신거부    0  1000
# 2 2013-04-29 10:01:47  기술보증기금  BBB  우리은행  여신거부    0  1450
# 3 2013-03-28 09:52:47  기술보증기금  BBB  기업은행  여신거부    0   300
# 4 2013-09-17 11:10:43  기술보증기금    B  전북은행  여신승인   50  5500

# %% [markdown]
# 1. 대출 승인이 된 기업 중, 자본금이 가장 많은 100개 기업에 대하여 추출하고, 해당 기업의 기술명 중 가장 빈도수가 높은 단어를 확인하시오.명사를 추출해 확인하시오.

# %%
df2 = df1.loc[df1['진행상태'] == '여신승인'].sort_values(by='자본금', ascending=False).head(100)

# %%
df2
# Out:
#           회사명                                  기술명       기술분류         설립일  \
# 1691   엔프로그기공                      저발열 저수축 시멘트 조성물  화학(화공 섬유)  2009/02/09
# 447    클로벳모터스                         선박용 위성통신 안테나       정보통신  2004/02/05
# 1494   엔프로그물산    경유 차량의 CNG 전소 및 LNG 혼소 차량개조 기술 개발        에너지  1999/08/13
# 1943    텍틱스제약                             무백래쉬 감속기         기계  1989/01/01
# 1802   슈터스모터스           k21 차기보병전투장갑차 조준경용 탐지기-냉각기         기계  1998/10/10
# ...       ...                                  ...        ...         ...
# 1348   신식당솔루션          비금속광물 분쇄 및 석회 입상고토 비료 생산 공정  화학(화공 섬유)  1993/08/09
# 670      경일통신  열처리 강 2중홀의 조도 및 정밀도를 높이기 위한 서멧리머 양산         기계  1996/12/01
# 726    텍틱스소프트            스마트폰 기반 모바일 CCTV 상황관제 시스템       정보통신  1998/04/28
# 644    엔프로그무역                   통신형 전원 마그네틱 커넥터 개발       정보통신  2000/09/18
# 1705  파워레인저물산                      대기전력 저감용 그린 아답터       전기전자  2000/09/18
#
#                      신청일    평가기관    평가등급  신청은행  진행상태  대출금액    자본금
# 1691 2011-04-05 10:39:20      AA  기술보증기금  우리은행  여신승인  1000  31250
# 447  2013-05-21 11:23:43  기술보증기금       A  기업은행  여신승인  1000  27530
# 1494 2011-03-08 10:56:16      AA  기술보증기금  기업은행  여신승인  1650  21929
# 1943 2011-11-03 09:16:10       A  기술보증기금  기업은행  여신승인    30  14462
# 1802 2011-09-27 11:23:42      AA  기술보증기금  기업은행  여신승인    40  14392
# ...                  ...     ...     ...   ...   ...   ...    ...
# 1348 2012-10-04 16:12:35  기술보증기금      BB  신한은행  여신승인    30   1700
# 670  2012-12-13 15:54:29  기술보증기금      BB  기업은행  여신승인    30   1692
# 726  2012-06-04 15:50:29  기술보증기금      AA  기업은행  여신승인   329   1682
# 644  2012-06-14 13:25:15  기술보증기금       A  기업은행  여신승인   100   1678
# 1705 2011-07-01 15:16:48      AA  기술보증기금  기업은행  여신승인  1000   1678
#
# [100 rows x 11 columns]

# %%
df2['기술명']
# Out:
# 1691                        저발열 저수축 시멘트 조성물
# 447                            선박용 위성통신 안테나
# 1494      경유 차량의 CNG 전소 및 LNG 혼소 차량개조 기술 개발
# 1943                               무백래쉬 감속기
# 1802             k21 차기보병전투장갑차 조준경용 탐지기-냉각기
#                        ...
# 1348            비금속광물 분쇄 및 석회 입상고토 비료 생산 공정
# 670     열처리 강 2중홀의 조도 및 정밀도를 높이기 위한 서멧리머 양산
# 726               스마트폰 기반 모바일 CCTV 상황관제 시스템
# 644                      통신형 전원 마그네틱 커넥터 개발
# 1705                        대기전력 저감용 그린 아답터
# Name: 기술명, Length: 100, dtype: object

# %%
from konlpy.tag import Okt

# %%
okt = Okt()

# %%
okt.pos(df2['기술명'].values[0])
# Out:
# [('저', 'Determiner'),
#  ('발열', 'Noun'),
#  ('저', 'Determiner'),
#  ('수축', 'Noun'),
#  ('시멘트', 'Noun'),
#  ('조성', 'Noun'),
#  ('물', 'Noun')]

# %%
okt.nouns(df2['기술명'].values[0])
# Out:
# ['발열', '수축', '시멘트', '조성', '물']

# %%
df_Pos = pd.DataFrame() 
for i in range(len(df2['기술명'])) : 
    dfn = pd.DataFrame(okt.pos(df2['기술명'].values[i]), columns=['형태소','품사'])
    df_Pos = pd.concat([df_Pos,dfn])

# %%
df_nouns = df_Pos.loc[df_Pos['품사'] == 'Noun']

# %%
df_nouns['형태소'].unique()
# Out:
# array(['발열', '수축', '시멘트', '조성', '물', '선박', '용', '위성', '통신', '안테나', '경유',
#        '차량', '전소', '및', '혼소', '개조', '기술', '개발', '무', '백래쉬', '감속', '기',
#        '차기', '보병', '전투', '장갑차', '조준', '탐지기', '냉각기', '재료', '특성', '풍력발전',
#        '시스템', '요소', '부품', '중', '타워', '제조', '제작', '증착', '장비', '기업', '모빌리티',
#        '환경', '구축', '위', '솔루션', '비자', '전', '친환경', '아동', '가구', '디', '스펜서',
#        '펌프', '상용차', '포함', '클린', '디젤', '그린', '자동', '차용', '스테인레스', '이중',
#        '링', '프레', '스타', '입', '배관', '재', '반도체', '칩', '여러', '기타', '모듈',
#        '카메라', '등', '테스트', '제품', '치과', '임플란트', '오리고기', '이용', '끼', '식',
#        '사용', '멸균', '레토르트', '돼지', '가금', '혈청', '진단', '온라인게임', '사업', '수문',
#        '인양', '장치', '산업', '플랜', '기능', '사이드', '미러', '자동차', '헤드', '실린더',
#        '글로벌', '연동', '고정', '구조', '포장', '박스', '전동', '청소', '차', '전동기', '일반',
#        '중계기', '매', '루트', '다모', '통한', '교육', '서비스', '개폐기', '차단', '기용',
#        '에폭시', '몰딩', '건설', '기계', '유압', '튜브', '조합', '품', '실시간', '모니터링',
#        '다기', '능', '혈', '기기', '도요타', '납품', '룸', '내장', '블랙박스', '희토류', '본드',
#        '자석', '공법', '굴삭기', '가공', '클라우드', '기반', '광고', '플랫폼', '키', '오스',
#        '전자상거래', '충전', '강상', '형교', '거더교', '대체', '폴리', '올레', '바닥재', '나선형',
#        '덕트', '엘', '보우', '방송', '콘텐츠', '수평', '조절', '검안', '호롭터', '불량', '패널',
#        '처리', '화학', '약품', '폐액', '정제', '재생', '방법', '안전', '변', '어셈블리',
#        '신재생에너지', '부하', '변압기', '생석회', '고순', '오메가', '를', '의약', '원료', '광도',
#        '파로', '소자', '수동', '광', '난', '연성', '스티로폼', '그', '즉석', '분쇄', '냉동',
#        '과즙', '음료', '용기', '생산', '무선통신', '모뎀', '수출', '고분자', '수지', '무기',
#        '안료', '바닥', '마감', '산화', '폐수처리', '공정', '휴대전화', '판', '전자부품', '실장',
#        '질소', '강선', '송전', '선', '멀티터치', '스크린', '오디오', '네비게이션', '라디오', '공조',
#        '통합', '부속품', '금', '발', '전용', '발전기', '패키지', '구성', '개통', '계', '대형',
#        '프레임', '적용', '용량', '태양열', '평판', '집', '습', '원식', '냉', '난방', '히트',
#        '음악게임', '툴', '오투잼', '차원', '자인', '입력장치', '가상', '보드', '원자력발전소',
#        '철근콘크리트', '조물', '형성', '유로폼', '센서', '일체', '소음', '진동', '방지', '건축',
#        '음향', '실용', '효율', '열교환기', '설계', '위험', '감지', '상황', '지능', '방폭', '창호',
#        '충격', '흡수', '공기', '동형', '헬리', '컬', '트림', '제어', '밸브', '침구', '류',
#        '제', '세대', '심장', '조영제', '혁신', '신약', '규칙', '터치', '라멘', '형태', '주차장',
#        '건축물', '온라인', '보안', '색상', '모양', '점토', '벽돌', '청정', '주산', '농', '수산물',
#        '자재', '웹', '어플리케이션', '증', '이도', '손실', '나선', '주소', '관리', '형상관리',
#        '알루미늄합금', '경봉', '연속', '주조', '영상', '기록', '중장비', '유기성', '잔재', '축산',
#        '분뇨', '유', '기질', '비료', '비금속', '광물', '석회', '입상', '고토', '열처리', '강',
#        '중홀', '조도', '정밀도', '멧', '리머', '양산', '스마트폰', '모바일', '관제', '전원', '마',
#        '그네', '커넥터', '대기전력', '감용', '답터'], dtype=object)

# %%
df_nouns.value_counts()
# Out:
# 형태소  품사
# 및    Noun    23
# 개발   Noun    22
# 용    Noun    21
# 기술   Noun    21
# 제조   Noun    19
#              ..
# 보드   Noun     1
# 변압기  Noun     1
# 변    Noun     1
# 벽돌   Noun     1
# 히트   Noun     1
# Name: count, Length: 371, dtype: int64

# %% [markdown]
# 2. 기업의 설립일을 이용해, 기업의 업력 (설립 후 현재까지 지속된 기간 / 연도)을 계산하고, 대출 승인여부에 따른 기업 업력의 대표값의 차이가 있는지 검정하시오.

# %%
df1['설립일_dt'] = pd.to_datetime(df1['설립일'])

# %%
df1['업력'] = 2024 - df1['설립일_dt'].dt.year

# %%
df1['업력']
# Out:
# 0       19
# 1       25
# 2       22
# 3       12
# 4       21
#         ..
# 2010    14
# 2011    19
# 2012    33
# 2013    13
# 2014    25
# Name: 업력, Length: 2015, dtype: int32

# %%
cond1 = (df1['진행상태'] == '여신승인')
df_pass = df1.loc[cond1]
df_fail = df1.loc[~cond1]

print(stats.normaltest(df_pass['업력'])) # 정규분포X
print(stats.normaltest(df_fail['업력'])) # 정규분포X
# Out:
# NormaltestResult(statistic=1140.8692233373934, pvalue=1.833985364724405e-248)
# NormaltestResult(statistic=300.22104878717283, pvalue=6.424326137902909e-66)

# %%
stats.ranksums(df_pass['업력'],df_fail['업력']) # pvale < 0.05 => 귀무가설 기각 => 대립가설 참 => 대표값 차이가 있다
# Out:
# RanksumsResult(statistic=3.460923202273835, pvalue=0.000538326359827545)

# %% [markdown]
# 3. 기업 평가등급과 대출 승인여부의 유의미한 차이가 있는지 가설 검정을 수행하고, 대출 승인 비율을 각 평가 등급 별로 계산하시오.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2015 entries, 0 to 2014
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   회사명     2015 non-null   object
#  1   기술명     2015 non-null   object
#  2   기술분류    2014 non-null   object
#  3   설립일     2015 non-null   object
#  4   신청일     2015 non-null   datetime64[ns]
#  5   평가기관    2012 non-null   object
#  6   평가등급    2015 non-null   object
#  7   신청은행    2015 non-null   object
#  8   진행상태    2015 non-null   object
#  9   대출금액    2015 non-null   object
#  10  자본금     2015 non-null   int64
#  11  설립일_dt  2015 non-null   datetime64[ns]
#  12  업력      2015 non-null   int32
# dtypes: datetime64[ns](2), int32(1), int64(1), object(9)
# memory usage: 196.9+ KB

# %%
c1 = pd.crosstab(df1['평가등급'],df1['진행상태'])
stats.chi2_contingency(c1)
# < 0.05 => 귀무가설 기각 => 대립가설 참 => 상관있다.
# Out:
# Chi2ContingencyResult(statistic=491.56416657936137, pvalue=1.0645795763900513e-83, dof=32, expected_freq=array([[3.63027295e+01, 1.53508685e+02, 1.88585608e-01],
#        [1.08908189e+01, 4.60526055e+01, 5.65756824e-02],
#        [3.82133995e-01, 1.61588089e+00, 1.98511166e-03],
#        [7.33697270e+01, 3.10249132e+02, 3.81141439e-01],
#        [7.31786600e+01, 3.09441191e+02, 3.80148883e-01],
#        [6.43895782e+01, 2.72275931e+02, 3.34491315e-01],
#        [1.91066998e-01, 8.07940447e-01, 9.92555831e-04],
#        [3.82133995e-01, 1.61588089e+00, 1.98511166e-03],
#        [1.91066998e-01, 8.07940447e-01, 9.92555831e-04],
#        [1.33746898e+00, 5.65558313e+00, 6.94789082e-03],
#        [1.14640199e+00, 4.84764268e+00, 5.95533499e-03],
#        [1.91066998e-01, 8.07940447e-01, 9.92555831e-04],
#        [9.55334988e-01, 4.03970223e+00, 4.96277916e-03],
#        [1.91066998e-01, 8.07940447e-01, 9.92555831e-04],
#        [1.91066998e-01, 8.07940447e-01, 9.92555831e-04],
#        [1.20754342e+02, 5.10618362e+02, 6.27295285e-01],
#        [9.55334988e-01, 4.03970223e+00, 4.96277916e-03]]))

# %%
c2 = pd.crosstab(df1['평가등급'],df1['진행상태'], margins=True).reset_index()
c2['여신거부 비율'] = c2['여신거부'] / c2['All'] * 100
c2['여신승인 비율'] = c2['여신승인'] / c2['All'] * 100
c2['투자연계 비율'] = c2['투자연계'] / c2['All'] * 100
c2
# Out:
# 진행상태     평가등급  여신거부  여신승인  투자연계   All     여신거부 비율     여신승인 비율    투자연계 비율
# 0           A    49   141     0   190   25.789474   74.210526   0.000000
# 1          AA    12    45     0    57   21.052632   78.947368   0.000000
# 2         AAA     0     2     0     2    0.000000  100.000000   0.000000
# 3           B    92   292     0   384   23.958333   76.041667   0.000000
# 4          BB    82   301     0   383   21.409922   78.590078   0.000000
# 5         BBB    91   246     0   337   27.002967   72.997033   0.000000
# 6           C     1     0     0     1  100.000000    0.000000   0.000000
# 7         CCC     1     1     0     2   50.000000   50.000000   0.000000
# 8          T2     1     0     0     1  100.000000    0.000000   0.000000
# 9       T2/AA     6     0     1     7   85.714286    0.000000  14.285714
# 10       T3/A     5     0     1     6   83.333333    0.000000  16.666667
# 11         T4     1     0     0     1  100.000000    0.000000   0.000000
# 12     T4/BBB     4     1     0     5   80.000000   20.000000   0.000000
# 13       T6/B     1     0     0     1  100.000000    0.000000   0.000000
# 14      T8/CC     1     0     0     1  100.000000    0.000000   0.000000
# 15     기술보증기금    35   597     0   632    5.537975   94.462025   0.000000
# 16    한국발명진흥회     3     2     0     5   60.000000   40.000000   0.000000
# 17        All   385  1628     2  2015   19.106700   80.794045   0.099256

# %% [markdown]
# 4. 여신승인 된 기업 중, 자본금과 대출금액의 합이 가장 높은 10개 기업을 확인하시오.

# %%
df_pass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1628 entries, 0 to 2013
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   회사명     1628 non-null   object
#  1   기술명     1628 non-null   object
#  2   기술분류    1628 non-null   object
#  3   설립일     1628 non-null   object
#  4   신청일     1628 non-null   datetime64[ns]
#  5   평가기관    1628 non-null   object
#  6   평가등급    1628 non-null   object
#  7   신청은행    1628 non-null   object
#  8   진행상태    1628 non-null   object
#  9   대출금액    1628 non-null   object
#  10  자본금     1628 non-null   int64
#  11  설립일_dt  1628 non-null   datetime64[ns]
#  12  업력      1628 non-null   int32
# dtypes: datetime64[ns](2), int32(1), int64(1), object(9)
# memory usage: 171.7+ KB

# %%
df_pass['대출금액_int'] = df_pass['대출금액'].replace( {'금액없음':0}).astype('int64')
# Out:
# C:\Users\UserK\AppData\Local\Temp\ipykernel_11908\3723773219.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_pass['자본금']
# Out:
# 0       1100
# 4       5500
# 8        150
# 9        300
# 10       400
#         ...
# 2009    2100
# 2010       3
# 2011     263
# 2012     300
# 2013     100
# Name: 자본금, Length: 1628, dtype: int64

# %%
df_pass['자본금과 대출금액 합'] = df_pass['대출금액_int'] + df_pass['자본금']
# Out:
# C:\Users\UserK\AppData\Local\Temp\ipykernel_11908\2334278003.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [raw]
# df_pass.sort_values(by='자본금과 대출금액 합', ascending=False).head(10)['회사명']

# %% [markdown]
# 5. 기술 분류에 '기계'에 해당하는 기업의 기술명을 단어표현을 통해, '반도체'라는 단어와 가장 유사한 단어들이 무엇이 있는지 확인하시오.

# %%
nouns_list = [okt.nouns(x) for x in df1.loc[df1['기술분류'] == '기계']['기술명'].values]

# %%
nouns_list
# Out:
# [['잠수함', '용', '통합', '양강', '마스트', '개발', '및', '사업'],
#  ['소성', '가공', '통한', '강도', '형강', '및', '생산', '설비', '개발'],
#  ['철판', '자동', '면', '취기', '기술', '개발', '및', '제조', '기술'],
#  ['길이', '조절', '치가', '부착', '무용', '가구'],
#  ['반도체', '금', '부품', '정밀', '가공', '기술'],
#  ['답터', '플레이', '트', '작시', '정밀', '기술', '개발'],
#  ['방산', '부품', '절삭', '가공', '기술'],
#  ['산업', '용', '가스', '압축기', '및', '대형', '철', '조물', '제작', '기술'],
#  ['금', '형용', '핀', '제작'],
#  ['제어', '방식', '원단', '절', '단기', '및', '개발'],
#  ['진공', '비용', '씰링제', '개발'],
#  ['형', '진공', '로봇', '이송', '시스템'],
#  ['철강', '코일', '포장', '용', '포장재', '제조'],
#  ['무대', '장치', '용', '모터', '장치'],
#  ['자동', '차용', '개발'],
#  ['스', '크롤', '부품', '가공', '기술'],
#  ['냉장고', '금', '제조'],
#  ['용접', '개선', '용', '면', '취기'],
#  ['기밀', '향상', '보강', '테', '제조'],
#  ['산업', '부품', '유압', '프레', '스', '개발'],
#  ['판재', '이용', '율', '대화', '위', '부재', '자동', '배치', '방법'],
#  ['캐스팅', '금', '제조', '기술'],
#  ['자동', '차용', '고무', '제품', '제조', '기술'],
#  ['자동', '조정', '기능', '심압대', '가공'],
#  ['자동차', '부품', '제조', '기술'],
#  ['출력', '응용', '강성', '유격', '차량', '용', '신축', '샤프트'],
#  ['차염', '발생', '설비'],
#  ['상용', '차용', '자식', '엑셀', '페달', '생산'],
#  ['상용', '차용', '축', '에어', '서스펜션', '리프', '팅', '장치', '제조', '기술'],
#  ['중기관총', '용', '구경', '도트', '사이트'],
#  ['조선해', '설계', '기술', '등', '이용', '설계', '기술'],
#  ['프레', '스', '가공', '통해', '자동차', '부품', '생산', '기술'],
#  ['자동차', '부품', '용', '금', '가공', '기술'],
#  ['철도차량', '부품', '제조', '기술'],
#  ['색조', '화장품', '자동', '충', '진기'],
#  ['를', '사용', '초음파', '디핑', '세척', '기술'],
#  ['바텐', '승', '하강', '장치'],
#  ['공작기계', '부품', '및', '선반', '엔진', '부품', '임', '가공'],
#  ['플랜트', '배관', '설계', '및', '응력', '해석'],
#  ['정밀', '금속', '가공', '제품', '제조'],
#  ['자동차', '자동변속기', '부품', '제조', '기술'],
#  ['자동차', '암레스트', '제조', '기술'],
#  ['폐열', '회수', '활용', '라비', '인쇄', '건조', '장치'],
#  ['볼트', '리벳', '등', '제조'],
#  ['유기', '폐기물', '건조', '처리장치'],
#  ['곡선', '레일', '주행', '개발'],
#  ['커넥터', '사출', '금', '제작', '기술'],
#  ['가로등', '렌즈', '용', '외', '부품', '용', '사출', '성형', '기술'],
#  ['차량', '용', '브레이크', '디스크', '측정', '장치'],
#  ['파렛트', '제조', '기술'],
#  ['초', '정밀', '설비', '이송', '및', '셋업', '기술'],
#  ['하이브리드', '시스템', '차량', '장', '착용', '유압', '크레인', '개발'],
#  ['가성소다', '재', '이용', '장치'],
#  ['유압', '펌프', '용', '피스톤', '가공', '기술'],
#  ['승용', '속', '미션', '동력', '전달', '기어', '기술'],
#  ['자동', '및', '자동', '설비', '자동', '검사', '기'],
#  ['자동차', '부품', '용', '프레', '스', '물', '가공', '기술'],
#  ['마', '네트', '리프트', '등', '제조', '기술'],
#  ['승용차', '용', '머플러', '생산', '기술'],
#  ['전자부품', '및', '자동차', '전장', '부품', '용', '커넥터', '제조'],
#  ['자동차', '공조', '시스템', '사출', '금'],
#  ['자동차', '부품', '운반', '용', '파레트', '생산', '기술'],
#  ['건설', '기계', '용', '유압', '튜브', '조합', '품', '제작', '기술'],
#  ['공작기계', '용', '시스템', '개발'],
#  ['공작기계', '용', '부대', '기구', '물', '가공', '기술'],
#  ['댐', '수위', '자동', '절용', '철', '제관', '싸이', '폰', '제작'],
#  ['자동', '차용', '용', '제조', '기술'],
#  ['공작기계', '용', '제조', '기술'],
#  ['고난', '삭용', '유압', '블럭', '가공'],
#  ['필터', '집', '진기', '탈진', '효율', '향상', '위', '펄스', '시스템'],
#  ['자동화기', '부품', '절삭', '가공'],
#  ['분', '기관', '이용', '소화', '설비', '배관', '제작', '기술'],
#  ['휴대', '기기', '차량', '용', '거치'],
#  ['중', '대형', '정밀', '사출', '금', '설계', '및', '제작', '기술'],
#  ['하천', '해양', '준설', '바지', '선용', '준설', '펌프', '제조', '기술'],
#  ['선박', '진용', '제조', '기술'],
#  ['반도체', '장', '비용', '기계', '부품', '가공', '기술'],
#  ['자동차', '부품', '등', '제조', '기술'],
#  ['필름', '용', '슬롯', '코터', '제조', '기술'],
#  ['무용', '의자', '제조', '기술'],
#  ['로봇', '적용', '자동화', '생산', '설비', '제조', '기술'],
#  ['관로', '압력', '이용', '체크', '밸브', '제어', '장치'],
#  ['방화', '유리', '프레임', '구조체'],
#  ['차체', '프레임', '결', '지그', '제작', '기술'],
#  ['고철', '가공', '설비', '제조', '기술'],
#  ['와이퍼', '블레이드'],
#  ['에어백', '인플레', '터', '가스', '발생', '기', '용', '징'],
#  ['기술', '적용', '녹즙기', '제조', '기술'],
#  ['제조', '기술'],
#  ['선박', '및', '해양', '플랜트', '배관', '설계', '기술'],
#  ['자동', '차용', '부품'],
#  ['해양', '플랜트', '용', '금속', '조물', '제조'],
#  ['경찰', '순찰차', '경찰', '수송', '버스', '등', '특', '차량', '개발'],
#  ['자동차', '부품', '브라켓', '류', '프레', '스', '가공', '기술'],
#  ['자동', '차용', '볼트', '류', '및', '핀류', '제조', '기술'],
#  ['자동', '차용', '용'],
#  ['자동', '차용', '변속기', '일체', '치', '무연', '삭', '정밀', '단조', '기술'],
#  ['지능', '아웃', '사이드', '미러'],
#  ['자동차', '브레이크', '부품', '생산', '기술'],
#  ['윤전', '및', '옵셋', '인쇄', '기술'],
#  ['화학', '약품', '압송', '용', '칼', '펌프'],
#  ['연료', '절약', '복합', '기능', '중형', '트랙터', '및', '차량', '부', '착용', '지게차'],
#  ['고속', '생산', '이어폰', '필름', '진동', '판', '형기'],
#  ['몰드', '베이스', '가공', '기술'],
#  ['미생물', '검사', '처리', '장비', '제조', '기술'],
#  ['친환경', '분젠', '버너'],
#  ['기계', '부품', '절삭', '가공', '기술'],
#  ['각종', '산업', '용', '감속', '기', '제조', '기술'],
#  ['진공', '펌프', '용', '로터', '및', '샤프트', '부품', '개발'],
#  ['커피', '생', '로스팅', '원두', '일체', '기계', '및', '생', '원두', '자동', '이송', '기'],
#  [],
#  ['자동', '차용', '속', '오토', '미션', '기어', '가공', '기술'],
#  ['토너', '용', '기어', '및', '자동차', '부품', '기어', '사출', '기술'],
#  ['양계', '용', '계', '이송', '장치'],
#  ['자동', '차용', '루프', '랙', '제조', '기술'],
#  ['형강', '가공', '기술'],
#  ['판넬', '개폐', '문의', '제조', '공정', '및', '설치', '기간', '단축', '기술'],
#  ['자원', '탐사', '용', '추기', '제조', '기술'],
#  ['자동차', '엔진', '부품', '등', '정밀', '가공', '및', '조립', '기술'],
#  ['패스', '타입', '분산', '및', '유화', '장치'],
#  ['양산', '고려', '고성능', '의료', '체어', '용', '차세대', '광원', '무영', '등', '시스템', '개발'],
#  ['를', '이용', '자동', '제어', '시스템'],
#  ['레이저', '절단', '이용', '산업', '기계', '부품', '제작'],
#  ['지용', '기계', '제조', '초', '지기', '중건', '장치'],
#  ['판금', '가공', '기술'],
#  ['트레일러', '용', '슬라이드', '로우', '베드'],
#  ['의료', '및', '반도체', '용', '특수', '금'],
#  ['초소', '스프링', '제작', '기술'],
#  ['수용성', '도장', '부스', '자동화', '및', '적외선', '건조', '기술'],
#  ['목재', '펠렛', '보일러'],
#  ['효율', '양각', '금'],
#  ['칼라', '강판', '인쇄', '프린팅', '설비', '제조', '기술'],
#  ['이중', '벨트', '툴', '박스', '폴리', '싱', '머신'],
#  ['열연', '가열', '제작', '및', '설치'],
#  ['밸브', '용', '액츄에이터', '제조', '방법'],
#  ['공법', '활용', '제철', '설비', '부분품', '가공', '기술'],
#  ['이', '부착', '원형', '톱날', '제조', '기술'],
#  ['발전', '플랜트', '용', '고온', '고압', '보일러', '급수', '펌프', '기술'],
#  ['유압', '브레이커', '연비', '향상', '기술', '개발'],
#  ['선박', '의장', '설계', '기술'],
#  ['류기', '의', '가공', '기술'],
#  ['굴삭기', '유압', '부품', '가공'],
#  ['철근', '배근', '기술'],
#  ['기계', '부품', '제조', '기술'],
#  ['제어', '시스템', '이용', '인버터', '제작', '기술'],
#  ['주입', '장치'],
#  ['자동', '삽입', '기술'],
#  ['친환경', '압축', '진개', '차', '수거', '장치', '제조'],
#  ['제강', '슬', '래그', '이용', '연마', '재', '제조'],
#  ['대형', '글라스', '유기물', '처'],
#  ['소형', '가공', '장치', '개발', '및', '생산'],
#  ['공작기계', '특수강', '부품', '정밀', '가공', '기술'],
#  ['금', '제조', '기술'],
#  ['자동차', '전조등', '베이스', '개발'],
#  ['열처리', '강', '중홀', '조도', '및', '정밀도', '위', '멧', '리머', '양산'],
#  ['목적', '단', '파괴', '기'],
#  ['용', '덕트', '제조', '기술'],
#  ['산업', '용', '기어'],
#  ['공작기계', '부품', '제조'],
#  ['산업', '설비', '부품', '용', '철판', '절단', '가공', '기술'],
#  ['포', '장기', '포대', '공급', '장치'],
#  ['친환경', '감', '탈'],
#  ['중장비', '하부', '프레임', '제조'],
#  ['작동', '방지', '수단', '구비', '도어', '락'],
#  ['유류', '탱크', '수직', '천공', '누유', '감지', '장치', '및', '그', '설치', '방법'],
#  ['철', '스크랩', '압축', '가공', '기술'],
#  ['화학', '정유', '공장', '및', '발전', '플랜트', '용'],
#  ['철근', '결속', '선', '자동', '팅', '시스템', '구축'],
#  ['축', '겐트', '리', '로봇', '가공'],
#  ['로', '및', '스팀', '에너지', '공급', '장치'],
#  ['경량', '및', '부품', '가공', '기술', '개발'],
#  ['선박', '및', '해양', '플랜트', '용', '배관', '및', '철', '설계', '기술'],
#  ['반도체', '제조', '용', '및', '개발'],
#  ['스테인레스', '이중', '링', '프레', '스타', '입', '배관', '재'],
#  ['자동차', '부품', '시트', '프레임', '차체', '부품', '외', '제조', '기술'],
#  ['자동', '차용', '제어', '케이블'],
#  ['제약', '기계', '용', '메인', '디스크', '부품', '생산', '위', '초', '정밀', '가공'],
#  ['수문', '인양', '장치', '제조', '기술'],
#  ['선박', '용', '하드코어', '격벽', '패널', '제조', '위', '금'],
#  ['가축', '사료', '혼', '합기', '배합'],
#  ['열교환기', '및', '화력발전', '소용', '금속', '부품', '가공', '기술'],
#  ['각형', '캔', '용기', '제조', '장치', '및', '제조', '방법'],
#  ['롤', '표면', '물질', '제거', '장치'],
#  ['조립', '필터', '및', '그', '조립', '방법'],
#  ['공작기계', '부품', '슬라이딩', '베어링', '제조'],
#  ['자동차', '동력', '전달', '장치', '용', '핵심', '부품'],
#  ['방', '정밀', '부품', '가공', '기술'],
#  ['충전', '소형', '드라이버'],
#  ['선박', '블럭', '조립'],
#  ['중대', '선박', '진의', '주물', '제품', '대한', '절삭', '가공', '기술'],
#  ['중장비', '무한궤도', '바퀴', '용', '부품', '정밀', '제조', '기술'],
#  ['제조', '기술'],
#  ['제조', '기술'],
#  ['태양광', '웨이퍼', '정장', '비', '개발'],
#  ['친환경', '휴대', '용', '스터드', '용', '접기', '개발'],
#  ['호텔', '서비스', '용', '지능', '로봇', '시스템', '사업'],
#  ['엽', '장비', '개발'],
#  ['축소', '슬라이딩', '접촉', '단자', '및', '이의', '설치', '구조'],
#  ['차체', '부품', '개발'],
#  ['핀', '튜브', '제조', '기술'],
#  ['금', '가공', '기술'],
#  ['개발'],
#  ['점등', '검', '사용'],
#  ['프로그레시브', '금', '이용', '자동차', '부품', '제조'],
#  ['신발', '용', '톰슨', '목', '제작'],
#  ['대형', '산업', '용', '기계', '베드', '가공', '기술'],
#  ['중장비', '부품', '가공', '기술'],
#  ['배드민턴', '연습', '장치'],
#  ['금속', '비금속', '표면처리', '용', '자동화', '기계', '제작'],
#  ['쇼트', '블', '라스트', '및', '인산염', '피막', '공정', '자동화', '기술'],
#  ['자동차', '부품', '절삭', '가공', '기술'],
#  ['고속', '인장', '충격', '시험', '기', '제조', '기술'],
#  ['어버트먼트', '스', '크류', '제거', '장치'],
#  ['산업', '용', '열교환기', '제조', '기술'],
#  ['자동', '공구', '교환', '장치'],
#  ['전용', '설비', '개발', '사업'],
#  ['자동', '차용', '미션', '핵심', '부품', '제조'],
#  ['자동차', '동력', '전달', '장치', '용', '정밀', '기계', '부품', '가공'],
#  ['연마', '벨트', '정기', '개발'],
#  ['디', '스펜서', '용', '펌프', '및', '디', '스펜서'],
#  ['알루미늄', '전용', '압출기', '제작'],
#  ['다각', '지원', '라운드', '앵커', '용', '브라켓'],
#  ['자동', '스폿', '용접', '방식', '스틸', '파레트'],
#  ['자동차', '부품', '금', '제작', '기술'],
#  ['타이어', '성형', '브레다', '개발'],
#  ['캐스터', '제조', '기술'],
#  ['자동', '제어', '설비', '제작', '기술'],
#  ['및', '사업'],
#  ['미용', '기기', '부품', '가공', '기술', '개발'],
#  ['고속', '분말', '포', '장기', '필름', '정렬', '장치'],
#  ['터릿', '공구', '홀더', '제작', '기술'],
#  ['덤프', '트럭', '자동', '덮개', '장치'],
#  ['목적', '계류', '장치', '인쇄회로기판', '공용', '가공'],
#  ['스마트', '센서'],
#  ['면', '실링', '방식', '자동', '라인', '블라인드', '밸브'],
#  ['선용', '용', '접기', '개발', '및', '사업'],
#  ['샌드', '우치', '판넬', '자제', '생산', '시스템', '개발'],
#  ['공기', '동형', '헬리', '컬', '트림', '제어', '밸브'],
#  ['호', '이스트', '크레인', '설치', '휠', '시브', '와이어', '드럼', '후크', '가공품'],
#  ['프로그레시브', '금', '및', '프레', '스', '가공', '기술'],
#  ['스테인레스', '원통', '물탱크', '제조', '기술'],
#  ['자동', '차용', '스티', '링', '휠', '생산', '기술'],
#  ['선박', '플랜트', '제조', '위', '치구', '생산', '기술'],
#  ['자동', '차용', '리퍼', '징'],
#  ['터치', '패널', '제조', '장비'],
#  ['개발', '및', '사업'],
#  ['소형', '터빈', '엔진', '소기', '부품', '등', '제조'],
#  ['메탄', '정제', '장치'],
#  ['필라멘트', '라인', '딩', '시스템'],
#  ['사출', '금', '제조', '기술'],
#  ['선박', '평형', '수', '처리장치'],
#  ['방위산업', '용', '장갑차', '부품', '정밀', '가공', '기술'],
#  ['전자', '빔', '이용', '반도체', '정의', '폐', '가스', '처리장치', '및', '처리', '방법'],
#  ['소음기', '일체', '팬', '필터', '유닛', '장착', '나노', '계측장비', '용', '방음', '챔버'],
#  ['전동', '리프트'],
#  ['중대', '등반', '압', '프레', '스', '개발'],
#  ['냉', '방기', '및', '조기', '제어', '시스템'],
#  ['나노', '막', '필터', '이용', '에칭', '액', '재생', '장치', '및', '그', '재생', '방법'],
#  ['골', '판지', '형용', '골', '롤'],
#  ['유압', '실린더', '적용', '제조', '기술'],
#  ['엘이디', '제조', '공정', '용', '순화', '액', '열', '냉각', '장치'],
#  ['제조', '기술', '개발', '및', '생산'],
#  ['고성능', '소형', '전기', '이륜차', '개발'],
#  ['슬라이딩', '창문', '잠금장치'],
#  ['개발'],
#  ['가상', '현실', '대응', '동작', '자전거', '운동', '기구'],
#  ['대형', '선박', '용', '크레인', '제어', '기술'],
#  ['및', '및', '디지털', '디텍터', '이용', '선', '자동', '검사', '장치'],
#  ['자동차', '헤드', '실린더', '제작', '기술'],
#  ['발', '성형', '품', '검사', '장치', '및', '발', '장치'],
#  ['카메라', '소자', '제조', '용'],
#  ['목적', '계류', '장치'],
#  ['열교환기', '용', '플랜', '면', '변형', '측정기', '개발'],
#  ['캐비넷', '간이', '스프링클러', '설비'],
#  ['전자', '제어', '자동차', '시뮬레이터'],
#  ['연속', '진공', '성형', '장치'],
#  ['선박', '상용', '발전기', '프레임', '건설', '장비', '상', '하부', '프레임'],
#  ['롤', '포밍기술', '자동', '차용', '테', '트림', '범퍼', '일체'],
#  ['냉각탑', '용', '자가발전', '시스템', '및', '무동', '냉각탑'],
#  ['사출', '형기', '노즐', '장치'],
#  ['파장', '대의', '적용', '개발'],
#  ['발', '전용', '터빈', '부품', '정밀', '가공'],
#  ['미립', '분류', '진동', '스크린', '피더', '기술'],
#  ['자동', '차용', '프레', '스', '금', '가공', '기술'],
#  ['자동차', '향', '장치', '부품', '제조'],
#  ['글로브', '박스', '용', '블로워'],
#  ['휴대폰', '금', '가공'],
#  ['플라노', '밀러', '가공', '기술'],
#  ['친환경', '자동차', '용', '성능', '시험', '장치', '및', '개발'],
#  ['자동', '차용', '부품', '금', '제조', '기술'],
#  ['자동', '차용', '컴프레서', '삭', '가공', '기술'],
#  ['재봉틀', '용', '훅', '제조', '사업'],
#  ['수평', '자동', '조절', '검안', '호롭터'],
#  ['자동', '차용', '향', '부품', '조립', '자동화', '설비'],
#  ['초', '고압', '가스', '차단기', '부품', '제조', '기술'],
#  ['오', '폐수', '감형', '수저', '자동', '세척', '분', '리기', '개발'],
#  ['공장', '자동화', '설비', '제어', '시스템', '개발'],
#  ['생산자', '동화', '설비', '제조'],
#  ['축냉', '시스템', '이용', '냉', '난방', '시스템'],
#  ['열전달', '효율', '잠열', '축열', '용기'],
#  ['판', '스프링', '이용', '시소', '및', '놀이', '시설', '제조'],
#  ['공작기계', '류', '및', '음식물', '쓰레기', '감량', '처리기'],
#  ['벌브', '실링', '머신', '버너', '장치'],
#  ['자동차', '부품', '제조', '기술'],
#  ['수중', '모터', '펌프', '자동', '운전', '기록', '장치'],
#  ['인서트', '천', '사출', '금', '장치', '개발'],
#  ['몰드', '베이스', '제조', '기술'],
#  ['소형', '트랙터', '용', '유압식', '운전', '동력', '전달', '장치'],
#  ['필터', '시스템', '및', '장비'],
#  ['굴삭기', '용', '유압', '펌프', '제조', '기술'],
#  ['옥외', '교량', '엘리베이터', '제조', '기술'],
#  ['대형', '알루미늄', '소재', '가공', '용', '전용기', '개발'],
#  ['교육', '용', '비행', '로봇'],
#  ['자식', '도', '어록', '구비', '무용', '가구'],
#  ['프레', '스', '금'],
#  ['열교환기', '용', '브레이', '징', '자동화', '시스템', '개발'],
#  ['반도체', '제조', '설비', '부품', '제조'],
#  ['오일', '여과', '장치'],
#  ['보일러', '용', '개량', '볼', '밸브', '및', '급수', '난방', '용', '결구', '제조', '기술'],
#  ['신발', '부품', '작용', '금', '제조', '기술'],
#  ['선박', '구성', '부분품', '절단', '가공', '기술'],
#  ['스프링클러', '장착', '구조'],
#  ['공법'],
#  ['사파이어', '결정', '성장', '방법', '그', '장치'],
#  ['자동', '차용', '변속기', '유성기', '부품', '제조'],
#  ['신차', '종', '도어', '트림', '메인', '판넬', '개발'],
#  ['폐기물', '파쇄', '및', '분쇄기', '제조', '기술'],
#  ['브레이크', '용', '금', '개발', '및', '사출', '성형'],
#  ['승강기', '주차', '시스템', '리모', '데링', '기술'],
#  ['플랜트', '용', '압력', '용기', '제조', '기술'],
#  ['리니', '스테이지'],
#  ['산업', '용', '엔진', '발전기', '부품'],
#  ['반도체', '정', '기계', '개발'],
#  ['소방기', '자재', '렉시', '블', '조인트', '등', '제조', '기술'],
#  ['금', '이용', '열교환기', '용', '나선', '튜브', '제조', '기술'],
#  ['자동차', '부품', '동력', '전달', '장치', '및', '하이브리드', '카', '부품', '제조', '기술'],
#  ['반도체', '공정', '모니터링', '시스템'],
#  ['유로폼', '자동', '청소기', '파이프', '청소', '교정', '기'],
#  ['상용차', '포함', '클린', '디젤', '그린', '자동', '차용', '부품', '제조'],
#  ['프리', '폼', '검사', '장치'],
#  ['가전제품', '제조', '자동화', '설비'],
#  ['트랙터', '용', '앞', '차축', '프레임', '제작', '기술'],
#  ['전산실', '랙용', '공기조화', '장치'],
#  ['안개', '소산', '시스템'],
#  ['준설', '수', '처리', '장치'],
#  ['외벽', '부착', '초음파', '유량계', '정밀', '센서', '고정기'],
#  ['자동차', '향', '및', '제동장치', '부품', '가공', '기술'],
#  ['복수', '성형', '공정', '가능', '케', '파이프', '가공', '장치'],
#  ['타이밍', '제조', '기술'],
#  ['무대', '조작', '자동화', '기술'],
#  ['차세대', '중장', '비용', '소음', '구성', '유압', '펌프', '케이', '싱', '품', '개발'],
#  ['조선', '및', '플랜트', '용', '플랜', '제조'],
#  ['발', '전설', '비용', '목', '제작', '기술'],
#  ['굴삭기', '부품', '및', '풍력발전', '부품', '가공'],
#  ['전해', '살균', '정수기'],
#  ['각종', '산업', '용', '스프링', '제조', '기술'],
#  ['배처', '플랜트', '용', '기반', '혼합', '응기', '상용', '기술', '개발'],
#  ['임플란트', '시술', '용', '드릴', '비트'],
#  ['파이프', '공법', '이용', '자동차', '에어컨', '용', '머플러'],
#  ['알루미늄', '선체', '및', '의장', '제조', '기술'],
#  ['철망', '조기', '횡', '철선', '자동', '공급', '홉퍼', '장치'],
#  ['공정', '장비'],
#  ['자동차', '부품', '사출', '및', '경질', '코팅'],
#  ['복합', '공정'],
#  ['충격', '흡수', '용', '전류', '차단기', '부품', '개발'],
#  ['판형', '열교환기', '설계', '및', '제조', '엔지니어링', '기술'],
#  ['미끄럼', '방지', '조물', '및', '그', '시공', '방법'],
#  ['제작', '증착', '장비'],
#  ['사다리', '평형', '유지', '장치'],
#  ['수문', '및', '그', '제작', '방법'],
#  ['자동차', '장재', '출품'],
#  ['반도체', '지그'],
#  ['친환경', '아동', '가구'],
#  ['달리기', '용', '운동', '기구'],
#  ['자동', '차용', '브라켓'],
#  ['터보', '냉동기'],
#  ['사출', '무인', '냉각', '시스템'],
#  ['무늬', '목', '샤시', '제조'],
#  ['보급', '휠체어', '리프트'],
#  ['유기', '용제', '고순', '재생', '설비'],
#  ['자동화기', '부품', '가공', '및', '조립', '기술'],
#  ['발포', '형기'],
#  ['소방', '호스', '및', '후', '렉시', '블', '조인트', '외'],
#  ['정밀', '금'],
#  ['가전제품', '용', '사출', '금', '제조'],
#  ['초', '저온', '액체', '펌프'],
#  ['미압용', '평판', '부양', '유', '니트', '개발'],
#  ['테스트', '핸들', '러', '개선'],
#  ['상용차', '차체'],
#  ['반도체', '생산', '로봇', '용', '진공', '다축', '장치'],
#  [],
#  ['조립', '및', '검사', '기'],
#  ['시공', '기술'],
#  ['전기자동차', '용', '무단', '변속', '시스템'],
#  ['정밀', '복합', '툴', '개발', '및', '제작'],
#  ['자동차', '동력', '전달', '장치', '제조', '및', '상품화', '개발'],
#  ['자동차', '시트', '용', '팔', '받침', '개발'],
#  ['평형', '규조토', '여과기', '슬러지', '자동', '배출', '시스템'],
#  ['골', '판지', '형성', '공조', '덕트'],
#  ['제조'],
#  ['산업', '용', '에어', '필터', '및', '유공', '압', '오일', '필터', '제조', '기술'],
#  ['공작기계', '부품', '가공'],
#  ['프레', '스', '압형', '제조', '기술'],
#  ['유공', '압', '라인', '체결', '용', '피팅'],
#  ['화장품', '케이스', '용', '금', '제조', '기술'],
#  [],
#  ['도금', '및', '양산', '개발'],
#  ['플라스틱', '볼트', '너트'],
#  ['산업', '용', '커버', '절곡', '방법'],
#  ['반도체', '컨', '넥타', '금', '부품'],
#  ['산업', '용', '플랜', '제조', '기술'],
#  ['개발'],
#  ['션', '레이', '터'],
#  ['자동차', '부품', '가공'],
#  ['정장', '비', '제조', '기술'],
#  ['등', '공작기계', '제조', '기술'],
#  ['가공', '기술'],
#  ['웨이퍼', '폴리', '싱', '및', '정', '장비'],
#  ['해충', '퇴', '치기'],
#  ['경량', '강도', '조물', '제작', '기술'],
#  ['자동', '차용', '금', '제조', '기술'],
#  ['알루미늄', '압출', '및', '이송', '장치'],
#  ['댐핑', '기능', '슬라이드', '용', '자동', '폐쇄', '장치', '기술'],
#  ['전자부품', '표면', '실장', '기술'],
#  ['가전제품', '프레', '스', '금', '설계', '및', '가공', '기술'],
#  ['고압', '밸브'],
#  ['인치', '에피', '웨이퍼', '이송', '전용', '트랜스', '퍼', '로봇', '개발'],
#  ['방폭용', '플렉시블', '조인트'],
#  [],
#  [],
#  ['방폭', '창호', '용', '충격', '흡수', '장치'],
#  ['수분', '제거', '장치'],
#  ['전동', '카트', '및', '전기자동차', '시스템', '기술'],
#  ['빌드업', '금'],
#  [],
#  ['회전', '커터'],
#  ['건설', '중장비', '부품', '정밀', '가공'],
#  ['항공기', '부품', '가공', '기술'],
#  ['반도체', '웨이퍼', '제조', '시', '발생', '폐', '슬러지', '재생', '방법'],
#  ['악취', '감', '및', '오수', '정화', '장치', '개발'],
#  ['정체', '외관', '검', '사용', '조명', '장치'],
#  ['브이', '커팅용', '바이트', '수단'],
#  ['연', '제거', '시스템', '제조', '방법'],
#  ['천', '인서트', '성형', '장치', '및', '그', '성형', '방법'],
#  ['드럼', '제조', '장치', '및', '그', '제조', '방법'],
#  ['그레이', '팅', '연결', '구조'],
#  ['순간', '온수', '가열', '기'],
#  ['코팅', '제품'],
#  ['크레인', '호', '이스트', '제동', '방법', '및', '그', '제동', '장치'],
#  ['강판', '스크랩', '재활용', '등기', '구', '프레임', '등', '제조'],
#  ['가공', '기법', '활용', '아크릴', '통합', '디자인', '및', '생산'],
#  ['빌트', '업', '가공', '기술', '부식', '방지', '기술', '적용', '철골', '제품', '제조', '기술'],
#  ['공정', '개선', '통산', '골', '판지', '생산', '향상'],
#  ['선박', '블럭', '자동차', '프레임', '등', '생산', '위', '철판', '가공', '기술'],
#  ['방산품', '가공'],
#  ['및', '용', '자식', '파킹', '브레이크', '리퍼', '개발'],
#  ['선박', '블럭', '제작', '기술'],
#  ['수직', '사출', '형기', '개발'],
#  [],
#  ['생산', '공정', '물류', '장비'],
#  ['차량', '용', '성형', '시', '탭가공', '일체', '프로그레시브', '금'],
#  ['자동차', '변속기', '부품', '등', '제조', '기술'],
#  ['가변', '주파수', '제어', '방법', '이용', '구경', '웨이퍼', '초음파', '가공', '시스템', '기술', '개발'],
#  ['공장', '자동화', '자동', '제어', '시스템'],
#  ['반도체', '장비'],
#  ['폐열', '회수', '보일러', '효율', '증대', '및', '노후', '방지', '기술'],
#  ['선박', '용', '제조', '기술'],
#  ['로봇', '기술', '기반', '공작기계'],
#  ['자동차', '헤드', '라이닝', '제조', '자동화', '설비'],
#  ['자동', '차용', '프레', '스', '금', '제조', '기술'],
#  ['중량', '운반', '용', '캐스터', '및', '스틸케이스', '사업'],
#  ['사출', '기', '노즐', '가스', '배출', '장치'],
#  ['프레', '스', '금', '가공', '기술'],
#  ['필라멘트', '와인', '딩', '머신'],
#  ['신형', '전투', '장갑차', '의', '차체', '제어', '시스템'],
#  ['차기', '보병', '전투', '장갑차', '조준', '용', '탐지기', '냉각기'],
#  ['선박', '중속', '엔진', '실린더', '블럭', '제조', '기술'],
#  ['공작기계', '및', '방산', '부품', '설계', '제작'],
#  ['자동차', '부품', '용', '지그', '제작'],
#  ['중장비', '유압', '실린더', '부품', '제작', '기술'],
#  ['유압', '펌프'],
#  ['최신', '사양', '색', '옵셋', '인쇄기', '통한', '품질', '인쇄물', '제작'],
#  ['중량', '물', '이동', '위', '무동', '대차', '동화', '시스템', '개발'],
#  ['산업', '기계', '부품', '절삭', '가공', '기술'],
#  ['선박', '엔진', '용', '실린더', '헤드', '제조'],
#  ['일체', '몰드', '프레임', '금', '인서트', '성형', '기술', '개발', '및', '사업'],
#  ['생산', '공정', '최적화', '통한', '복합', '다기', '능화', '생산', '프로세스'],
#  ['가전', '용', '터치', '도어', '치', '개발'],
#  ['사출', '용', '금', '제조', '기술'],
#  ['구동', '드라이브', '국산', '통한', '해외', '시장', '경쟁력', '강화'],
#  ['턱', '구조', '상', '판', '분리', '신축', '이음', '장치'],
#  ['패키지', '강제', '순환', '가정', '용', '태양열', '수기'],
#  ['사지', '이용', '광고', '용', '솔벤트', '프린트'],
#  ['물류', '용기', '재사용', '위', '세척', '장치'],
#  ['링크', '밴딩', '시스템'],
#  ['공작기계', '부품', '및', '완성', '품', '원통', '연삭기', '생산', '기술'],
#  [],
#  ['비데', '정용', '부품', '개발'],
#  ['마스크', '세척', '장치', '제조', '기술'],
#  ['저온', '플라즈마', '멸균', '기'],
#  ['프레', '스', '금', '가공', '기술'],
#  ['레이저', '가공', '통한', '자동차', '부품', '가공', '기술'],
#  ['배기', '장치', '개선'],
#  ['알루미늄', '복합', '판넬', '가공'],
#  ['자식', '오토바이', '건', '장치'],
#  ['유비쿼터스', '절전', '가이드', '장치'],
#  ['화학', '플랜트', '용', '응기', '개발'],
#  ['자주포', '등', '방산', '부품', '가공', '기술'],
#  ['나선형', '덕트', '엘', '보우', '제조', '기술'],
#  ['스', '크류', '건', '진공', '펌프', '생산', '기술'],
#  ['초', '정밀', '플라스틱', '렌즈', '금'],
#  ['머', '시닝', '센터', '공작물', '자동', '교환', '장치'],
#  ['무', '백래쉬', '감속', '기'],
#  ['리튬이온', '배터리', '조립', '장비'],
#  ['무선', '소음', '진동', '계측기', '개발'],
#  ['정밀', '제어', '기술'],
#  ['프레', '스', '공정', '자동화', '설비', '제조', '기술'],
#  ['초', '액화', '저장', '탱크', '단열', '성능', '개선', '및', '설계', '기법'],
#  ['대형', '진공', '챔버', '오토', '리드', '장치'],
#  ['를', '이용', '연속', '주조', '용', '엔지니어링', '솔루션'],
#  ['싱글', '패스', '잉크젯', '헤드', '활용', '디지털', '라벨', '인쇄기'],
#  ['자동차', '자동화', '조립'],
#  ['장비', '쿨링', '시스템'],
#  ['자동차', '부품', '물', '유용', '파렛트', '자동화', '생산', '기'],
#  ['효율', '열교환기', '설계', '및', '제조'],
#  ['자동화', '제어장치', '제조', '기술'],
#  ['박판', '절단', '자동화', '장치'],
#  ['터치스크린', '패널', '진공', '합착기', '제조', '장비']]

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(nouns_list, vector_size = 100, window=5, min_count=1 , sg=1)

# %%
model.wv.most_similar('반도체')
# Out:
# [('개발', 0.4676632583141327),
#  ('시스템', 0.4182552397251129),
#  ('유공', 0.4062539041042328),
#  ('제조', 0.39454492926597595),
#  ('위', 0.3944481909275055),
#  ('프레임', 0.3928125202655792),
#  ('장치', 0.39046645164489746),
#  ('용', 0.3767850399017334),
#  ('및', 0.3728918135166168),
#  ('제어', 0.3715917766094208)]

# %% [markdown]
# 6. 대출금액을 가장 많이 집행한 은행을 확인하고, 해당 은행이 어떤 기술분류에 대출금액을 가장 많이 집행했는지 계산하시오.
